# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# always useful
import numpy as np
import scipy as sp
import seaborn as sns
import math
import pandas as pd
from scipy import linalg as la

from matplotlib.ticker import AutoMinorLocator, MultipleLocator, FuncFormatter
from scipy.stats.distributions import norm

# %% [markdown]
# 1\. **PCA on 3D dataset**
#
# * Generate a dataset with 3 features each with N entries (N being ${\cal O}(1000)$). With $N(\mu,\sigma)$ the normali distribution with mean $\mu$ and $\sigma$  standard deviation, generate the 3 variables $x_{1,2,3}$ such that:
#     * $x_1$ is distributed as $N(0,1)$
#     * $x_2$ is distributed as $x_1+N(0,3)$
#     * $x_3$ is given by $2x_1+x_2$
# * Find the eigenvectors and eigenvalues of the covariance matrix of the dataset
# * Find the eigenvectors and eigenvalues using SVD. Check that the two procedures yield to same result
# * What percent of the total dataset's variability is explained by the principal components? Given how the dataset was constructed, do these make sense? Reduce the dimensionality of the system so that at least 99% of the total variability is retained.
# * Redefine the data in the basis yielded by the PCA procedure
# * Plot the data points in the original and the new coordiantes as a set of scatter plots. Your final figure should have 2 rows of 3 plots each, where the columns show the (0,1), (0,2) and (1,2) proejctions.

# %%
N = 1000
x1 = np.random.normal(0, 1, N)
x2 = x1 + np.random.normal(0, 3, N)
x3 = 2*x1 + x2
x = np.array([x1,x2,x3])
c = np.cov(x)
l,V = la.eig(c)
print('eigenvalues = ',l)
print('eigenvectors = ','\n',V)
# Out:
# eigenvalues =  [ 2.74802550e+01+0.j -3.53088793e-16+0.j  1.93178282e+00+0.j]
# eigenvectors =
#  [[-0.11124935 -0.81649658  0.5665306 ]
#  [-0.5826061  -0.40824829 -0.70278266]
#  [-0.80510479  0.40824829  0.43027853]]

# %%
U, spectrum, Vt = la.svd(x)
print('eigenvectors','\n',U)
#print('spectrum','\n',spectrum)
print('eigenvalues = ',spectrum**2/1000)
#print('Vt','\n',Vt)
print('The two procedures give the same eigenvectors. The eigenvalues are the same with an appropriate ordering and scaling. Just one eigenvalue changes as it is very close to 0 in both the cases.')
# Out:
# eigenvectors
#  [[-0.11122635  0.56653511 -0.81649658]
#  [-0.58263462 -0.70275902 -0.40824829]
#  [-0.80508733  0.4303112   0.40824829]]
# eigenvalues =  [2.74669201e+01 1.92992692e+00 8.97449752e-32]
# The two procedures give the same eigenvectors. The eigenvalues are the same with an appropriate ordering and scaling. Just one eigenvalue changes as it is very close to 0 in both the cases.

# %%
l, V = np.linalg.eig(c)
Lambda=np.diag(l)
print (Lambda)
x1_var = abs(Lambda[0,0])/abs(Lambda).trace()
x2_var = abs(Lambda[1,1])/abs(Lambda).trace()
x3_var = abs(Lambda[2,2])/abs(Lambda).trace()
print('Percent of the total dataset variability of eigenvalue',Lambda[0,0],'=',x1_var*100,'%')
print('Percent of the total dataset variability of eigenvalue',Lambda[1,1],'=',x2_var*100,'%')
print('Percent of the total dataset variability of eigenvalue',Lambda[2,2],'=',x3_var*100,'%')
print('Yes it makes sense as both x2 and x3 depend on x1. x3 depend also on x2.')

print ('Percent of the total dataset variability of eigenvalues',Lambda[0,0],'and',Lambda[2,2],'together is',abs(Lambda[0,0]+Lambda[2,2])/abs(Lambda).trace()*100,'%')
# Out:
# [[ 2.74802550e+01  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00 -3.53088793e-16  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  1.93178282e+00]]
# Percent of the total dataset variability of eigenvalue 27.4802549607429 = 93.43199938946614 %
# Percent of the total dataset variability of eigenvalue -3.530887928952716e-16 = 1.200490749789117e-15 %
# Percent of the total dataset variability of eigenvalue 1.931782821080622 = 6.568000610533872 %
# Yes it makes sense as both x2 and x3 depend on x1. x3 depend also on x2.
# Percent of the total dataset variability of eigenvalues 27.4802549607429 and 1.931782821080622 together is 100.0 %

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 3,figsize = (10,6) )

ax[0,0].scatter(x[0,:], x[1,:], alpha=0.2)
ax[0,1].scatter(x[0,:], x[2,:], alpha=0.2)
ax[0,2].scatter(x[1,:], x[2,:], alpha=0.2)

xpp = np.dot(V.T,x)
ax[1,0].scatter(xpp[0,:], xpp[1,:], alpha=0.2)
ax[1,1].scatter(xpp[0,:], xpp[2,:], alpha=0.2)
ax[1,2].scatter(xpp[1,:], xpp[2,:], alpha=0.2)
fig.tight_layout()
print('In the second row the plots are ordered according to the order of the eigenvalues of the covariance matrix.')
# Out:
# In the second row the plots are ordered according to the order of the eigenvalues of the covariance matrix.

# %% [markdown]
# 2\. **PCA on a nD dataset**
#
# Start from the dataset you have genereted in the previous exercise and add uncorrelated random noise. Such noise should be represented by other 10 uncorrelated variables normal distributed, with standar deviation much smaller (say, a factor 50) than those used to generate the $x_1$ and $x_2$.
#
# Repeat the PCA procedure and compare the results with what you obtained before

# %%
X2 = x 
for i in range(0,10):
    xc = np.random.normal(0, 1/50, N)
    X2 = np.vstack([X2,xc])
C2 = np.cov(X2)    
l2,V2 = la.eig(C2)
Lambda2=np.diag(l2)

# %%
num_rows, num_cols = X2.shape
for i in range(0,num_rows):
    x_var = abs(Lambda2[i,i])/abs(Lambda2).trace()
    print('Percent of the total dataset variability of feature',i+1,'=',(x_var*100),'%')
print ('Percent of the total dataset variability of eigenvalues',(Lambda2[0,0]),'and',(Lambda2[1,1]),'is',(abs(Lambda2[0,0]+Lambda2[1,1])/abs(Lambda2).trace()*100),'%') 
print('Despite the presence of random noise, the result is the same as before')
# Out:
# Percent of the total dataset variability of feature 1 = 93.41919008664838 %
# Percent of the total dataset variability of feature 2 = 6.567107789833075 %
# Percent of the total dataset variability of feature 3 = 6.859884682286319e-16 %
# Percent of the total dataset variability of feature 4 = 0.00116980234459073 %
# Percent of the total dataset variability of feature 5 = 0.0012027716600353335 %
# Percent of the total dataset variability of feature 6 = 0.0012307037494269446 %
# Percent of the total dataset variability of feature 7 = 0.0015786054681907668 %
# Percent of the total dataset variability of feature 8 = 0.0013006498899184181 %
# Percent of the total dataset variability of feature 9 = 0.0013544165846997944 %
# Percent of the total dataset variability of feature 10 = 0.001387733018557253 %
# Percent of the total dataset variability of feature 11 = 0.0015059530996282332 %
# Percent of the total dataset variability of feature 12 = 0.0014840161336878103 %
# Percent of the total dataset variability of feature 13 = 0.0014874715698063512 %
# Percent of the total dataset variability of eigenvalues (27.480258052647063+0j) and (1.9317852847661765+0j) is 99.98629787648146 %
# Despite the presence of random noise, the result is the same as before

# %%
fig2, ax2 = plt.subplots(nrows = 2, ncols = 1,figsize = (5,8),squeeze=False)

ax2[0,0].scatter(X2[0,:], X2[1,:], alpha=0.2)
ax2[0,0].set_title('Data points in the original coordinates')

Xpp2 = np.dot(V2.T,X2)
ax2[1,0].scatter(Xpp2[0,:], Xpp2[1,:], alpha=0.2)
ax2[1,0].set_title('Data points in the new coordinates')
fig2.tight_layout()

# %% [markdown]
# 3 \. **Looking at an oscillating spring** (optional)
#
# Imagine you have $n$ cameras looking at a spring oscillating along the $x$ axis. Each  camera record the motion of the spring looking at it along a given direction defined by the pair $(\theta_i, \phi_i)$, the angles in spherical coordinates.
#
# Start from the simulation of the records (say ${\cal O}(1000)$) of the spring's motion along the x axis, assuming a little random noise affects the measurements along the $y$. Rotate such dataset to emulate the records of each camera.
#
# Perform a Principal Component Analysis on the thus obtained dataset, aiming at finding the only one coordinate that really matters.

# %% [markdown]
# 4\. **PCA on the MAGIC dataset** (optional)
#
# Perform a PCA on the magic04.data dataset

# %%
# get the dataset and its description on the proper data directory
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data -P ~/data/
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names -P ~/data/
