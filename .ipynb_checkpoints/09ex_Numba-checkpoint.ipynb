# %%
import os
import numpy as np
import math
os.environ["NUMBA_ENABLE_CUDASIM"] = "1"
from numba import jit, njit, vectorize, cuda, guvectorize
from matplotlib import pyplot as plt
from numba import vectorize, int64, float32, int16

# %% [markdown]
# ## Exercise 1
#
# Create a vectorized version of log and exp math function for 1D array A = [2, 5, 10, 3, 8]
#
# Results should be:
# + [0.6931472 1.609438  2.3025851 1.0986123 2.0794415]
# + [7.3890562e+00 1.4841316e+02 2.2026465e+04 2.0085537e+01 2.9809580e+03]

# %%
import numpy as np


@vectorize([float32(float32)],target='parallel', fastmath=True)
def exp (x):
    return np.exp(x)

@vectorize([float32(float32)],target='parallel', fastmath=True)
def log (x):
    return np.log(x)

A =np.array([2, 5, 10, 3, 8]).astype(np.float32) 

print(exp(A))
print(log(A))
# Out:
# [7.3890562e+00 1.4841316e+02 2.2026465e+04 2.0085537e+01 2.9809580e+03]
# [0.6931472 1.609438  2.3025851 1.0986123 2.0794415]

# %% [markdown]
# ## Exerice 2
# Compute the value of a Gaussian probability density function at $x$ with $mean = 1$, $\sigma = 1$, lower and upper bound in $(-3, 3)$ and $size = 100000$

# %%
size=100000
y=np.linspace(-3,3,size).astype(np.float32)

@vectorize([float32(float32)],target='parallel', fastmath=True)
def gauss(x):
    mu=1
    sigma=1
    return (np.exp(-((x-mu)**2)/(2*(sigma**2))))*(1/pow(2*np.pi*(sigma**2),1/2))

plt.plot(y,gauss(y))

# %% [markdown]
# ## Exercise 3
#
# Create a "zero suppression" function. A common operation when working with waveforms is to force all samples values below a certain absolute magnitude to be zero, as a way to eliminate low amplitude noise.
# Plot the data before and after the application of the zero_suppress function.
#
# $thresold = 15$

# %%
# %matplotlib inline

gridsize = (1, 2)
fig = plt.figure(figsize=(12, 4))

threshold=15
n = 100000
noise = np.random.normal(size=n) * 3
pulses = np.maximum(np.sin(np.arange(n) / (n / 23)) - 0.3, 0.0)
data = ((pulses * 300) + noise).astype(np.int16)
original=np.copy(data)

#put your code here

ax1=plt.subplot2grid(gridsize,(0,0))
ax1=plt.plot(np.arange(n),data)
ax1=plt.title("data")

@jit("void(i2[:])",nopython=True)
def zero_suppression (x):
    x[x<threshold]=0

zero_suppression(data)

ax2=plt.subplot2grid(gridsize,(0,1))
ax2=plt.plot(np.arange(n),data,'orange')
ax2=plt.title("suppressed data")

# %% [markdown]
# ## Exercise 4
#
# Calculate the Sigmoid kernel between the matrix X and Y defined as below. The Sigmoid kernel is defined as:
#
# $k(x,y) = \tanh(\alpha x^T y + c) $

# %%
from numba import cuda,jit
import numpy
import math


@cuda.jit
def sigmoid(x,y,k):
    alpha=3
    c=np.ones(y.shape[0])
    row, col = cuda.grid(2)
    if row < K.shape[0] and col < K.shape[1]:
         k[row][col]=np.arctan(alpha*x[col][row]*y[row][col]+c[row])


X = np.random.rand(3,3)
Y = np.random.rand(3,3)
K = np.zeros((3,3))

threadsperblock = (3, 1) #ThreadsPerBlock must be a divisor of the data dimension: 1024/ 64 / 16 = 1
blockspergrid_x = int(math.ceil(X.shape[0] / threadsperblock[0]))
blockspergrid_y = int(math.ceil(X.shape[1] / threadsperblock[1]))
blockspergrid = (blockspergrid_x, blockspergrid_y)
sigmoid[blockspergrid, threadsperblock](X,Y,K)
K
# Out:
# array([[1.04908073, 1.20806975, 1.17703382],
#        [1.30646086, 0.97123795, 0.86382146],
#        [1.25605695, 1.14102341, 0.79424597]])

# %% [markdown]
# ## Exercise 5
#
# Create a kernel function similar to the ```double_kernel``` see during the lecture and create a new function that takes a 3 dimensional matrix as input calculating the $cos$ for each element and then returns the result. The shape of the matrix must be $256X256X256$. The matrix can be randomly generated

# %%
@cuda.jit
def coseno(m1, m2):
    x, y, z = cuda.grid(3)
    if x < m2.shape[0] and y < m2.shape[1] and z <  m2.shape[2]:
         m2[x][y][z]=np.cos(m1[x][y][z])

m1=np.random.rand(256,256,256)
m2=np.zeros((256,256,256))

threadsperblock = (8,8,4) #ThreadsPerBlock must be a divisor of the data dimension: 1024/ 64 / 16 = 1
blockspergrid_x = int(math.ceil(m1.shape[0] / threadsperblock[0]))
blockspergrid_y = int(math.ceil(m1.shape[1] / threadsperblock[1]))
blockspergrid_z = int(math.ceil(m1.shape[2] / threadsperblock[2]))
blockspergrid = (blockspergrid_x, blockspergrid_y, blockspergrid_z)
coseno[blockspergrid, threadsperblock](m1,m2)
m2

#IT WORKS BUT TAKES TOO LONG
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-c8aab7355829> in <module>
#      13 blockspergrid_z = int(math.ceil(m1.shape[2] / threadsperblock[2]))
#      14 blockspergrid = (blockspergrid_x, blockspergrid_y, blockspergrid_z)
# ---> 15 coseno[blockspergrid, threadsperblock](m1,m2)
#      16 m2
#
# ~/anaconda3/lib/python3.8/site-packages/numba/cuda/simulator/kernel.py in __call__(self, *args)
#     104                 for grid_point in np.ndindex(*grid_dim):
#     105                     bm = BlockManager(self.fn, grid_dim, block_dim)
# --> 106                     bm.run(grid_point, *fake_args)
#     107
#     108             for wb in retr:
#
# ~/anaconda3/lib/python3.8/site-packages/numba/cuda/simulator/kernel.py in run(self, grid_point, *args)
#     248             def target():
#     249                 self._f(*args)
# --> 250             t = BlockThread(target, self, grid_point, block_point)
#     251             t.start()
#     252             threads.add(t)
#
# ~/anaconda3/lib/python3.8/site-packages/numba/cuda/simulator/kernel.py in __init__(self, f, manager, blockIdx, threadIdx)
#     154     '''
#     155     def __init__(self, f, manager, blockIdx, threadIdx):
# --> 156         super(BlockThread, self).__init__(target=f)
#     157         self.syncthreads_event = threading.Event()
#     158         self.syncthreads_blocked = False
#
# ~/anaconda3/lib/python3.8/threading.py in __init__(self, group, target, name, args, kwargs, daemon)
#     797             self._native_id = None
#     798         self._tstate_lock = None
# --> 799         self._started = Event()
#     800         self._is_stopped = False
#     801         self._initialized = True
#
# ~/anaconda3/lib/python3.8/threading.py in __init__(self)
#     504
#     505     def __init__(self):
# --> 506         self._cond = Condition(Lock())
#     507         self._flag = False
#     508
#
# ~/anaconda3/lib/python3.8/threading.py in __init__(self, lock)
#     220     """
#     221
# --> 222     def __init__(self, lock=None):
#     223         if lock is None:
#     224             lock = RLock()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Exercise 6
#
# Create a matrix multiplication kernel function, called ```matmul``` that takes as input two 2D matrices:
# + A of shape $24x12$
# + B of shape $12x22$
# and that computes the multiplication and put the results into a third matrix C of shape $24x12$
#
# A and B must be randomly generated and only int values are allowed.

# %%
from __future__ import division
from numba import cuda
import numpy
import math

# complete the code
@cuda.jit
def matmul(A, B, C):
    """Perform matrix multiplication of C = A * B
    """
    row, col = cuda.grid(2)
    if row < C.shape[0] and col < C.shape[1]:
        tmp = 0.
        for k in range(A.shape[1]):
            tmp += A[row, k] * B[k, col]
        C[row, col] = tmp

# Initialize the data arrays
A = np.random.randint(1,100,(24,12))
B = np.random.randint(1,100,(12,22))
C = np.zeros((24,22))

# Configure the blocks
threadsperblock = (12,11)
blockspergrid_x = int(math.ceil(C.shape[0] / threadsperblock[0]))
blockspergrid_y = int(math.ceil(C.shape[1] / threadsperblock[1]))
blockspergrid = (blockspergrid_x, blockspergrid_y)
matmul[blockspergrid,threadsperblock](A,B,C)
C
# Out:
# array([[41781., 45306., 23668., 29166., 38123., 47638., 26945., 33532.,
#         39181., 20552., 45359., 24099., 37253., 26722., 26936., 39571.,
#         38950., 36991., 40853., 31664., 45035., 42899.],
#        [27916., 31443., 17633., 32438., 36054., 50132., 18901., 31358.,
#         45621., 21739., 48539., 29549., 39220., 19808., 27251., 39612.,
#         41841., 28548., 33515., 32273., 45654., 35629.],
#        [30013., 25112., 14614., 19419., 26978., 34473., 18413., 22648.,
#         30780., 19809., 38213., 23850., 25352., 19471., 22932., 27858.,
#         25326., 28917., 28589., 25562., 35546., 36000.],
#        [35661., 36506., 20195., 30408., 30901., 43939., 27092., 27313.,
#         37742., 18051., 42362., 26568., 37457., 24123., 29158., 37205.,
#         33429., 35974., 37474., 35487., 42734., 40841.],
#        [34494., 30708., 20365., 26813., 31265., 39809., 28012., 29484.,
#         38199., 16985., 34422., 26243., 33391., 21646., 29454., 32809.,
#         33337., 29448., 30570., 33391., 43217., 38306.],
#        [36728., 34848., 17953., 24051., 31810., 39970., 25456., 31226.,
#         34665., 21875., 43830., 28435., 34946., 26747., 23667., 35675.,
#         32366., 33497., 36264., 35714., 42382., 42892.],
#        [18387., 18718.,  9915., 16521., 22026., 25974.,  9000., 14452.,
#         23135., 10367., 23596., 11214., 16928., 10683., 17545., 20164.,
#         23613., 17019., 15238., 11065., 21251., 18528.],
#        [33718., 36054., 22570., 28094., 32544., 46816., 25114., 32897.,
#         35414., 23861., 46829., 21554., 40206., 21467., 24384., 28151.,
#         37140., 28387., 34212., 30888., 41935., 40802.],
#        [22348., 23490., 12802., 14915., 17558., 23822., 13336., 14773.,
#         18685., 11387., 23102., 12083., 16955., 14038., 12248., 19637.,
