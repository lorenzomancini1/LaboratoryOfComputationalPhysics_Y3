# %% [markdown]
# ## Exercise 1
#
# Create a vectorized version of log and exp math function for 1D array A = [2, 5, 10, 3, 8]
#
# Results should be:
# + [0.6931472 1.609438  2.3025851 1.0986123 2.0794415]
# + [7.3890562e+00 1.4841316e+02 2.2026465e+04 2.0085537e+01 2.9809580e+03]

# %%
import math
import os
import numpy as np
from numba import cuda, vectorize, float32, float64, jit
import matplotlib.pyplot as plt
os.environ["NUMBA_ENABLE_CUDASIM"] = "1"

# %%
@vectorize([float32(float32)], target='parallel', fastmath=True)
def log(A):
    return np.log(A)

@vectorize([float32(float32)], target='parallel', fastmath=True)
def exp(A):
    return np.exp(A)

A = np.array([2,5,10,3,8]).astype(np.float32)
print(log(A))
print(exp(A))
# Out:
# [0.6931472 1.609438  2.3025851 1.0986123 2.0794415]
# [7.3890562e+00 1.4841316e+02 2.2026465e+04 2.0085537e+01 2.9809580e+03]

# %%
B = np.random.rand(1000).astype(np.float32)
# %timeit log(B)
# %timeit np.log(B)
# Out:
# 232 µs ± 8.05 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 1.95 µs ± 66.5 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# ## Exercise 2
# Compute the value of a Gaussian probability density function at $x$ with $mean = 1$, $\sigma = 1$, lower and upper bound in $(-3, 3)$ and $size = 100000$

# %%
@vectorize([float32(float32)], target='parallel', fastmath=True)
def gaus(x):
    return 1/np.sqrt(2*np.pi) * np.exp(-1/2 * (x-1)**2)

x = np.asarray(np.random.rand(100000)*6 - 3).astype(np.float32)
plt.plot(x, gaus(x), 'o', ms=0.05, color='black')

# %% [markdown]
# ## Exercise 3
#
# Create a "zero suppression" function. A common operation when working with waveforms is to force all samples values below a certain absolute magnitude to be zero, as a way to eliminate low amplitude noise.
# Plot the data before and after the application of the zero_suppress function.
#
# $thresold = 15$

# %%
# %matplotlib inline

n = 100000
noise = np.random.normal(size=n) * 3
pulses = np.maximum(np.sin(np.arange(n) / (n / 23)) - 0.3, 0.0)
data = ((pulses * 300) + noise).astype(np.int16)

from numba import jit, int16, void, cuda
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
ax[0].plot(data)

@jit([void(int16[:])], nopython=True) #takes more time than the normal implementation
def zero_suppress1(data):
    data[data < 15] = 0

@jit([void(int16[:])], nopython=True)# numba likes cicles
def zero_suppress2(data):
    for i, val in enumerate(data):
        if val < 15:
            data[i] = 0
            
def zero_suppress3(data):
    data[data < 15] = 0

zero_suppress2(data)
ax[1].plot(data)

# %%
# %timeit zero_suppress1(data)
# %timeit zero_suppress2(data)
# %timeit zero_suppress3(data)
# Out:
# 84.9 µs ± 556 ns per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 41.9 µs ± 4.39 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 73.1 µs ± 7.2 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# ## Exercise 4
#
# Calculate the Sigmoid kernel between the matrix X and Y defined as below. The Sigmoid kernel is defined as:
#
# $k(x,y) = \tanh(\alpha x^T y + c) $

# %%
X = np.random.rand(3,3)
Y = np.random.rand(3,3)

def k(x, y, a, c):
    return np.tanh(a*np.dot(x,y) + c)

k_numba = jit('f8[:,:](f8[:,:], f8[:,:], f4, f4)', fastmath=True, nopython=True)(k)

print(k_numba(X, Y, 1., 0.))
# %timeit k(X, Y, 1., 0.)
# %timeit k_numba(X, Y, 1., 0.)
# Out:
# <ipython-input-33-9a4f346392d9>:5: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 2d, A), array(float64, 2d, A))
#   return np.tanh(a*np.dot(x,y) + c)
# [[0.79231406 0.58901192 0.64469484]
#  [0.79274322 0.51338495 0.59503621]
#  [0.39624465 0.6459296  0.6781025 ]]
# 4.35 µs ± 60.9 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 1.69 µs ± 10.7 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# ## Exercise 5
#
# Create a kernel function similar to the ```double_kernel``` see during the lecture and create a new function that takes a 3 dimensional matrix as input calculating the $cos$ for each element and then returns the result. The shape of the matrix must be $256X256X256$. The matrix can be randomly generated

# %%
@cuda.jit
def triple_kernel(mat):
    x, y, z = cuda.grid(3)
    if x < mat.shape[0] and y < mat.shape[1] and z < mat.shape[2]:
        mat[x,y,z] = np.cos(mat[x,y,z])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-ca27dd98b9f4> in <module>
#       1 @cuda.jit
# ----> 2 def triple_kernel(mat):
#       3     x, y, z = cuda.grid(3)
#       4     if x < mat.shape[0] and y < mat.shape[1] and z < mat.shape[2]:
#       5         mat[x,y,z] = np.cos(mat[x,y,z])
#
# ~/anaconda3/lib/python3.8/site-packages/numba/cuda/decorators.py in jit(func_or_sig, argtypes, device, inline, link, debug, opt, **kws)
#      90         else:
#      91             if config.ENABLE_CUDASIM:
# ---> 92                 return FakeCUDAKernel(func_or_sig, device=device, fastmath=fastmath,
#      93                                       debug=debug)
#      94             elif device:
#
# TypeError: __init__() got an unexpected keyword argument 'debug'

# %%
M = np.random.rand(256,256,256)
threadsperblock = (16,16,16)
blockspergrid_x = int(math.ceil(M.shape[0] / threadsperblock[0]))
blockspergrid_y = int(math.ceil(M.shape[1] / threadsperblock[1]))
blockspergrid_z = int(math.ceil(M.shape[2] / threadsperblock[2]))
blockspergrid = (blockspergrid_x, blockspergrid_y, blockspergrid_z)
triple_kernel[blockspergrid, threadsperblock](M)
print(M)
# Out:
# ---------------------------------------------------------------------------
# CudaSupportError                          Traceback (most recent call last)
# <ipython-input-37-72791fc32876> in <module>
#       5 blockspergrid_z = int(math.ceil(M.shape[2] / threadsperblock[2]))
#       6 blockspergrid = (blockspergrid_x, blockspergrid_y, blockspergrid_z)
# ----> 7 triple_kernel[blockspergrid, threadsperblock](M)
#       8 print(M)
#
# ~/anaconda3/lib/python3.8/site-packages/numba/cuda/compiler.py in __call__(self, *args)
#     767
#     768     def __call__(self, *args):
# --> 769         return self.dispatcher.call(args, self.griddim, self.blockdim,
#     770                                     self.stream, self.sharedmem)
#     771
#
# ~/anaconda3/lib/python3.8/site-packages/numba/cuda/compiler.py in call(self, args, griddim, blockdim, stream, sharedmem)
#     859         argtypes = tuple(
#     860             [self.typingctx.resolve_argument_type(a) for a in args])
# --> 861         kernel = self.compile(argtypes)
#     862         kernel.launch(args, griddim, blockdim, stream, sharedmem)
#     863
#
# ~/anaconda3/lib/python3.8/site-packages/numba/cuda/compiler.py in compile(self, sig)
#     920         argtypes, return_type = sigutils.normalize_signature(sig)
#     921         assert return_type is None or return_type == types.none
# --> 922         cc = get_current_device().compute_capability
#     923         if self.specialized:
#     924             return self.definition
#
# ~/anaconda3/lib/python3.8/site-packages/numba/cuda/api.py in get_current_device()
#     373 def get_current_device():
#     374     "Get current device associated with the current thread"
# --> 375     return current_context().device
#     376
#     377
#
# ~/anaconda3/lib/python3.8/site-packages/numba/cuda/cudadrv/devices.py in get_context(devnum)
#     210     return the CUDA context.
#     211     """
# --> 212     return _runtime.get_or_create_context(devnum)
#     213
#     214
#
# ~/anaconda3/lib/python3.8/site-packages/numba/cuda/cudadrv/devices.py in get_or_create_context(self, devnum)
#     136             attached_ctx = self._get_attached_context()
#     137             if attached_ctx is None:
# --> 138                 return self._get_or_create_context_uncached(devnum)
#     139             else:
#     140                 return attached_ctx
#
# ~/anaconda3/lib/python3.8/site-packages/numba/cuda/cudadrv/devices.py in _get_or_create_context_uncached(self, devnum)
#     149             # Try to get the active context in the CUDA stack or
#     150             # activate GPU-0 with the primary context
# --> 151             with driver.get_active_context() as ac:
#     152                 if not ac:
#     153                     return self._activate_context_for(0)
#
# ~/anaconda3/lib/python3.8/site-packages/numba/cuda/cudadrv/driver.py in __enter__(self)
#     393         else:
#     394             hctx = drvapi.cu_context(0)
# --> 395             driver.cuCtxGetCurrent(byref(hctx))
#     396             hctx = hctx if hctx.value else None
#     397
#
# ~/anaconda3/lib/python3.8/site-packages/numba/cuda/cudadrv/driver.py in __getattr__(self, fname)
#     283
#     284         if self.initialization_error is not None:
# --> 285             raise CudaSupportError("Error at driver init: \n%s:" %
#     286                                    self.initialization_error)
#     287
#
# CudaSupportError: Error at driver init:
#
# CUDA driver library cannot be found.
# If you are sure that a CUDA driver is installed,
# try setting environment variable NUMBA_CUDA_DRIVER
# with the file path of the CUDA driver shared library.
# :

# %% [markdown]
# ## Exercise 6
#
# Create a matrix multiplication kernel function, called ```matmul``` that takes as input two 2D matrices:
# + A of shape $24x12$
# + B of shape $12x22$
# and that computes the multiplication and put the results into a third matrix C of shape $24x12$
#
# A and B must be randomly generated and only int values are allowed.

# %%
from __future__ import division
from numba import cuda
import numpy
import math

# complete the code
@cuda.jit
def matmul(A, B, C):
    """Perform matrix multiplication of C = A * B
    """
    row, col = cuda.grid(2)
    if row < C.shape[0] and col < C.shape[1]:
        tmp = 0.
        for k in range(A.shape[1]):
            tmp += A[row, k] * B[k, col]
        C[row, col] = tmp

# Initialize the data arrays
A = 
B = 

# Configure the blocks
threadsperblock = 
blockspergrid_x = 
blockspergrid_y = 
blockspergrid =
