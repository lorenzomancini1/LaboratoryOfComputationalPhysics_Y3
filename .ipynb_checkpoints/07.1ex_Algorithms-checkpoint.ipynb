# %% [markdown]
# 1\. **PCA on 3D dataset**
#
# * Generate a dataset with 3 features each with N entries (N being ${\cal O}(1000)$). With $N(\mu,\sigma)$ the normali distribution with mean $\mu$ and $\sigma$  standard deviation, generate the 3 variables $x_{1,2,3}$ such that:
#     * $x_1$ is distributed as $N(0,1)$
#     * $x_2$ is distributed as $x_1+N(0,3)$
#     * $x_3$ is given by $2x_1+x_2$
# * Find the eigenvectors and eigenvalues of the covariance matrix of the dataset
# * Find the eigenvectors and eigenvalues using SVD. Check that the two procedures yield to same result
# * What percent of the total dataset's variability is explained by the principal components? Given how the dataset was constructed, do these make sense? Reduce the dimensionality of the system so that at least 99% of the total variability is retained.
# * Redefine the data in the basis yielded by the PCA procedure
# * Plot the data points in the original and the new coordiantes as a set of scatter plots. Your final figure should have 2 rows of 3 plots each, where the columns show the (0,1), (0,2) and (1,2) proejctions.

# %%
import numpy as np 
from scipy import linalg as la
import numpy.random as rd
import matplotlib.pyplot as plt
n=2000
x1=rd.normal(loc=0.0, scale=1.0,size=n)
x2=x1+rd.normal(loc=0.0, scale=3.0,size=n)
x3=2*x1+x2
x=np.array([x1,x2,x3])

covx=np.cov(x)
l,V =la.eig(covx)
U,D,Vsvd=la.svd(covx)
print('Are the values the same as we expected?')
print(np.allclose(l,[D[0],D[2],D[1]]),'\n')

print(l,[D[0],D[2],D[1]],'\n')
print('The percentage of data expressed by the principal components is:',1-D.min()/D.sum())
print("it's what we expected because one of the line is a linear combination of the other two")

Xp = np.dot(V.T, x)

print(Xp)
fig,ax=plt.subplots(2,3,figsize=[30,20])
ax[0,0].plot(x[0,:],x[1,:],'r.')
ax[0,1].plot(x[0,:],x[2,:],'b.')
ax[0,2].plot(x[1,:],x[2,:],'g.')
ax[1,0].scatter(Xp[0,:],Xp[1,:],color='red')
ax[1,1].scatter(Xp[0,:],Xp[2,:],color='blue')
ax[1,2].scatter(Xp[1,:],Xp[2,:],color='green',marker='.')


plt.show()
# Out:
# Are the values the same as we expected?
# True
#
# [ 2.76277460e+01+0.j -9.25364220e-16+0.j  2.00420918e+00+0.j] [27.627746005524028, 3.8632220180611122e-16, 2.004209184114264]
#
# The percentage of data expressed by the principal components is: 1.0
# it's what we expected because one of the line is a linear combination of the other two
# [[ 1.18429775e+00 -5.53597594e+00  1.82913881e+00 ... -2.18725398e+00
#   -3.04713064e+00  5.18002752e+00]
#  [-1.90207727e-17  4.81194589e-16 -2.81105487e-16 ...  1.79702471e-16
#    1.46732608e-16 -4.88738605e-16]
#  [ 3.71583704e-01  6.57173873e-02 -1.22104753e+00 ...  2.18868888e-01
#   -7.44500860e-01 -1.30344227e+00]]

# %%
print(l)
print(V)
# Out:
# [ 2.76277460e+01+0.j -9.25364220e-16+0.j  2.00420918e+00+0.j]
# [[-0.12117014 -0.81649658  0.56449192]
#  [-0.57018844 -0.40824829 -0.71289443]
#  [-0.81252873  0.40824829  0.41608941]]

# %% [markdown]
# 2\. **PCA on a nD dataset**
#
# Start from the dataset you have genereted in the previous exercise and add uncorrelated random noise. Such noise should be represented by other 10 uncorrelated variables normal distributed, with standar deviation much smaller (say, a factor 50) than those used to generate the $x_1$ and $x_2$.
#
# Repeat the PCA procedure and compare the results with what you obtained before

# %%
xn=np.append(x,[rd.normal(loc=0.0,scale=0.02,size=n) for i in range(10)],axis=0)


covxn=np.cov(xn)

l,V =la.eig(covxn)
print(l)
print('The percentage of data represented by the 2 biggest eigenvalues is :')
print(abs(l[0]/sum(l)+l[1]/sum(l)))


fig,ax=plt.subplots(2,3,figsize=[30,20])
ax[0,0].plot(xn[0,:],xn[6,:],'r.')
ax[0,1].plot(x[0,:],x[2,:],'b.')
ax[0,2].plot(x[1,:],x[2,:],'g.')
ax[1,0].scatter(Xp[0,:],Xp[1,:],color='red')
ax[1,1].scatter(Xp[0,:],Xp[2,:],color='blue')
ax[1,2].scatter(Xp[1,:],Xp[2,:],color='green',marker='.')
# Out:
# [ 2.76277479e+01+0.j  2.00421185e+00+0.j -1.14823159e-15+0.j
#   3.61902278e-04+0.j  3.64713578e-04+0.j  4.33974278e-04+0.j
#   4.25091525e-04+0.j  3.86697154e-04+0.j  3.91223165e-04+0.j
#   3.93150672e-04+0.j  4.13575164e-04+0.j  4.05037802e-04+0.j
#   4.06081817e-04+0.j]
# The percentage of data represented by the 2 biggest eigenvalues is :
# 0.9998656547666339

# %% [markdown]
# 3 \. **Looking at an oscillating spring** (optional)
#
# Imagine you have $n$ cameras looking at a spring oscillating along the $x$ axis. Each  camera record the motion of the spring looking at it along a given direction defined by the pair $(\theta_i, \phi_i)$, the angles in spherical coordinates.
#
# Start from the simulation of the records (say ${\cal O}(1000)$) of the spring's motion along the x axis, assuming a little random noise affects the measurements along the $y$. Rotate such dataset to emulate the records of each camera.
#
# Perform a Principal Component Analysis on the thus obtained dataset, aiming at finding the only one coordinate that really matters.

# %%
period=10
Ampl=1.0
nT=2000
n_cameras=20
T=np.linspace(0,50,num=nT)
x=np.sin(0.5*period*T/np.pi)*Ampl
y=rd.normal(0.0,0.05,len(T))
z=np.zeros(len(T))

coords=np.array([x,y])

teta=rd.rand(n_cameras)*np.pi
phi=rd.rand(n_cameras)*np.pi*2.0

x_cam=np.sin(teta)*np.cos(phi)
y_cam=np.sin(teta)*np.sin(phi)

cam_coords=np.array([x_cam,y_cam])

c=np.zeros([n_cameras,nT*2])

for i in range(n_cameras):
    c[i,0::2]=coords[0,:]*x_cam[i]
    c[i,1::2]=coords[1,:]*y_cam[i]

    
    

plt.plot(T,c[9,1::2])
plt.show()

# %%
prova=np.array([[0.5,0.1],[1,0.5]])
Xr=np.dot(prova,coords)
plt.plot(T,Xr[1])
plt.show()

# %% [markdown]
# 4\. **PCA on the MAGIC dataset** (optional)
#
# Perform a PCA on the magic04.data dataset

# %%
# get the dataset and its description on the proper data directory
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data -P ~/data/
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names -P ~/data/
