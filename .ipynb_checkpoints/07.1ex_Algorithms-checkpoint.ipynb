# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
import scipy as sp
from scipy import linalg as la
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 1\. **PCA on 3D dataset**
#
# * Generate a dataset with 3 features each with N entries (N being ${\cal O}(1000)$). With $N(\mu,\sigma)$ the normal distribution with mean $\mu$ and $\sigma$  standard deviation, generate the 3 variables $x_{1,2,3}$ such that:
#     * $x_1$ is distributed as $N(0,1)$
#     * $x_2$ is distributed as $x_1+N(0,3)$
#     * $x_3$ is given by $2x_1+x_2$
# * Find the eigenvectors and eigenvalues of the covariance matrix of the dataset
# * Find the eigenvectors and eigenvalues using SVD. Check that the two procedures yield to same result
# * What percent of the total dataset's variability is explained by the principal components? Given how the dataset was constructed, do these make sense? Reduce the dimensionality of the system so that at least 99% of the total variability is retained.
# * Redefine the data in the basis yielded by the PCA procedure
# * Plot the data points in the original and the new coordiantes as a set of scatter plots. Your final figure should have 2 rows of 3 plots each, where the columns show the (0,1), (0,2) and (1,2) proejctions.

# %%
#definition of feauture
n=1000
x1 = np.random.normal(0,1,n)
x2 = x1 + np.random.normal(0,3,n)
x3 = 2*x2 + x1
X = np.array([x1,x2,x3])
print(X)
print('-------------')

#covariance matrix
np.cov(X)
l, V = la.eig(np.cov(X))
print('Eigenvalues:',l)#eigenvalues l1,l2,l3
print('Eigenvectors:',V)#eigenvectors v1,v2,v3
print('-------------')

#SVD and check the results
U, spectrum, Vt = la.svd(X)
m, n = U.shape[0], Vt.shape[0]
D = np.zeros((m, n))
for i in range(min(n, 3)):
    D[i, i] = spectrum[i]
SVD = np.dot(U, np.dot(D, Vt))
print ('Original Matrix:',SVD)#the original X matrix
print('-------------')

#check the percentage
l_svd = (spectrum**2)/(n-1)
V_svd = U
print(l_svd)
l_svd[-1]=0
print('If we remove the 3rd eigenvalue we retain the 99% or 100% of the variance of the dataset:',(l_svd[0]+l_svd[1])/sum(l_svd))
print('-------------')

#redefine data
X_new = np.dot(U, np.dot(D, Vt))
print(X_new.shape)

#plots
fig = plt.figure(figsize=(12,8))


plt.subplot(2,3,1)
plt.scatter(X[0], X[1], alpha=0.2)
scale_factor=0.5
for li, vi in zip(l, V.T):
    print (li, vi)
    # the line is defined by means of its beginning and its end 
    plt.plot([0, scale_factor*li*vi[0]], [0, scale_factor*li*vi[1]], 'r-', lw=2)
#(0,1) means x[0] vs X[1] scatter plot
plt.title("(0,1) projection",fontsize=14)
plt.ylabel("X dataset original", fontsize=16)
plt.axis([-15,15,-15,15])

plt.subplot(2,3,2)
plt.scatter(X[0], X[2], alpha=0.2)
plt.title("(0,2) projection",fontsize=14)
plt.axis([-15,15,-15,15])

plt.subplot(2,3,3)
plt.scatter(X[1], X[2], alpha=0.2)
plt.title("(1,2) projection",fontsize=14)
plt.axis([-15,15,-15,15])

plt.subplot(2,3,4)
plt.scatter(X_new[0], X_new[1], alpha=0.2)
plt.ylabel("$X_{new}$ dataset redefined",fontsize=16)
plt.axis([-15,15,-15,15])

plt.subplot(2,3,5)
plt.scatter(X_new[0], X_new[2], alpha=0.2)
plt.axis([-15,15,-15,15])

plt.subplot(2,3,6)
plt.scatter(X_new[1], X_new[2], alpha=0.2)
plt.axis([-15,15,-15,15])

plt.show()
# Out:
# [[  1.03947919   0.33020196  -0.50107268 ...   1.05720636   1.82691968
#    -1.31747539]
#  [  0.18003287  -3.53425212  -6.97425169 ...   5.8683264   -4.46273571
#    -1.32681482]
#  [  1.39954493  -6.73830229 -14.44957606 ...  12.79385916  -7.09855173
#    -3.97110503]]
# -------------
# Eigenvalues: [ 5.60564282e+01+0.j  9.72459749e-01+0.j -1.61764365e-15+0.j]
# Eigenvectors: [[-0.05976383 -0.91091252 -0.40824829]
#  [-0.42234864  0.39364319 -0.81649658]
#  [-0.90446112 -0.12362614  0.40824829]]
# -------------
# Original Matrix: [[  1.03947919   0.33020196  -0.50107268 ...   1.05720636   1.82691968
#    -1.31747539]
#  [  0.18003287  -3.53425212  -6.97425169 ...   5.8683264   -4.46273571
#    -1.32681482]
#  [  1.39954493  -6.73830229 -14.44957606 ...  12.79385916  -7.09855173
#    -3.97110503]]
# -------------
# [5.61722429e+01 9.74118670e-01 2.30212655e-31]
# If we remove the 3rd eigenvalue we retain the 99% or 100% of the variance of the dataset: 1.0
# -------------
# ...

# %% [markdown]
# What we see is that the first two dimensions are the one that retain the majority of the variance of the dataset, meanwhile
# the third is only a linear combination of the others (as it was construct the dataset)

# %% [markdown]
# 2\. **PCA on a nD dataset**
#
# Start from the dataset you have genereted in the previous exercise and add uncorrelated random noise. Such noise should be represented by other 10 uncorrelated variables normal distributed, with standar deviation much smaller (say, a factor 50) than those used to generate the $x_1$ and $x_2$.
#
# Repeat the PCA procedure and compare the results with what you obtained before

# %%
#definition of feauture
n=1000
x1 = np.random.normal(0,1,n)
x2 = x1 + np.random.normal(0,3,n)
x3 = 2*x2 + x1
x4 = np.random.normal(0,1/50,(10,n))#adding 10 features of noise
X = np.concatenate(([x1],[x2],[x3],x4),axis=0)
print(X.shape)
print('-------------')

#covariance matrix
np.cov(X)
l, V = la.eig(np.cov(X))
print('Eigenvalues:',l)#eigenvalues l1,l2,l3
print('Eigenvectors:',V)#eigenvectors v1,v2,v3
print('-------------')

#SVD and check the results
U, spectrum, Vt = la.svd(X)
m, n = U.shape[0], Vt.shape[0]
D = np.zeros((m, n))
for i in range(min(n, 3)):
    D[i, i] = spectrum[i]
SVD = np.dot(U, np.dot(D, Vt))
print ('Original Matrix:',SVD)#the original X matrix
print('-------------')

#check the percentage
l_svd = (spectrum**2)/(n-1)
V_svd = U
print('If we leave only the first two eigenvalues we retain the 99% or 100% of the variance of the dataset:')
print((l_svd[0]+l_svd[1])/sum(l_svd))
l_svd[2:]=0
print('-------------')

#redefine data
X_new = np.dot(U, np.dot(D, Vt))
print(X_new.shape)

#plots
fig = plt.figure(figsize=(12,8))


plt.subplot(2,3,1)
plt.scatter(X[0], X[1], alpha=0.2)
scale_factor=0.5
for li, vi in zip(l, V.T):
    print ('Eigenvalue:',li, 'Eigenvector:',vi)
    # the line is defined by means of its beginning and its end 
    plt.plot([0, scale_factor*li*vi[0]], [0, scale_factor*li*vi[1]], 'r-', lw=2)
#(0,1) means x[0] vs X[1] scatter plot
plt.title("(0,1) projection",fontsize=14)
plt.ylabel("X dataset original", fontsize=16)
plt.axis([-15,15,-15,15])

plt.subplot(2,3,2)
plt.scatter(X[0], X[2], alpha=0.2)
plt.title("(0,2) projection",fontsize=14)
plt.axis([-15,15,-15,15])

plt.subplot(2,3,3)
plt.scatter(X[1], X[2], alpha=0.2)
plt.title("(1,2) projection",fontsize=14)
plt.axis([-15,15,-15,15])

plt.subplot(2,3,4)
plt.scatter(X_new[0], X_new[1], alpha=0.2)
plt.ylabel("$X_{new}$ dataset redefined",fontsize=16)
plt.axis([-15,15,-15,15])

plt.subplot(2,3,5)
plt.scatter(X_new[0], X_new[2], alpha=0.2)
plt.axis([-15,15,-15,15])

plt.subplot(2,3,6)
plt.scatter(X_new[1], X_new[2], alpha=0.2)
plt.axis([-15,15,-15,15])

plt.show()
# Out:
# (13, 1000)
# -------------
# Eigenvalues: [5.81111923e+01+0.j 9.18795719e-01+0.j 1.80350911e-15+0.j
#  3.28069911e-04+0.j 3.45435608e-04+0.j 3.72020927e-04+0.j
#  4.61508513e-04+0.j 3.86359465e-04+0.j 4.03542247e-04+0.j
#  4.14421996e-04+0.j 4.25384419e-04+0.j 4.34097283e-04+0.j
#  4.36518992e-04+0.j]
# Eigenvectors: [[-5.69404960e-02 -9.11091449e-01  4.08248290e-01 -4.68336734e-04
#    1.13260443e-03 -6.97874407e-04  1.31157625e-04 -3.46112107e-04
#   -3.52692775e-04  8.59309030e-04  5.82854152e-04  3.58516588e-04
#   -1.67435327e-04]
#  [-4.23566562e-01  3.92331565e-01  8.16496581e-01  2.13345480e-04
#   -4.60745445e-04  2.98640232e-04 -1.44885979e-05  1.62952023e-04
#    9.89172293e-05 -3.91865872e-04 -2.83756104e-04 -1.56460264e-04
#    4.96517334e-05]
#  [-9.04073619e-01 -1.26428320e-01 -4.08248290e-01 -4.16457730e-05
#    2.11113538e-04 -1.00593944e-04  1.02180429e-04 -2.02080614e-05
#   -1.54858317e-04  7.55772867e-05  1.53419443e-05  4.55960606e-05
#   -6.81318607e-05]
# ...

# %% [markdown]
# Here we see that the plots are qualitatively the same as before beacuse of the PCA reduction, where we retained only
# the most important axis of the dataset (x,y) the third is just a linear combination of the two, meanwhile the other 10
# axis are just noise (as the dataset was constructed like this)

# %% [markdown]
# 3 \. **Looking at an oscillating spring** (optional)
#
# Imagine you have $n$ cameras looking at a spring oscillating along the $x$ axis. Each  camera record the motion of the spring looking at it along a given direction defined by the pair $(\theta_i, \phi_i)$, the angles in spherical coordinates.
#
# Start from the simulation of the records (say ${\cal O}(1000)$) of the spring's motion along the x axis, assuming a little random noise affects the measurements along the $y$. Rotate such dataset to emulate the records of each camera.
#
# Perform a Principal Component Analysis on the thus obtained dataset, aiming at finding the only one coordinate that really matters.

# %% [markdown]
# 4\. **PCA on the MAGIC dataset** (optional)
#
# Perform a PCA on the magic04.data dataset (a telescope for $\gamma$-rays)

# %%
import wget
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data'
info = 'https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names'
wget.download(url)
wget.download(info)
# Out:
# 'magic04.names'

# %%
info = r'data\magic04.names'
f = open(info, "r")
print(f.read())
# Out:
# 1. Title of Database: MAGIC gamma telescope data 2004
#
# 2. Sources:
#
#    (a) Original owner of the database:
#
#        R. K. Bock
#        Major Atmospheric Gamma Imaging Cherenkov Telescope project (MAGIC)
#        http://wwwmagic.mppmu.mpg.de
#        rkb@mail.cern.ch
#
#    (b) Donor:
#
#        P. Savicky
#        Institute of Computer Science, AS of CR
#        Czech Republic
#        savicky@cs.cas.cz
#
#    (c) Date received: May 2007
#
# 3. Past Usage:
#
#    (a) Bock, R.K., Chilingarian, A., Gaug, M., Hakl, F., Hengstebeck, T.,
#        Jirina, M., Klaschka, J., Kotrc, E., Savicky, P., Towers, S.,
#        Vaicilius, A., Wittek W. (2004).
#        Methods for multidimensional event classification: a case study
#        using images from a Cherenkov gamma-ray telescope.
#        Nucl.Instr.Meth. A, 516, pp. 511-528.
#
#    (b) P. Savicky, E. Kotrc.
#        Experimental Study of Leaf Confidences for Random Forest.
# ...

# %%
filename = r'data\magic04.data'
data=pd.read_csv(filename,header=None)
data.head()
# Out:
#          0         1       2       3       4         5        6        7   \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110  -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238  -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580 -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633  -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525  21.8393
#
#         8         9  10
# 0  40.0920   81.8828  g
# 1   6.3609  205.2610  g
# 2  76.9600  256.7880  g
# 3  10.4490  116.7370  g
# 4   4.6480  356.4620  g
