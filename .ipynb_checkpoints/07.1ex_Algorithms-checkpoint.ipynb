# %% [markdown]
# 1\. **PCA on 3D dataset**
#
# * Generate a dataset with 3 features each with N entries (N being ${\cal O}(1000)$). With $N(\mu,\sigma)$ the normali distribution with mean $\mu$ and $\sigma$  standard deviation, generate the 3 variables $x_{1,2,3}$ such that:
#     * $x_1$ is distributed as $N(0,1)$
#     * $x_2$ is distributed as $x_1+N(0,3)$
#     * $x_3$ is given by $2x_1+x_2$
# * Find the eigenvectors and eigenvalues of the covariance matrix of the dataset
# * Find the eigenvectors and eigenvalues using SVD. Check that the two procedures yield to same result
# * What percent of the total dataset's variability is explained by the principal components? Given how the dataset was constructed, do these make sense? Reduce the dimensionality of the system so that at least 99% of the total variability is retained.
# * Redefine the data in the basis yielded by the PCA procedure
# * Plot the data points in the original and the new coordiantes as a set of scatter plots. Your final figure should have 2 rows of 3 plots each, where the columns show the (0,1), (0,2) and (1,2) proejctions.

# %%
import numpy as np
import numpy.random as npr
import matplotlib.pyplot as plt
import matplotlib.patches as pltp
from scipy import linalg as la

# %%
N = 1000




#dataset creation

x_1 = npr.randn(N)
x_2 = x_1 + npr.randn(N)*3
x_3 = 2*x_1 + x_2

X = np.array([x_1,x_2,x_3])


#eigendecomposition

C = np.cov(X)
l, V = la.eig(C)
print('eigenstate decomposition:')
print('the eigenvectors of cov matrix are:', np.real_if_close(l))
print('the eigenvectors are:',V.T[0],V.T[1],V.T[2])

#SVD method decomposition:

U, spectrum, Vt = la.svd(C)
print('\SVD method:')
print('squared eigenvalues:', spectrum)
print('eigenvectors:',Vt[0],Vt[1],Vt[2])


#verification:
D = np.dot(V, np.dot(np.diag(np.real_if_close(l)),la.inv(V)))

m,n = U.shape[0], V.shape[0]
O = np.zeros((m,n))
for i in range(min(m, n)):
    O[i, i] = spectrum[i]
E = np.dot(U, np.dot(O, Vt))


print('\nThe two methods lead to the same eigenvectors and eigenvalues. Infact:')
print('\ntest C = D:',np.allclose(C,D))
print('test C = E:',np.allclose(C,E))
# Out:
# eigenstate decomposition:
# the eigenvectors of cov matrix are: [2.74491402e+01 1.16527877e-15 1.92811607e+00]
# the eigenvectors are: [-0.11196258 -0.58172076 -0.80564592] [-0.81649658 -0.40824829  0.40824829] [ 0.56639007 -0.70351567  0.42926448]
# \SVD method:
# squared eigenvalues: [2.74491402e+01 1.92811607e+00 1.92318364e-15]
# eigenvectors: [-0.11196258 -0.58172076 -0.80564592] [ 0.56639007 -0.70351567  0.42926448] [-0.81649658 -0.40824829  0.40824829]
#
# The two methods lead to the same eigenvectors and eigenvalues. Infact:
#
# test C = D: True
# test C = E: True

# %%
#PCA

l, V = np.linalg.eig(C)
Lambda=np.diag(l)
L_trace = Lambda.trace()


th = 0.99*Lambda.trace()  #set threshold at 99% of trace




#find number of components i which positions in Lambda's trace sum up to 99%
x,i = 0,0
k = l.argsort()     #rank l elements from the smaller to the bigger
z = l[k][::-1]            #reorder l in descendent order
while x < th:
    x += z[i]
    i += 1
#returns i = 2 variables needed    

print('\nIf we look at the contributions of different variables to the eigenvalues of covariance matrix:\n',Lambda[0,0],Lambda[1,1],Lambda[2,2])
print('We can see that the second one is negligible with respect to the other two. This is reasonable since there is a variable that is linearly dependent from the others and consequently with a proper rotation (V matrix) in the coordinate space we can find a basis in which almost all the information (>99%) is held by 2 only variables.')

#The reduced dataset in the original basis is obtained by rotation, reduction(of less significant feature) and counterrotation:
Xp = np.dot(V.T,X)
Xpp = np.delete(Xp, np.argmin(l), 0)
W = np.delete(V, np.argmin(l), 1)
Xppp = np.dot(W, Xpp)


#plot section
gridsize = (2, 3)
fig = plt.figure(figsize=(12, 8))

ax00 = plt.subplot2grid(gridsize, (0, 0))
ax01 = plt.subplot2grid(gridsize, (0, 1))
ax02 = plt.subplot2grid(gridsize, (0, 2))
ax10 = plt.subplot2grid(gridsize, (1, 0))
ax11 = plt.subplot2grid(gridsize, (1, 1))
ax12 = plt.subplot2grid(gridsize, (1, 2))


# a scale factor to emphazise the lines 
scale_factor=0.6


#original distribution:
ax00.scatter(X[0,:], X[1,:], alpha=0.3, color = 'gold')
ax00.set_title('original $x_2$ vs $x_1$')
ax00.set_xlim(-15.,15.)
ax00.set_ylim(-15.,15.)
#ax00.plot([0, scale_facto r*l[0]*V.T[0,0]], [0, scale_factor*l[0]*V.T[0,1]], 'r-', lw=2) 
#ax00.plot([0, scale_factor*l[1]*V.T[1,0]], [0, scale_factor*l[1]*V.T[1,1]], 'r-', lw=2) 


ax01.scatter(X[1,:], X[2,:], alpha=0.2, color = 'green')
ax01.set_title('original $x_3$ vs $x_2$')
ax01.set_xlim(-15.,15.)
ax01.set_ylim(-15.,15.)
#ax01.plot([0, scale_factor*l[1]*V.T[1,1]], [0, scale_factor*l[1]*V.T[1,2]], 'r-', lw=2) 
#ax01.plot([0, scale_factor*l[2]*V.T[2,1]], [0, scale_factor*l[2]*V.T[2,2]], 'r-', lw=2) 

ax02.scatter(X[2,:], X[0,:], alpha=0.2, color = 'blue')
ax02.set_title('original $x_1$ vs $x_3$')
ax02.set_xlim(-15.,15.)
ax02.set_ylim(-15.,15.)
#ax02.plot([0, scale_factor*l[2]*V.T[2,0]], [0, scale_factor*l[2]*V.T[2,2]], 'r-', lw=2) 
#ax02.plot([0, scale_factor*l[0]*V.T[0,0]], [0, scale_factor*l[0]*V.T[0,2]], 'r-', lw=2) 




#rotated distribution:
ax10.scatter(Xp[0,:], Xp[1,:], alpha=0.3, color = 'gold')
ax10.set_title('rotated $x_2$ vs $x_1$')
ax10.set_xlim(-15.,15.)
ax10.set_ylim(-15.,15.)
#ax10.plot([0, scale_factor*l[0]*V.T[0,0]], [0, scale_factor*l[0]*V.T[0,1]], 'r-', lw=2) 
#ax10.plot([0, scale_factor*l[1]*V.T[1,0]], [0, scale_factor*l[1]*V.T[1,1]], 'r-', lw=2) 


ax11.scatter(Xp[1,:], Xp[2,:], alpha=0.2, color = 'green')
ax11.set_title('rotated $x_3$ vs $x_2$')
ax11.set_xlim(-15.,15.)
ax11.set_ylim(-15.,15.)
#ax11.plot([0, scale_factor*l[1]*V.T[1,1]], [0, scale_factor*l[1]*V.T[1,2]], 'r-', lw=2) 
#ax11.plot([0, scale_factor*l[2]*V.T[2,1]], [0, scale_factor*l[2]*V.T[2,2]], 'r-', lw=2) 

ax12.scatter(Xp[2,:], Xp[0,:], alpha=0.2, color = 'blue')
ax12.set_title('rotated $x_1$ vs $x_3$')
ell = pltp.Ellipse((-.5, -.5), 40, 40, color='r', clip_on=False, fill=False)
ax12.add_artist(ell)
ax12.set_xlim(-15.,15.)
ax12.set_ylim(-15.,15.)
#ax12.plot([0, scale_factor*l[2]*V.T[2,0]], [0, scale_factor*l[2]*V.T[2,2]], 'r-', lw=2) 
#ax12.plot([0, scale_factor*l[0]*V.T[0,0]], [0, scale_factor*l[0]*V.T[0,2]], 'r-', lw=2) 

plt.show()

print('as one might see looking at line 2, the data after the rotation are aligned in a narrow line along one principal axis in the new basis (first and second plot). The third plot contains therefor all the useful information (above 99%), i.e., depicts the spread uncorrelatoed data on a single plane')
print('\n It is also visible then how two only features are enough to describe properly this dataset.')
print('\n The red circled scatter plot returns the two more important features in rotated space (reducing the dimensionality of the problem in this case is geometrically represented by finding the proper plane on which the data are actually mostly distributed on).')
# Out:
# If we look at the contributions of different variables to the eigenvalues of covariance matrix:
#  27.44914023556728 1.1652787678155488e-15 1.9281160670039237
# We can see that the second one is negligible with respect to the other two. This is reasonable since there is a variable that is linearly dependent from the others and consequently with a proper rotation (V matrix) in the coordinate space we can find a basis in which almost all the information (>99%) is held by 2 only variables.
# as one might see looking at line 2, the data after the rotation are aligned in a narrow line along one principal axis in the new basis (first and second plot). The third plot contains therefor all the useful information (above 99%), i.e., depicts the spread uncorrelatoed data on a single plane
#
#  It is also visible then how two only features are enough to describe properly this dataset.
#
#  The red circled scatter plot returns the two more important features in rotated space (reducing the dimensionality of the problem in this case is geometrically represented by finding the proper plane on which the data are actually mostly distributed on).

# %% [markdown]
# * Find the eigenvectors and eigenvalues of the covariance matrix of the dataset
# * Find the eigenvectors and eigenvalues using SVD. Check that the two procedures yield to same result
# * What percent of the total dataset's variability is explained by the principal components? Given how the dataset was constructed, do these make sense? Reduce the dimensionality of the system so that at least 99% of the total variability is retained.
# * Redefine the data in the basis yielded by the PCA procedure
# * Plot the data points in the original and the new coordiantes as a set of scatter plots. Your final figure should have 2 rows of 3 plots each, where the columns show the (0,1), (0,2) and (1,2) proejctions.

# %% [markdown]
# 2\. **PCA on a nD dataset**
#
# Start from the dataset you have genereted in the previous exercise and add uncorrelated random noise. Such noise should be represented by other 10 uncorrelated variables normal distributed, with standar deviation much smaller (say, a factor 50) than those used to generate the $x_1$ and $x_2$.
#
# Repeat the PCA procedure and compare the results with what you obtained before

# %%
sigmas = np.array([1,1.5,2,2.5,3,3.5,4,4.5,5,5.5])  #list of (different) standard deviations for noise variables
sigmas /= 50


Z = npr.randn(N,10)*sigmas
Z = Z.T
X = np.vstack((X,Z))
print(np.shape(X))
# Out:
# (13, 1000)

# %%
#eigendecomposition of cov matrix:

C = np.cov(X)
l, V = la.eig(C)
print('eigenstate decomposition:')
print('the eigenvalues of cov matrix are:\n', np.real_if_close(l))

k = np.argsort(l)
k = k[::-1]
l = l[k]
V = V[:,k]
X = X[:,k]

Lambda=np.diag(l)
L_trace = Lambda.trace()

th = 0.99*Lambda.trace()  #set threshold at 99% of trace

#find number of components i which positions in Lambda's trace sum up to 99%
x,i = 0,0
while x < th:
    x += l[i]
    i += 1
print('\nThe number of components sufficient to sum up to the 99% of cov matrix trace is',i)
print('As we can see, nothing changes from the previous case since adding randomly distributed variables which are less widely distributed around zero does not affect our data.')
print('In fact, the order of magnitude of their corresponding eigenvalue in cov matrix is negligible w.r.t. the two largest components, which is what we expect from a noise dataset.')
# Out:
# eigenstate decomposition:
# the eigenvalues of cov matrix are:
#  [ 2.89434328e+01  1.88161813e+00  1.20215496e-02  1.00832763e-02
#   7.96736976e-03  6.20135440e-03  5.18991735e-03  3.45227452e-03
#  -1.86820015e-15  2.51197838e-03  3.92778008e-04  8.99440115e-04
#   1.47976448e-03]
#
# The number of components sufficient to sum up to the 99% of cov matrix trace is 2
# As we can see, nothing changes from the previous case since adding randomly distributed variables which are less widely distributed around zero does not affect our data.
# In fact, the order of magnitude of their corresponding eigenvalue in cov matrix is negligible w.r.t. the two largest components, which is what we expect from a noise dataset.

# %% [markdown]
# 3 \. **Looking at an oscillating spring** (optional)
#
# Imagine you have $n$ cameras looking at a spring oscillating along the $x$ axis. Each  camera record the motion of the spring looking at it along a given direction defined by the pair $(\theta_i, \phi_i)$, the angles in spherical coordinates.
#
# Start from the simulation of the records (say ${\cal O}(1000)$) of the spring's motion along the x axis, assuming a little random noise affects the measurements along the $y$. Rotate such dataset to emulate the records of each camera.
#
# Perform a Principal Component Analysis on the thus obtained dataset, aiming at finding the only one coordinate that really matters.

# %%
#NOTE: I had some trouble in understanding the exercise text and picture correctly the workframe. Because of this, I reasoned about this specific exercise with my colleague Andrea Scanu of Physics of Data, and we found together the working strategy that then each of us has independently implemented.



A = 1        #Set oxillation amplitude
omega = 0.5  #Set frequency
N = 1000     #Set number of timesteps

def harm_os(t):
    x = A*np.cos(omega*t)
    return x

gridsize = (1, 2)
fig = plt.figure(figsize=(10, 5))

ax1 = plt.subplot2grid(gridsize, (0, 0), projection='3d')
ax2 = plt.subplot2grid(gridsize, (0, 1), projection='3d')

#data generation

t = np.linspace(0,100,N)   #timesteps for simulation
x_t = harm_os(t)           #corresponding value of harm os 
y_t = np.random.randn(N)*0.05  
ax1.set_xlabel('t')
ax1.set_ylabel('$x_t$')
ax1.set_zlabel('$y_t$')
ax1.set_zlim([-1,1])
ax1.set_title('harmonic oscillator')
ax1.plot(t,x_t,y_t)


#cameras settings

n = 200  #set cameras number, assumed homogene distribution on a radius 1 sphere 

import mpl_toolkits.mplot3d.axes3d as axes3d





def fibonacci_sphere(samples=1):    #I used a function found on the net to generate an uniformly distributed set of point on a sphere

    points = []
    cartesians = []
    phi = np.pi * (3. - np.sqrt(5.))  # golden angle in radians

    for i in range(samples):
        y = 1 - (i / float(samples - 1)) * 2  # y goes from 1 to -1
        radius = np.sqrt(1 - y * y)  # radius at y

        theta = phi * i  # golden angle increment

        x = np.cos(theta) * radius
        z = np.sin(theta) * radius
        
        P = np.arctan(y/x)
        T = np.arccos(z/np.sqrt(x**2+y**2+z**2))

        cartesians.append([x,y,z])  #cartesian output for camera position
        points.append((T,P))        #spherical coord. output for camera position

    return cartesians, points  #pair theta/phi






cameras_c, cameras_ang = fibonacci_sphere(n)
cameras_c, cameras_ang = np.array(cameras_c), np.array(cameras_ang)
print('shape of cameras array:', np.shape(cameras_c))

ax2.set_title('cameras distribution')
#ax2.plot([0.], [0.], [0.], markerfacecolor='k', markeredgecolor='blue', marker='o', markersize=10, alpha=0.6)
ax2.scatter(
    cameras_c.T[0],cameras_c.T[1], cameras_c.T[2], color = 'red',
    linewidth=0, alpha=0.7)



#rotate data according to camera position: assumng that the camera is located along the z axis in its own reference frame, we can find relations between the original cartesian axes and the camera's ones by rotatying in a proper way the dataset according to the theta_i and phi_i angles as follows

def rot_x(theta):
    matrix = [[1,0,0],\
              [0,np.cos(theta),-np.sin(theta)],\
              [0,np.sin(theta),np.cos(theta)]]
    return matrix

def rot_z(phi):
    matrix = [[np.cos(phi),-np.sin(phi),0],\
              [np.sin(phi),np.cos(phi),0],\
              [0,0,1]]
    return matrix

def PCA(X):
    C = np.cov(X)
    l, V = la.eig(C)

    k = np.argsort(l)   #reorder eigenvalues in decrescent order (vectors and coordinates as a consequence)
    k = k[::-1]
    l = l[k]
    V = V[:,k]
    X = X[:,k]

    Lambda=np.diag(l)
    L_trace = Lambda.trace()

    th = 0.99*Lambda.trace()  #set threshold at 99% of trace

    #find number of components i which positions in Lambda's trace sum up to 99%
    x,i = 0,0
    while x < th:
        x += l[i]
        i += 1

    W = V[:,:i]          
    XX = np.dot(V.T,X)
    XX = XX[:i]
    
    return W, XX, i  #returns reduced eigenvector matrix, reduced dataset in this soace abd 



#Create dataset of points viewed by the cameras, by rotating the original data with matixes rot_z and rot_x, rotation along the omonimous axis:
orig_data = np.array([x_t,y_t,np.zeros(len(x_t))])  #add z component (zero everywhere)

rot_data = [np.dot(rot_z(phi),np.dot(rot_x(theta),orig_data)) for (theta,phi) in cameras_ang]
rot_data = np.array(rot_data)

print('shape of rot_data array: ',np.shape(rot_data))
W,XX,I = [],[],[]
for i in range(len(rot_data)):
    w, _, _ = PCA(rot_data[i])
    W.append(w)                       #Save the principal component eigenvector for each camera's cov matrix on rotated data    

W = np.array(W)
print('the number of principal component eigenvector per camera is:', np.size(W,2))
print('We actually expect only one coordinate to count, since the signal is the one and only directed along the x axis and characterized by a single coordinate')


#check alignment between principal component eigenvector for each camera and the (1,0,0) vector in original basis:

Wp = []    #rotated vectors

for i in range(len(W)):
    theta, phi = cameras_ang[i][0], cameras_ang[i][1]
    wp = np.dot(rot_x(-theta),np.dot(rot_z(-phi),W[i]))
    wp = wp.T[0].tolist()
    Wp.append(wp)

print('Now I reported the principal component of each camera in the original basis: I expect it to be parallel to the x axis (at least in first approximation)')
print('Looking at some random vectors we can easily compare them with (1,0,0):\n')

for i in range(10):
    print(Wp[np.random.randint(0,len(Wp))],'\n')
    
print('It is easy to notice that the first component of those vector is completely compatible with either 1 or -1 (with precision > 0.01%)')
print('Similarly, the last component is extremely close to zero')
print('The second component is compatible with zero up to a 0.1% factor, still good but not perfect due to interference of noise. By the way, this noise is anyway reduced by the action of PCA. In the end the system works well as expected')
# Out:
# shape of cameras array: (200, 3)
# shape of rot_data array:  (200, 3, 1000)
# the number of principal component eigenvector per camera is: 1
# We actually expect only one coordinate to count, since the signal is the one and only directed along the x axis and characterized by a single coordinate
# Now I reported the principal component of each camera in the original basis: I expect it to be parallel to the x axis (at least in first approximation)
# Looking at some random vectors we can easily compare them with (1,0,0):
#
# [-0.999998736622252, 0.0015895766416620808, 1.2696007439805257e-16]
#
# [-0.999998736622252, 0.0015895766416621382, 4.2500725161431774e-17]
#
# [-0.999998736622252, 0.0015895766416621298, -1.6479873021779667e-16]
#
# [-0.999998736622252, 0.0015895766416621298, -1.6479873021779667e-16]
#
# [0.9999987366222522, -0.001589576641662187, -4.98136688148465e-16]
#
# [-0.9999987366222521, 0.0015895766416622673, -2.172741153660951e-16]
#
# [-0.999998736622252, 0.001589576641662181, 5.182486384480711e-17]
#
# [-0.9999987366222521, 0.0015895766416623575, -9.790345617544105e-17]
#
# [-0.9999987366222521, 0.001589576641662105, 5.833007687972014e-17]
#
# [-0.999998736622252, 0.0015895766416619936, -1.3010426069826053e-16]
#
# It is easy to notice that the first component of those vector is completely compatible with either 1 or -1 (with precision > 0.01%)
# Similarly, the last component is extremely close to zero
# The second component is compatible with zero up to a 0.1% factor, still good but not perfect due to interference of noise. By the way, this noise is anyway reduced by the action of PCA. In the end the system works well as expected
# <ipython-input-6-52ddb4356086>:53: RuntimeWarning: divide by zero encountered in double_scalars
#   P = np.arctan(y/x)

# %% [markdown]
# 4\. **PCA on the MAGIC dataset** (optional)
#
# Perform a PCA on the magic04.data dataset

# %%
# get the dataset and its description on the proper data directory
#!wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data -P ~/data/
#!wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names -P ~/data/ 

import csv

#data importation:

datalist = []

with open('/Users/ale/data/magic04.data') as data_file:
    for line in csv.reader(data_file, delimiter=','): # the delimiter is often guessed by the reader
        # again note that elements of each line are treated as strings
        # if you need to convert them into numbers, you need to to that yourself
        fLength,fWidth,fSize,\
        fConc,fConc1,fAsym,\
        fM3Long,fM3Trans,fAlpha,fDist = map(float,line[:-1])
        datalist.append([fLength,fWidth,fSize,fConc,fConc1,fAsym,fM3Long,fM3Trans,fAlpha,fDist])
        

dataset = np.array(datalist)
print(np.shape(dataset))
# Out:
# (19020, 10)

# %%
#PCA:

C = np.cov(dataset.T)
l, V = np.linalg.eig(C)
Lambda=np.diag(l)
L_trace = Lambda.trace()

th = 0.99*Lambda.trace()  #set threshold at 99% of trace

#find number of components i which positions in Lambda's trace sum up to 99%
x,i = 0,0
k = l.argsort()     #rank l elements from the smaller to the bigger
z = l[k][::-1]            #reorder l in descendent order
while x < th:
    x += z[i]
    i += 1          #index of first unuseful feature after reordering according to cov matrix eigenvalues

print('The cov matrix eigenvalues are:',l)
print('For a reasonably good description of the system it is enough to consider', i , 'features out of the', np.size(dataset,1),'total ones.')
print('\nThe correspondent eigenvalues add up to the 99%+ of the trace of cov matrix.')    

red_data = np.dot(V.T,dataset.T)
red_data = red_data[:,k][:i]   #get rid of extra features: new dataset = 6 rows (features) x 19020 entries
print('red_data shape:',np.shape(red_data))
# Out:
# The cov matrix eigenvalues are: [6.57979140e+03 3.85387048e+03 2.01638313e+03 1.32675968e+03
#  6.10187259e+02 4.33599171e+02 1.17330074e+02 8.63965822e-02
#  1.07363851e-02 3.85322858e-04]
# For a reasonably good description of the system it is enough to consider 6 features out of the 10 total ones.
#
# The correspondent eigenvalues add up to the 99%+ of the trace of cov matrix.
# red_data shape: (6, 10)
