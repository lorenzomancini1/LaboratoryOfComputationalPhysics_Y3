# %% [markdown]
# 1\. **PCA on 3D dataset**
#
# * Generate a dataset with 3 features each with N entries (N being ${\cal O}(1000)$). With $N(\mu,\sigma)$ the normali distribution with mean $\mu$ and $\sigma$  standard deviation, generate the 3 variables $x_{1,2,3}$ such that:
#     * $x_1$ is distributed as $N(0,1)$
#     * $x_2$ is distributed as $x_1+N(0,3)$
#     * $x_3$ is given by $2x_1+x_2$
# * Find the eigenvectors and eigenvalues of the covariance matrix of the dataset
# * Find the eigenvectors and eigenvalues using SVD. Check that the two procedures yield to same result
# * What percent of the total dataset's variability is explained by the principal components? Given how the dataset was constructed, do these make sense? Reduce the dimensionality of the system so that at least 99% of the total variability is retained.
# * Redefine the data in the basis yielded by the PCA procedure
# * Plot the data points in the original and the new coordiantes as a set of scatter plots. Your final figure should have 2 rows of 3 plots each, where the columns show the (0,1), (0,2) and (1,2) proejctions.

# %%
from IPython.display import Image
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from matplotlib.ticker import AutoMinorLocator, MultipleLocator, FuncFormatter
import seaborn as sns
from matplotlib import pyplot as pp
import math as m
import pandas as pd
import scipy
from scipy import linalg as la
import numpy.random as npr


#esercizio 1

gauss1 = np.random.randn(1000)
gauss2 = gauss1 + 3*np.random.randn(1000)
gauss3 = 2*gauss1 + gauss2

data = np.array([gauss1,gauss2,gauss3])

cov = np.cov(data)
l, V = la.eig(cov)
U, spectrum, Vt = np.linalg.svd(cov)

tr = sum(spectrum)
tr1 = sum(l)
percent = spectrum/tr

D = np.zeros((3, 3))
for i in range(min(3, 1000)):
    D[i, i] = spectrum[i]
    

m, a, b =  np.linalg.svd(np.dot(data,data.T))

n, c, d =  np.linalg.svd(np.dot(data.T,data))

D = np.zeros((3, 1000))
for i in range(min(3, 1000)):
    D[i, i] = a[i]

print(np.shape(d),np.shape(b),np.shape(D))

SVD = np.dot(b, np.dot(D, d))

print(np.allclose(SVD, data))

# In this case there are two eigenvalues which consist in the > 99% of the trace 
#so I could consider just those two eigenvectors.
#This happens beacause of the liner dependency.

l0, V0 = np.linalg.eig(np.dot(data, data.T)/(1000-1))

data0 = np.dot(V0.T,data)
# Out:
# (1000, 1000) (3, 3) (3, 1000)
# False

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(8, 4))

ax1.scatter(x=data[0], y=data[1], marker='o', c='r')
ax2.scatter(x=data[0], y=data[2], marker='o', c='g')
ax3.scatter(x=data[1], y=data[2], marker='o', c='b')

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(8, 4))

ax1.scatter(x=data0[0], y=data0[1], marker='o', c='r')
ax2.scatter(x=data0[0], y=data0[2], marker='o', c='g')
ax3.scatter(x=data0[1], y=data0[2], marker='o', c='b')

# %%
#data reduced 


datar = np.array([data0[0],data[1]])

cov = np.cov(datar)
l, V = la.eig(cov)
U, spectrum, Vt = np.linalg.svd(cov)

tr = sum(spectrum)
tr1 = sum(l)
percent = spectrum/tr


print(cov)
print(spectrum)

l0, V0 = np.linalg.eig(np.dot(datar, datar.T)/(1000-1))

data0 = np.dot(V0.T,datar)


# before rotation

plt.scatter(datar[0,:], datar[1], alpha=0.2)
# Out:
# [[ 28.68424088 -16.38786171]
#  [-16.38786171  10.35356091]]
# [38.29562768  0.74217412]

# %%
#after rotation

plt.scatter(data0[0,:], data0[1], alpha=0.2)

# %% [markdown]
# 2\. **PCA on a nD dataset**
#
# Start from the dataset you have genereted in the previous exercise and add uncorrelated random noise. Such noise should be represented by other 10 uncorrelated variables normal distributed, with standar deviation much smaller (say, a factor 50) than those used to generate the $x_1$ and $x_2$.
#
# Repeat the PCA procedure and compare the results with what you obtained before

# %%
random10 = npr.randn(10,1000)/50

dati = np.concatenate((data,random10), axis =0)

cova = np.cov(dati)
lam , Vec = la.eig(cova)
VectorsT, spect, Vectors = np.linalg.svd(cova)

tr2 = sum(spect)
tr3 = sum(lam)
percentual = spect/tr2


l1, V1 = np.linalg.eig(np.dot(dati, dati.T)/(1000-1))

dati1 = np.dot(V1.T,dati)


#print(cova)

#print(Vec)

#print(Vectors)

print(spect)
print(tr2)

#as in the previous case there are two eigenvalue which consist in > 99%, so the fluctuation are contained in those two
#rotating and removing the unnecessary datasets:

plt.scatter(dati1[0,:], dati1[1], alpha=0.2)
# Out:
# [2.86842428e+01 1.95445121e+00 4.68125569e-04 4.37080806e-04
#  4.33331518e-04 4.15539421e-04 4.01473006e-04 3.92971097e-04
#  3.81264264e-04 3.69444973e-04 3.62392311e-04 3.54174305e-04
#  7.15547085e-16]
# 30.642709821894

# %% [markdown]
# 3 \. **Looking at an oscillating spring** (optional)
#
# Imagine you have $n$ cameras looking at a spring oscillating along the $x$ axis. Each  camera record the motion of the spring looking at it along a given direction defined by the pair $(\theta_i, \phi_i)$, the angles in spherical coordinates.
#
# Start from the simulation of the records (say ${\cal O}(1000)$) of the spring's motion along the x axis, assuming a little random noise affects the measurements along the $y$. Rotate such dataset to emulate the records of each camera.
#
# Perform a Principal Component Analysis on the thus obtained dataset, aiming at finding the only one coordinate that really matters.

# %%
# esercizio 3

time = np.array([i/50 for i in range(-500,500)])

positionx = np.cos(time)

positiony = 0.05*np.random.randn(1000)

positionz = np.zeros(1000)

position = np.array([positionx,positiony,positionz])

# I have created a set of coordinates (x,y,z) for an harmonic oscillator 


plt.plot(time,positionx)
plt.plot(time,positiony)
plt.plot(time,positionz)

# these three plots show the time evolution of the three coordinates

anglesphi = np.array([np.pi*i/3 for i in range(0,3)])
anglestheta = np.array([np.pi*i/3 for i in range(-2,2)])

# a set of angles to label the cameras

rotx = np.array([[[1,0,0],[0,np.cos(i),-np.sin(i)],[0,np.sin(i),np.cos(i)]] for i in anglestheta ])
rotz = np.array([[[np.cos(i),-np.sin(i),0],[np.sin(i),np.cos(i),0],[0,0,1]] for i in anglesphi ])

# the related rotation around x and z axis

rotation = []
for i in range(0,3):
    for j in range(0,len(anglestheta)):
        rotation.append(np.dot(rotx[j],np.dot(rotz[i], position)))

rotation = np.array(rotation)

# this is a set of the positions recorded by all of the 12 cameras, 

#print(rotation.shape)

# shape = (12,3,1000)

fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(8, 4))

ax1.scatter(x=rotation[0][0], y=rotation[7][0], marker='o', c='r')
ax2.scatter(x=rotation[3][0], y=rotation[1][0], marker='o', c='g')
ax3.scatter(x=rotation[4][0], y=rotation[1][2], marker='o', c='b')

# some correlation

cov1 = np.cov(rotation[0])
cov2 = np.cov(rotation[1])
cov3 = np.cov(rotation[2])
cov4 = np.cov(rotation[3])
cov5 = np.cov(rotation[4])
cov6 = np.cov(rotation[5])
cov7 = np.cov(rotation[5])
cov8 = np.cov(rotation[7])


# some of the covariance matrices

VectorsT1, spect1, Vectors1 = np.linalg.svd(cov1)
VectorsT2, spect2, Vectors2 = np.linalg.svd(cov2)
VectorsT3, spect3, Vectors3 = np.linalg.svd(cov3)
VectorsT4, spect4, Vectors4 = np.linalg.svd(cov4)
VectorsT5, spect5, Vectors5 = np.linalg.svd(cov5)
VectorsT6, spect6, Vectors6 = np.linalg.svd(cov6)
VectorsT7, spect7, Vectors7 = np.linalg.svd(cov7)
VectorsT8, spect8, Vectors8 = np.linalg.svd(cov8)

print(spect)

# here we can see that the spectrum has a eigenvalus greater than the others for all cameras record

print("The eigenvector of the greater eigenvalues rotated:")
print(Vectors1.T[0])
print(Vectors2.T[0])
print(Vectors3.T[0])
print(Vectors4.T[0])
print(np.dot(rotz[1].T,Vectors5.T[0]))
print(np.dot(rotz[1],Vectors6.T[0]))
print(np.dot(rotz[1],Vectors7.T[0]))      
print(np.dot(rotz[1],Vectors8.T[0]))

print("As we can see the result is compatiple with the x axis (1,0,0), so there is an axis which consist in the large amount of the information")


#This last exercise has been developed with the help of another Data Physics student Alessandro Marcomini. 
#The idea is the same one but the code has been developed by ourselves.
# Out:
# [5.20383895e-01 2.58985607e-03 3.83362871e-19]
# The eigenvector of the greater eigenvalues rotated:
# [-0.99999856 -0.00169842 -0.        ]
# [-0.99999856  0.00169842 -0.        ]
# [-0.99999856 -0.00169842  0.        ]
# [-0.99999856  0.00169842 -0.        ]
# [-9.99998558e-01 -1.69842001e-03  2.58447996e-14]
# [-9.99998558e-01  1.69842001e-03 -2.34649199e-14]
# [-9.99998558e-01  1.69842001e-03 -2.34649199e-14]
# [-9.99998558e-01  1.69842001e-03  2.34649199e-14]
# As we can see the result is compatiple with the x axis (1,0,0), so there is an axis which consist in the large amount of the information

# %% [markdown]
# 4\. **PCA on the MAGIC dataset** (optional)
#
# Perform a PCA on the magic04.data dataset

# %%
# get the dataset and its description on the proper data directory
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data -P ~/data/
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names -P ~/data/
