# %% [markdown]
# 1\. **PCA on 3D dataset**
#
# * Generate a dataset with 3 features each with N entries (N being ${\cal O}(1000)$). With $N(\mu,\sigma)$ the normali distribution with mean $\mu$ and $\sigma$  standard deviation, generate the 3 variables $x_{1,2,3}$ such that:
#     * $x_1$ is distributed as $N(0,1)$
#     * $x_2$ is distributed as $x_1+N(0,3)$
#     * $x_3$ is given by $2x_1+x_2$
# * Find the eigenvectors and eigenvalues of the covariance matrix of the dataset
# * Find the eigenvectors and eigenvalues using SVD. Check that the two procedures yield to same result
# * What percent of the total dataset's variability is explained by the principal components? Given how the dataset was constructed, do these make sense? Reduce the dimensionality of the system so that at least 99% of the total variability is retained.
# * Redefine the data in the basis yielded by the PCA procedure
# * Plot the data points in the original and the new coordiantes as a set of scatter plots. Your final figure should have 2 rows of 3 plots each, where the columns show the (0,1), (0,2) and (1,2) proejctions.

# %%
import numpy as np
import seaborn as sns
import math
import pandas as pd
from scipy import linalg as la
import matplotlib.pyplot as plt

# %%
########################## GENERATE THE DATASET ##########################

N = 1000 # number of entries

#For random samples from N(\mu, \sigma^2), use:
#  N(\mu,\sigma^2) = sigma * np.random.randn(...) + mu

x1 = np.random.randn(N) # x1 is done

# For creating an array of data normally distributed around 0 with deviation = 3, we must multiply np.random.randn
# by sqrt(3):
sqrtthree = math.sqrt(3) # I'm saving it as a variable so that it won't be computed every time

x2 = np.random.randn(N) * sqrtthree
# Now for every i element of x2, we must add x1[i]:
x2 = np.add(x1, x2)

#x3[i] is just 2*x1[i]+x2[i]
x3 = np.add(2*x1, x2)
#sns.distplot(x3); # just checking if everything is alright so far

dataset = []
dataset = np.append(dataset,x1)
dataset = np.append(dataset,x2)
dataset = np.append(dataset,x3)
dataset = dataset.reshape(3,1000)
print(dataset,'\n',x1)
# Out:
# [[ 0.13469723  0.85162804  0.15945331 ...  0.76695023 -0.80812208
#    0.04292756]
#  [ 2.14816182 -1.97288944  0.53291711 ... -1.50715501 -1.05415786
#   -2.59016145]
#  [ 2.41755628 -0.26963335  0.85182374 ...  0.02674545 -2.67040202
#   -2.50430633]]
#  [ 1.34697232e-01  8.51628045e-01  1.59453314e-01 -1.06551743e+00
#  -7.04994006e-01 -6.51057018e-01  1.41047472e+00 -8.24760391e-01
#  -3.68077863e-01  2.34471427e-01 -1.71803475e+00 -1.47700853e+00
#  -1.14640196e+00  1.30645286e+00  1.20242749e+00 -1.69270185e-01
#   2.28747280e-01  1.93161353e-01  2.55191992e+00 -5.65529637e-01
#  -7.71140978e-01 -5.70019444e-01  3.55710974e-01 -1.09663646e+00
#  -1.80203144e+00 -7.61479486e-01  2.15478737e-01  2.62107475e-01
#  -9.08581895e-01 -7.41147839e-01 -2.00019505e+00 -4.44241641e-01
#  -1.04479829e+00  7.98951203e-01  5.02590104e-01  3.70512114e-02
#   1.56174506e+00  1.03058202e+00 -1.07507381e+00  1.14598862e-01
#  -5.74134293e-01  1.50642122e-01 -1.23148503e-01 -7.41420253e-01
# ...

# %%
############# EIGENVECTORS AND VALUES OF COVARIANCE MATRIX ##############
dataset_cov = np.cov(dataset)


# EIGENVECTORS AND VALUES OF COVARIANCE MATRIX USING SCIPY FUNCTIONS
l, V = la.eig(dataset_cov)

print(dataset_cov.shape)


# EIGENVECTORS AND VALUES OF COVARIANCE MATRIX USING SVD
U, spectrum, Vt = la.svd(dataset_cov)

m, n = dataset_cov.shape[0], dataset_cov.shape[1]

D = np.zeros((m, n))
for i in range(min(m, n)):
    D[i, i] = spectrum[i]
SVD = np.dot(U, np.dot(D, Vt))

lsvd, Vsvd = la.eig(SVD)

#print((np.allclose(l,lsvd) and np.allclose(Vsvd,V, atol=.9)))
diff = np.add(SVD,-dataset_cov)
diff # matrix of the differences beetween dataset_cov and SVD

# Given that the matrices dataset_cov and SVD are almost equal, but not the same, the eigenvalue and eigenvectors
# will be different
# Out:
# (3, 3)
# array([[ 0.00000000e+00, -2.22044605e-16,  3.10862447e-15],
#        [ 5.55111512e-16, -1.77635684e-15,  0.00000000e+00],
#        [ 8.88178420e-16, -1.77635684e-15,  3.55271368e-15]])

# %%
##################### PCA ########################

# Let us see how are the eigenvalues are
x = np.arange(0,3,1)
plt.scatter(x,l)

# Only 2 of the 3 seems relevant

# %%
threshold = 0.1

Lambda=np.diag(l)
print(Lambda.shape)
pcafilter = ((abs(Lambda) > threshold).astype(int))
pcaLambda = np.multiply(Lambda,pcafilter)

print(pcaLambda)

# we can still “explain” ...

pcaLambda.trace()/Lambda.trace() # almost everything

# ... of the total variability.

# We can say that the two principal components can explain everything, the other non-zero components are still very
# much insignificant
# Out:
# (3, 3)
# [[15.5858961 +0.j  0.        +0.j  0.        +0.j]
#  [ 0.        +0.j -0.        +0.j  0.        +0.j]
#  [ 0.        +0.j  0.        +0.j  1.14205212+0.j]]
# (1+0j)

# %%
########## PCA BASIS ################

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(dataset[0,:], dataset[1,:], dataset[2,:], c='g',alpha=0.1)

# %%
print(np.dot(V,V.T))
print(V)
# Out:
# [[ 1.00000000e+00 -5.23179536e-16  1.20111018e-16]
#  [-5.23179536e-16  1.00000000e+00  4.00297133e-16]
#  [ 1.20111018e-16  4.00297133e-16  1.00000000e+00]]
# [[-0.20275465 -0.81649658  0.54057736]
#  [-0.4593147  -0.40824829 -0.78890008]
#  [-0.864824    0.40824829  0.29225464]]

# %%
rdataset = np.dot(V.T,dataset)
dataset.shape
# Out:
# (3, 1000)

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3, figsize=(16, 8))


ax1.scatter(x=dataset[0,:], y=dataset[1,:], marker='o', c='r', edgecolor='b', alpha=0.2)    
ax2.scatter(x=dataset[1,:], y=dataset[2,:], marker='o', c='r', edgecolor='b', alpha=0.2)
ax3.scatter(x=dataset[0,:], y=dataset[2,:], marker='o', c='r', edgecolor='b', alpha=0.2)

ax4.scatter(x=rdataset[0,:], y=rdataset[1,:], marker='o', c='g', edgecolor='b', alpha=0.2)
plt.axis([-10,10,-10,10]);
ax5.scatter(x=rdataset[1,:], y=rdataset[2,:], marker='o', c='g', edgecolor='b', alpha=0.2)
plt.axis([-10,10,-10,10]);
ax6.scatter(x=rdataset[0,:], y=rdataset[2,:], marker='o', c='g', edgecolor='b', alpha=0.2)
plt.axis([-10,10,-10,10]);

# %%
# Il metodo PCA sembra aver funzionato: i dati sono stati rappresentati nella base dei due autovalori rappresentativi
# E' possibile di fatti ridurre il problema di una dimensione andando a lavorare coi dati in tale base
#

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(rdataset[0,:], rdataset[1,:], rdataset[2,:], c='g',alpha=0.1)
ax.view_init(elev=90, azim=90)

# %% [markdown]
# 2\. **PCA on a nD dataset**
#
# Start from the dataset you have genereted in the previous exercise and add uncorrelated random noise. Such noise should be represented by other 10 uncorrelated variables normal distributed, with standar deviation much smaller (say, a factor 50) than those used to generate the $x_1$ and $x_2$.
#
# Repeat the PCA procedure and compare the results with what you obtained before

# %%
import random

x4 = np.zeros(0)
print(x4)
x4bin = N//10 # 100

i = 1
while(i<=10):
    temp = (np.random.randn(x4bin) * math.sqrt(1/50) +random.randrange(-10,10))/(random.randrange(1,10))
    x4 = np.append(x4,temp)
    i += 1

#print(x4)
print(x4.shape)
sns.distplot(x4);

x4 = x4.reshape(-1,1)
# this looks pretty much a random noise
# Out:
# []
# (1000,)

# %%
print(x1.shape,x2.shape,x4.shape)
ex2data = []
ex2data = np.append(ex2data,x1)
ex2data = np.append(ex2data,x2)
ex2data = np.append(ex2data,x4)

ex2data = ex2data.reshape(3,1000)

#print(ex2data,x1)
# Out:
# (1000,) (1000,) (1000, 1)

# %%
ex2data_cov = np.cov(ex2data)

print(ex2data_cov)


ex2l, ex2V = la.eig(ex2data_cov)

ex2Lambda=np.diag(ex2l)

print(ex2Lambda) # no eigenvalues are negligible
# Out:
# [[ 0.9744625   0.96444504  0.13534997]
#  [ 0.96444504  3.99892779 -0.13896819]
#  [ 0.13534997 -0.13896819  7.4990641 ]]
# [[0.68890673+0.j 0.        +0.j 0.        +0.j]
#  [0.        +0.j 4.27747137+0.j 0.        +0.j]
#  [0.        +0.j 0.        +0.j 7.50607629+0.j]]

# %%
ex2rdata = np.dot(ex2V.T,ex2data)

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3, figsize=(16, 8))

ax1.scatter(x=ex2data[0,:], y=ex2data[1,:], marker='o', c='r', edgecolor='b', alpha=0.2)
ax2.scatter(x=ex2data[1,:], y=ex2data[2,:], marker='o', c='r', edgecolor='b', alpha=0.2)
ax3.scatter(x=dataset[0,:], y=ex2data[2,:], marker='o', c='r', edgecolor='b', alpha=0.2)

ax4.scatter(x=ex2rdata[0,:], y=ex2rdata[1,:], marker='o', c='g', edgecolor='b', alpha=0.2)
plt.axis([-10,10,-10,10]);
ax5.scatter(x=ex2rdata[1,:], y=ex2rdata[2,:], marker='o', c='g', edgecolor='b', alpha=0.2)
plt.axis([-10,10,-10,10]);
ax6.scatter(x=ex2rdata[0,:], y=ex2rdata[2,:], marker='o', c='g', edgecolor='b', alpha=0.2)
plt.axis([-10,10,-10,10]);

# %%
# il primo grafico dovrebbe rappresentare x1 e x2, mentre il secondo e il terzo rappresentano x3 con x2 o x1
# questo si può intuire confrontando il secondo e il terzo grafico con l'istogramma di x4, che presenta gli stessi
# "picchi".

# %% [markdown]
# 3 \. **Looking at an oscillating spring** (optional)
#
# Imagine you have $n$ cameras looking at a spring oscillating along the $x$ axis. Each  camera record the motion of the spring looking at it along a given direction defined by the pair $(\theta_i, \phi_i)$, the angles in spherical coordinates.
#
# Start from the simulation of the records (say ${\cal O}(1000)$) of the spring's motion along the x axis, assuming a little random noise affects the measurements along the $y$. Rotate such dataset to emulate the records of each camera.
#
# Perform a Principal Component Analysis on the thus obtained dataset, aiming at finding the only one coordinate that really matters.

# %%
# first, we generate the data for the camera (0,0):
#  x(t) = A*sin(w*t)
# Let's consider A and w = 0:
#  x(t) = sin(t)

camera00x = np.zeros(0)
camera00y = np.zeros(0)
camera00z = np.ones(6280)
temp = np.cos(np.arange(0,6280)/100)

camera00x = np.append(camera00x, temp)
camera00y = np.random.rand(6280)/10
#print(temp)
plt.scatter(camera00x, camera00y,alpha=0.1)
print(camera00x.shape,camera00y.shape)
# Out:
# (6280,) (6280,)

# %%
camera = np.concatenate((camera00x, camera00y, camera00z), axis=0)
camera = camera.reshape(3,6280)
# now me must rotate our data (to simulate other cameras)
#print(camera00x,camera,camera00y)

# %%
def rotationmatrix(theta,psi):
    rot = np.zeros((3,3))
    
    rot[0,0] = math.cos(theta)
    rot[1,0] = math.sin(theta)
#   rot[2,0] = 0
    rot[0,1] = -math.cos(psi)*math.sin(theta)
    rot[1,1] = math.cos(psi)*math.cos(theta)
    rot[2,1] = -math.sin(psi)
    rot[0,2] = -math.sin(psi)*math.sin(theta)
    rot[1,2] = math.sin(psi)*math.cos(theta)
    rot[2,2] = math.cos(psi)
    
    return rot

# %%
rot = rotationmatrix(0,math.pi/2)
rcamera = np.dot(rot.T,camera)

plt.scatter(rcamera[0,:], rcamera[1,:],alpha=0.1)

# at psi = pi/2 we only see y and z, so the "sinusoidal" feature of the data is not shown

# %%
# for theta = 0 and psi = pi/2 the transformation works, so the matrix should be right, let's some other rotation

# %%
rot = rotationmatrix(0,0)
rcamera = np.dot(rot.T,camera)

plt.scatter(rcamera[0,:], rcamera[1,:],alpha=0.1)
#this is the exact same plot, (identical transformation)

# %%
rot = rotationmatrix(math.pi/2,0)
rcamera = np.dot(rot.T,camera)

plt.scatter(rcamera[0,:], rcamera[1,:],alpha=0.1)

# In this graph z axis doesn't show up, we only rotate the camera to see the first plot rotated of 90° degrees

# %%
rot = rotationmatrix(math.pi/4,math.pi/4)
rcamera = np.dot(rot.T,camera)

plt.scatter(rcamera[0,:], rcamera[1,:],alpha=0.1)

# this is a more mixed transformation

# %%
# Now we have to generate more data for different angles

theta = 2 * math.pi * random.uniform(0, 1)
phi   = math.acos(1 - 2 * random.uniform(0, 1))
    
# let's define the rotation matrix:
transf = rotationmatrix(theta,phi)
    
# we have to rotate the data
othercamera = np.dot(transf.T,camera)

# %%
othercamera_cov = np.cov(othercamera)

ex3l, ex3V = la.eig(othercamera_cov)

ex3Lambda=np.diag(ex3l)

# %%
pcacamera = np.dot(ex3V.T,othercamera)

# %%
fig, ((ax1, ax2, ax3), (ax7,ax8,ax9), (ax4, ax5, ax6)) = plt.subplots(nrows=3, ncols=3, figsize=(16, 12))

ax1.scatter(x=camera[0,:], y=camera[1,:], marker='o', c='r', edgecolor='b', alpha=0.2)
ax2.scatter(x=camera[0,:], y=camera[2,:], marker='o', c='r', edgecolor='b', alpha=0.2)
ax3.scatter(x=camera[1,:], y=camera[2,:], marker='o', c='r', edgecolor='b', alpha=0.2)

ax7.scatter(x=othercamera[0,:], y=othercamera[1,:], marker='o', c='b', edgecolor='k', alpha=0.2)
plt.axis([-10,10,-10,10]);
ax8.scatter(x=othercamera[0,:], y=othercamera[2,:], marker='o', c='b', edgecolor='k', alpha=0.2)
plt.axis([-10,10,-10,10]);
ax9.scatter(x=othercamera[1,:], y=othercamera[2,:], marker='o', c='b', edgecolor='k', alpha=0.2)
plt.axis([-10,10,-10,10]);

ax4.scatter(x=pcacamera[0,:], y=pcacamera[1,:], marker='o', c='g', edgecolor='g', alpha=0.2)
plt.axis([-10,10,-10,10]);
ax5.scatter(x=pcacamera[0,:], y=pcacamera[2,:], marker='o', c='g', edgecolor='g', alpha=0.2)
plt.axis([-10,10,-10,10]);
ax6.scatter(x=pcacamera[1,:], y=pcacamera[2,:], marker='o', c='g', edgecolor='g', alpha=0.2)
plt.axis([-10,10,-10,10]);

# %%
# La prima riga è relativa ai dati della telecamera orientata a (theta,phi)=(0,0)
# La seconda riga è relativa ai dati della telecamera con angolo theta e phi cambiati
# La terza riga rappresenta i dati delle telecamera spostata, nella base degli autovalori secondo il metodo PCA

# %% [markdown]
# 4\. **PCA on the MAGIC dataset** (optional)
#
# Perform a PCA on the magic04.data dataset

# %%
# get the dataset and its description on the proper data directory
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data -P ~/data/
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names -P ~/data/
# Out:
# --2020-11-26 14:59:21--  https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1477391 (1.4M) [application/x-httpd-php]
# Saving to: ‘/home/saverio/data/magic04.data.10’
#
# magic04.data.10     100%[===================>]   1.41M  1.07MB/s    in 1.3s
#
# 2020-11-26 14:59:23 (1.07 MB/s) - ‘/home/saverio/data/magic04.data.10’ saved [1477391/1477391]
#
# --2020-11-26 14:59:23--  https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5400 (5.3K) [application/x-httpd-php]
# ...
