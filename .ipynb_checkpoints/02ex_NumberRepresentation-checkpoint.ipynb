# %% [markdown]
# 1\. Write a function that converts number representation (bin<->dec<->hex)

# %%
#code ex1

k= input("Digit a,b or c, if you want to convert: \n a.decimal number \n b.binary number \n c.hexidecimal \n")


def convert(n):
    if k == str("a"):
        print('Hexadecimal representation:', hex(n))
        print('Binary representation; ', bin(n))      
    if k == str("b"):
        print('Hexadecimal representation:', hex(n))
        print('Decimal representation: ', n )
    if k== str("c"):
        print('Decimal representation:', n)
        print('Binary representation; ', bin(n))      

if k == str("a"):
    d = int(input("Enter a decimal number: "))
    print(d)
    convert(d)
         
if k == str("b"):
    bi = int(input("Enter a binary number: "),2)
    convert(bi)
    
if k == str("c"):
    he = int(input("Enter a hexidecimal number: "),16)
    convert(he)
# Out:
# Digit a,b or c, if you want to convert:
#  a.decimal number
#  b.binary number
#  c.hexidecimal
# a
# Enter a decimal number: 18
# 18
# Hexadecimal representation: 0x12
# Binary representation;  0b10010

# %% [markdown]
# 2\. Write a function that converts a 32 bit word into a single precision floating point (i.e. interprets the various bits as sign, mantissa and exponent)

# %%
#code ex2
import math
a = 11000000101100000000000000000000 #binary number
alist = [str(x) for x in str(a)]


def conv(*alist):
    s = int(alist[0])
    #print(s)
    
    exp=alist[1:9]
    #print(exp)    
    exp_n = int("".join(exp),2)  #convert in binary the numbers from the list
    p = pow(2,(exp_n-127))
    #print(p)
        
    mant=alist[9:33]
    #print(mant)
    mant_n=int("".join(mant),2)
    #print(mant_n)
    power = math.ceil(math.log(mant_n,10))

    
    num = (pow(-1,s) + pow(-1,s)*(mant_n/pow(10,power))) * pow(10,p)
    print(format(num, "e"))
    

    
print("Number in binary: ", a)    
conv(*alist)
# Out:
# Number in binary:  11000000101100000000000000000000
# -1.314573e+04

# %% [markdown]
# 3\. Write a program to determine the underflow and overflow limits (within a factor of 2) for python on your computer.
#
# **Tips**: define two variables inizialized to 1 and halve/double them enough time to exceed the under/over-flow limits

# %%
#code ex3
import sys

under = 1
over = 1


#underflow limit
while under > sys.float_info.min:
    result= under
    under = under/2
print("Underflow: ", result)

#overflow limit
while over < sys.float_info.max:
    result2=over
    over = over*2
print("Overflow: ",float(result2))
# Out:
# Underflow:  4.450147717014403e-308
# Overflow:  8.98846567431158e+307

# %% [markdown]
# 4\. Write a program to determine the machine precision
#
# **Tips**: define a new variable by adding a smaller and smaller value (proceeding similarly to prob. 2) to an original variable and check the point where the two are the same

# %%
#code ex4

s_var=1
o_var=1

for i in range (100):
    s_var=s_var/2
    var=1+s_var
    if o_var == var:
        print("The two variable are the same, for i equal to: ", i)
        break
# Out:
# The two variable are the same, for i equal to:  52

# %% [markdown]
# 5\. Write a function that takes in input three parameters $a$, $b$ and $c$ and prints out the two solutions to the quadratic equation $ax^2+bx+c=0$ using the standard formula:
# $$
# x=\frac{-b\pm\sqrt{b^2-4ac}}{2a}
# $$
#
# (a) use the program to compute the solution for $a=0.001$, $b=1000$ and $c=0.001$
#
# (b) re-express the standard solution formula by multiplying top and bottom by $-b\mp\sqrt{b^2-4ac}$ and again find the solution for $a=0.001$, $b=1000$ and $c=0.001$. How does it compare with what previously obtained? Why?
#
# (c) write a function that compute the roots of a quadratic equation accurately in all cases

# %%
#code ex5

#part a

a=0.001
b=1000
c=0.001

import math

def solution(a,b,c):
    delta_sqrt=math.sqrt((b*b)-(4*a*c))
    sol1=(-b+delta_sqrt)/(2*a) 
    sol2=(-b-delta_sqrt)/(2*a)
    return sol1, sol2

print("Part a")
print(solution(a,b,c))
print("\n")

#part b

def solution2(a,b,c):
    delta_sqrt=math.sqrt((b*b)-(4*a*c))
    sol1=((-b+delta_sqrt)*(-b-delta_sqrt))/((2*a)*(-b-delta_sqrt)) 
    sol2=((-b-delta_sqrt)*(-b+delta_sqrt))/((2*a)*(-b+delta_sqrt))
    return sol1, sol2

print("Part b")
print(solution2(a,b,c))
print("\n")

#How does it compare with what previously obtained? Why?
#The result otained is not exactly the same: after multiplying top and bottom for the required quantity we obtain different decimals due to computer arithmetic.
#when using floating point numbers, algebrically equivalent algorithms can give different results.


#part c  IN ALL CASES 

def solution_allcases(a,b,c):
    delta=(b*b)-(4*a*c)
    delta_sqrt=math.sqrt(abs((b*b)-(4*a*c)))
    if a==0: 
        print("Error: it's not a quadratic equation")
        return 
    if delta > 0:
        sol1=(-b+delta_sqrt)/(2*a) 
        sol2=(-b-delta_sqrt)/(2*a)
        print(sol1,sol2)
    if delta == 0:
        print("The two solution are the same: ", (-b)/(2*a))
    if delta < 0:
        print((-b/(2*a)), "+", (delta_sqrt/2*a),"i")
        print((-b/(2*a)), "-", (delta_sqrt/2*a),"i")
        
print("Part c")        
solution_allcases(1,4,5)
# Out:
# Part a
# (-9.999894245993346e-07, -999999.999999)
#
#
# Part b
# (-9.999894245993346e-07, -999999.9999990001)
#
#
# Part c
# -2.0 + 1.0 i
# -2.0 - 1.0 i

# %% [markdown]
# 6\. Write a program that implements the function $f(x)=x(x−1)$
#
# (a) Calculate the derivative of the function at the point $x = 1$ using the derivative definition:
#
# $$
# \frac{{\rm d}f}{{\rm d}x} = \lim_{\delta\to0} \frac{f(x+\delta)-f(x)}{\delta}
# $$
#
# with $\delta = 10^{−2}$. Calculate the true value of the same derivative analytically and compare with the answer your program gives. The two will not agree perfectly. Why not?
#
# (b) Repeat the calculation for $\delta = 10^{−4}, 10^{−6}, 10^{−8}, 10^{−10}, 10^{−12}$ and $10^{−14}$. How does the accuracy scales with $\delta$?

# %%
#code ex6

import math

#part a 
x=1

#funxione x(x-1)
def func(x):
    r=x*(x-1)
    return r

#using definition
def derivative(x):
    d=1e-2
    return (func(x+d)-func(x))/d

print("Value of derivative following the definition: ", derivative(x))
print("\n")

#analytically
def derivative_a(x):
    deriv = 2*x-1
    return deriv

print("Value of derivative analytically ", derivative_a(x))
print("\n")

#The two will not agree perfectly. Why not? 
#Because we cannot compute the limite: delta is small but not sufficiently small to give the same result as the analytically one.

#part b

def derivative_prec(x):
    for i in range(2,15,2):
        d=math.pow(10,-i)
        print("Derivative: ", (func(x+d)-func(x))/d," with d: ", d)
derivative_prec(x)

#How does the accuracy scales with delta? Accuracy gets better with the reducing values of delta.
# In my case it get better until delta=1e-8; then it gets worse. Also for delta=1e-16 it even gives 0.0: while dealing with really small numbers we can have problems due to how the numbers are stored in the binary representation.
# Out:
# Value of derivative following the definition:  1.010000000000001
#
#
# Value of derivative analytically  1
#
#
# Derivative:  1.010000000000001  with d:  0.01
# Derivative:  1.0000999999998899  with d:  0.0001
# Derivative:  1.0000009999177333  with d:  1e-06
# Derivative:  1.0000000039225287  with d:  1e-08
# Derivative:  1.000000082840371  with d:  1e-10
# Derivative:  1.0000889005833413  with d:  1e-12
# Derivative:  0.9992007221626509  with d:  1e-14

# %% [markdown]
# 7\. Consider the integral of the semicircle of radius 1:
# $$
# I=\int_{-1}^{1} \sqrt(1-x^2) {\rm d}x
# $$
# which it's known to be $I=\frac{\pi}{2}=1.57079632679...$.
# Alternatively we can use the Riemann definition of the integral:
# $$
# I=\lim_{N\to\infty} \sum_{k=1}^{N} h y_k
# $$
#
# with $h=2/N$ the width of each of the $N$ slices the domain is divided into and where
# $y_k$ is the value of the function at the $k-$th slice.
#
# (a) Write a programe to compute the integral with $N=100$. How does the result compares to the true value?
#
# (b) How much can $N$ be increased if the computation needs to be run in less than a second? What is the gain in running it for 1 minute?

# %%
import math
import time

#part a: write a programe to compute the integral with 𝑁=100.
def integral_a(Na):
    prod_a=[]
    for ka in range(1,Na):
        ha=2/Na
        xa=-1+ha*ka
        yka=math.sqrt(1-xa*xa)
        prod_a.append(ha*yka)
        result_a=sum(prod_a)
    return result_a

    
result = integral_a(100)
print("The result of the integral is: ", result)
print("The integral is equal to: ", (math.pi/2))
compare=((math.pi/2)-result)
print("The difference is: ", compare)
print("\n")

#How does the result compares to the true value? 
#The result is an approximation of the real value. 

#part b
def integral(N):
    prod=[]
    timeout_start = time.time()
    for k in range(1,N):
        h=2/N
        x=-1+h*k
        yk=math.sqrt(1-x*x)
        prod.append(h*yk)
    time_spent = time.time() - timeout_start
    #print("The result of the integral is: ", sum(prod))
    return(time_spent,prod)


timeout = 1 
prod=[]
N=2209000 #increase N if you see the running time is too low
[time_spent,prod] = integral(N)
print(N, time_spent,sum(prod))
while time_spent < timeout:
    N = N+1
    [time_spent,prod] = integral(N)
    print(N, time_spent,sum(prod))
print('We can use max N =',N-1,'to run the computation in less than a second')


#What is the gain in running it for 1 minute? 
#We would obtain a better approximation of the integral:

timeout = 60
prod=[]
N=150000000 #increase N if you see the running time is too low
[time_spent,prod] = integral(N)
print(N, time_spent,sum(prod))
while time_spent < timeout:
    N = N+1
    [time_spent,prod] = integral(N)
    print(N, time_spent,sum(prod))
print('We can use max N =',N-1,'to run the computation in less than a minut')
# Out:
# The result of the integral is:  1.5691342555492505
# The integral is equal to:  1.5707963267948966
# The difference is:  0.0016620712456461018
#
#
# 2209000 0.876044750213623 1.5707963262882259
# 2209001 0.8742282390594482 1.5707963262883653
# 2209002 0.8558883666992188 1.570796326288334
# 2209003 0.8527257442474365 1.5707963262883549
# 2209004 0.8461878299713135 1.5707963262883955
# 2209005 0.8483490943908691 1.5707963262884146
# 2209006 0.850898265838623 1.5707963262884799
# 2209007 0.8504586219787598 1.5707963262883828
# 2209008 0.8465056419372559 1.5707963262883442
# 2209009 0.8568222522735596 1.570796326288394
# 2209010 0.8602406978607178 1.5707963262883267
# 2209011 0.8549911975860596 1.5707963262881985
# 2209012 0.8449652194976807 1.5707963262884421
# 2209013 0.856281042098999 1.570796326288423
# 2209014 0.8614935874938965 1.5707963262884614
# 2209015 0.8606719970703125 1.5707963262883142
# 2209016 0.8529324531555176 1.5707963262884825
# ...
