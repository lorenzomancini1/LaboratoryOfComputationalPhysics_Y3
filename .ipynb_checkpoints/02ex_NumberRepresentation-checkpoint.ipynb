# %% [markdown]
# 1\. Write a function that converts number representation (bin<->dec<->hex)

# %%
print("Che tipo di \x1b[1;34mrappresentazione\x1b[0m vuoi usare per il numero che intendi inserire?")
print("Premi 1 per la \x1b[4;34mbinaria\x1b[0m, 2 per la \x1b[4;34mdecimale\x1b[0m, 3 per la \x1b[4;34mesadecimale\x1b[0m")
x=input()
x=int(x)
print("Inserisci il numero nella rappresentazione scelta:")
number=input()

if(x==1):#ho inserito un intero
    number=int(number)
    print("La sua rappresentazione binaria sarà data da: ",bin(number))
    print("La sua rappresentazione esadecimale sarà data da: ",hex(number))
elif(x==2):#ho inserito un binario
    number=int(number,2)
    print("La sua rappresentazione esadecimale sarà data da: ",hex(number))
    print("La sua rappresentazione decimale sarà data da: ",int(number))
elif(x==3):#ho inserito un esadecimale
    number=int(number,16)
    print("La sua rappresentazione binaria sarà data da: ",bin(number))
    print("La sua rappresentazione decimale sarà data da: ",int(number))   
else:
    print("C'è qulcosa che non va con la scelta della rappresentazione!")

# %% [markdown]
# 2\. Write a function that converts a 32 bit word into a single precision floating point (i.e. interprets the various bits as sign, mantissa and exponent)

# %%
x=input()
number=0.0#sarà il risultato finale
molt=x[0]#lo faccio per il segno
molt=int(molt)#--->converto in intero altrimenti dovrebbe essere stringa
#print(type(molt))
if (molt==0):
    number=(1.0)
else:
    number=-(1.0)

def converter(n):
    num_bin=int(n,2)
    return num_bin
    
esponente=''
for i in range(1,9):
    esponente=esponente+x[i]
#print(esponente)
#print(converter(esponente))--->converter trasforma un decimale in binario
#print(type(converter(esponente)))
def bin2float (b):
       s, f = b.find('.')+1, int(b.replace('.',''), 2)
       return f/2.**(len(b)-s) if s else f
mantissa='0.'
for j in range (9,len(x)):
    mantissa=mantissa+x[j]
#print(mantissa)---->mi serve per la mantissa
#print(bin2float(mantissa))---->bin2float mi converte una frazione in un numero binario
#print(type(bin2float(mantissa)))----> float
number=number*(1+bin2float(mantissa))*(2**(converter(esponente)-127))
print(number)
# Out:
# òufhvè
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-196-2cc56b0d49dc> in <module>
#       2 number=0.0#sarà il risultato finale
#       3 molt=x[0]#lo faccio per il segno
# ----> 4 molt=int(molt)#--->converto in intero altrimenti dovrebbe essere stringa
#       5 #print(type(molt))
#       6 if (molt==0):
#
# ValueError: invalid literal for int() with base 10: 'ò'

# %% [markdown]
# 3\. Write a program to determine the underflow and overflow limits (within a factor of 2) for python on your computer.
#
# **Tips**: define two variables inizialized to 1 and halve/double them enough time to exceed the under/over-flow limits

# %%
N=151#è l'ultima iterazione buona; a 152 va in overflow
n=1
for i in range (1,N):
    n=(2*i)*n
    if(i==N-1):
        
        print("%E" %(n)) # formato esponenziale
print("Fine")
# Out:
# 8.154414E+307
# Fine

# %%
N=157 #è l'ultima iterazione buona; a 158 va in underflow
n=1
for i in range (1,N):
    n=n/(2*i)
    if(i==N-1):
        print("%E" %(n))
        
print("Fine")
# Out:
# 1.482197E-323
# Fine

# %% [markdown]
# 4\. Write a program to determine the machine precision
#
# **Tips**: define a new variable by adding a smaller and smaller value (proceeding similarly to prob. 2) to an original variable and check the point where the two are the same

# %%
N=1080
a=10.0
b=0.0
print("step 0",a,b)

for i in range(1,N):
    diff=(b+a)/2.0
    if(a+diff!=a):
        a=diff
        print("step",i,a,b)
    else:
        b=dif
        print("I due valori sono uguali")
# Out:
# step 0 10.0 0.0
# step 1 5.0 0.0
# step 2 2.5 0.0
# step 3 1.25 0.0
# step 4 0.625 0.0
# step 5 0.3125 0.0
# step 6 0.15625 0.0
# step 7 0.078125 0.0
# step 8 0.0390625 0.0
# step 9 0.01953125 0.0
# step 10 0.009765625 0.0
# step 11 0.0048828125 0.0
# step 12 0.00244140625 0.0
# step 13 0.001220703125 0.0
# step 14 0.0006103515625 0.0
# step 15 0.00030517578125 0.0
# step 16 0.000152587890625 0.0
# step 17 7.62939453125e-05 0.0
# step 18 3.814697265625e-05 0.0
# step 19 1.9073486328125e-05 0.0
# step 20 9.5367431640625e-06 0.0
# step 21 4.76837158203125e-06 0.0
# step 22 2.384185791015625e-06 0.0
# step 23 1.1920928955078125e-06 0.0
# step 24 5.960464477539062e-07 0.0
# step 25 2.980232238769531e-07 0.0
# step 26 1.4901161193847656e-07 0.0
# step 27 7.450580596923828e-08 0.0
# step 28 3.725290298461914e-08 0.0
# step 29 1.862645149230957e-08 0.0
# step 30 9.313225746154785e-09 0.0
# step 31 4.6566128730773926e-09 0.0
# step 32 2.3283064365386963e-09 0.0
# ...

# %% [markdown]
# 5\. Write a function that takes in input three parameters $a$, $b$ and $c$ and prints out the two solutions to the quadratic equation $ax^2+bx+c=0$ using the standard formula:
# $$
# x=\frac{-b\pm\sqrt{b^2-4ac}}{2a}
# $$
#
# (a) use the program to compute the solution for $a=0.001$, $b=1000$ and $c=0.001$
#
# (b) re-express the standard solution formula by multiplying top and bottom by $-b\mp\sqrt{b^2-4ac}$ and again find the solution for $a=0.001$, $b=1000$ and $c=0.001$. How does it compare with what previously obtained? Why?
#
# (c) write a function that compute the roots of a quadratic equation accurately in all cases

# %%
#A e B#########################################################################
print("Inserire i valori dei parametri a,b,c per l'equazione di secondo grado")
a=float(input())
b=float(input())
c=float(input())
print("I valori scelti sono: a=",a, " b=",b," c=",c)

def soluzioni(a,b,c):
    delta=b**2-4*a*c
    x_1=(-b+delta**0.5)/(2*a) 
    x_2=(-b-delta**0.5)/(2*a)
    return print(x_2,x_1)
def soluzioni_new(a,b,c):
    delta=b**2-4*a*c
    x_1=(2*c)/(-b+delta**0.5) 
    x_2=(2*c)/(-b-delta**0.5)
    return print(x_1,x_2)


print("Le soluzioni \x1b[1;30mvecchie\x1b[0m sono: ")
soluzioni(a,b,c)

print("Le soluzioni \x1b[1;30mnuove\x1b[0m sono: ")
soluzioni_new(a,b,c)
# Out:
# Inserire i valori dei parametri a,b,c per l'equazione di secondo grado
# 0.001
# 1000
# 0.001
# I valori scelti sono: a= 0.001  b= 1000.0  c= 0.001
# Le soluzioni vecchie sono:
# -999999.999999 -9.999894245993346e-07
# Le soluzioni nuove sono:
# -1000010.5755125057 -1.000000000001e-06

# %%
#C#########################################################################
print("Inserire i valori dei parametri (a,b,c) per l'equazione di secondo grado")
a=float(input())
b=float(input())
c=float(input())
print("I valori scelti sono: a=",a, " b=",b," c=",c)


def new_method(a,b,c):
    if(a!=0 and b!=0 and c!=0):
        delta=b**2-4*a*c
        x1=(-b+delta**0.5)/(2*a) 
        x2=(-b-delta**0.5)/(2*a)
        if (abs(x1)>abs(x2)):
            x_1=x1
        else:
            x_1=x2
        x_2=-(b/a +x_1)
    elif(a!=0.0 and b!=0.0 and c==0.0):
        x_1=0.0
        x_2=-(b/a)
    elif(a!=0.0 and b==0.0 and c!=0.0):
        x_1=+(-c/a)**0.5
        x_2=-(-c/a)**0.5
    elif(a!=0.0 and b==0.0 and c==0.0):
        x_1=0
        x_2=0
    return print(x_1,x_2)


print(" \x1b[1;30mLe soluzioni sono:\x1b[0m ")
new_method(a,b,c)
# Out:
# Inserire i valori dei parametri a,b,c per l'equazione di secondo grado
# 0.00001
# 10000
# 0.00001
# I valori scelti sono: a= 1e-05  b= 10000.0  c= 1e-05
#  Le soluzioni sono:
# -999999999.9999999 -0.0

# %% [markdown]
# ### 6\. Write a program that implements the function $f(x)=x(x−1)$
#
# (a) Calculate the derivative of the function at the point $x = 1$ using the derivative definition:
#
# $$
# \frac{{\rm d}f}{{\rm d}x} = \lim_{\delta\to0} \frac{f(x+\delta)-f(x)}{\delta}
# $$
#
# with $\delta = 10^{−2}$. Calculate the true value of the same derivative analytically and compare with the answer your program gives. The two will not agree perfectly. Why not?
#
# (b) Repeat the calculation for $\delta = 10^{−4}, 10^{−6}, 10^{−8}, 10^{−10}, 10^{−12}$ and $10^{−14}$. How does the accuracy scales with $\delta$?

# %%
#a),b)#####################################################################
delta=[10**(-2),10**(-4),10**(-6),10**(-8),10**(-10),10**(-12),10**(-14)]
def func(var):
    f=var*(var-1)
    return f
def derivata_a (var):
    f=2*var-1
    return f
der_n=[]
for i in range(0,len(delta)):
    tot=0
    der_n.append((func(1+delta[i])-func(1))/delta[i])
    print("Derivata numerica per delta =",delta[i]," calcolata in x=1:",der_n[i])
    
print("\x1b[1;34m La derivata analitica è invece data da:\x1b[0m",derivata_a(1))
#I valori della derivata analitica (derivata_a) in x=1 e di quella numerica (der_n) nel medesimo punto sono diversi perchè non è possibile implementare il  concetto di limite infinitesimo. 
#Il risultato numerico quindi dipenderà dalla precisione con cui è possibile rappresentare il limite di delta che tende a zero: più è piccolo il delta inserito nell'espressione di riferiemento, più i 2 valori in esame saranno simili.
errore=[]
for i in range(0,len(delta)):
    errore.append((abs(derivata_a(1)-der_n[i])/derivata_a(1))*100)
    print("Errore percentuale per delta=",delta[i],": ",errore[i],"%")
# Out:
# Derivata numerica per delta = 0.01  calcolata in x=1: 1.010000000000001
# Derivata numerica per delta = 0.0001  calcolata in x=1: 1.0000999999998899
# Derivata numerica per delta = 1e-06  calcolata in x=1: 1.0000009999177333
# Derivata numerica per delta = 1e-08  calcolata in x=1: 1.0000000039225287
# Derivata numerica per delta = 1e-10  calcolata in x=1: 1.000000082840371
# Derivata numerica per delta = 1e-12  calcolata in x=1: 1.0000889005833413
# Derivata numerica per delta = 1e-14  calcolata in x=1: 0.9992007221626509
#  La derivata analitica è invece data da: 1
# Errore percentuale per delta= 0.01 :  1.0000000000000897 %
# Errore percentuale per delta= 0.0001 :  0.009999999988985486 %
# Errore percentuale per delta= 1e-06 :  9.99917733279787e-05 %
# Errore percentuale per delta= 1e-08 :  3.9225287462585356e-07 %
# Errore percentuale per delta= 1e-10 :  8.284037100736441e-06 %
# Errore percentuale per delta= 1e-12 :  0.008890058334132256 %
# ...

# %% [markdown]
# 7\. Consider the integral of the semicircle of radius 1:
# $$
# I=\int_{-1}^{1} \sqrt(1-x^2) {\rm d}x
# $$
# which it's known to be $I=\frac{\pi}{2}=1.57079632679...$.
# Alternatively we can use the Riemann definition of the integral:
# $$
# I=\lim_{N\to\infty} \sum_{k=1}^{N} h y_k
# $$
#
# with $h=2/N$ the width of each of the $N$ slices the domain is divided into and where
# $y_k$ is the value of the function at the $k-$th slice.
#
# (a) Write a programe to compute the integral with $N=100$. How does the result compares to the true value?
#
# (b) How much can $N$ be increased if the computation needs to be run in less than a second? What is the gain in running it for 1 minute?

# %%
#a)##########################################
import math as m
I=m.pi/2
a=float(input())
b=float(input())
N=100
passo=(b-a)/N
def funzione(x):
    func=(1-x**2)**0.5
    return func
somma=0
for i in range(0,N):
    somma=somma+(passo)*(funzione(a+i*passo))

print("Integrale numerico:",somma)
print("Integrale analitico (in [-1;1]):",I)
err=(abs(I-somma)/I)*100
print("Errore percentuale del",err,"%")
# Out:
# -1
# 1
# Integrale numerico: 1.5691342555492505
# Integrale analitico (in [-1;1]): 1.5707963267948966
# Errore percentuale del 0.10581074180619238 %

# %%
#b)################################################################
import time
start_time = time.time()


import math as m
I=m.pi/2
print("Esecuzione in circa 1 minuto")
a=-1.0
b=1.0
N=90000000
passo=(b-a)/N

def funzione(x):
    func=(1-x**2)**0.5
    return func

somma=0
for i in range(0,N):
    somma=somma+(passo)*(funzione(a+i*passo))

print("Integrale numerico:",somma)
print("Integrale analitico:",I)
err=(abs(I-somma)/I)*100
print("Errore percentuale del",err,"%")
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Esecuzione in circa 1 minuto
# Integrale numerico: 1.5707963267922795
# Integrale analitico: 1.5707963267948966
# Errore percentuale del 1.6660452211435117e-10 %
# --- 63.83237290382385 seconds ---

# %%
#b)################################################################
import time
start_time = time.time()


import math as m
I=m.pi/2
print("Esecuzione: circa 1 secondo")
a=-1.0
b=1.0
N=1500000
passo=(b-a)/N

def funzione(x):
    func=(1-x**2)**0.5
    return func

somma=0
for i in range(0,N):
    somma=somma+(passo)*(funzione(a+i*passo))

print("Integrale numerico:",somma)
print("Integrale analitico:",I)
err=(abs(I-somma)/I)*100
print("Errore percentuale del",err,"%")
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Esecuzione: meno di 1 secondo
# Integrale numerico: 1.5707963258896733
# Integrale analitico: 1.5707963267948966
# Errore percentuale del 5.762830064385445e-08 %
# --- 1.0379712581634521 seconds ---
