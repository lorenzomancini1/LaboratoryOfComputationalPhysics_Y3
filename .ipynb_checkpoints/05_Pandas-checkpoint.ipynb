# %% [markdown]
# # Pandas
#
# The `numpy` module is excellent for numerical computations, but to handle missing data or arrays with mixed types takes more work. The `pandas` module is currently the most widely used tool for data manipulation, providing high-performance, easy-to-use data structures and advanced data analysis tools.
#
# In particular `pandas` features:
#
# * A fast and efficient "DataFrame" object for data manipulation with integrated fancy indexing;
# * Tools for reading and writing data between in-memory data structures and different formats (CSV, Excel, SQL, HDF5);
# * Intelligent data alignment (columns/features) and integrated handling of missing data;
# * Intelligent label-based slicing, fancy indexing, and subsetting of large data sets;
# * Aggregating or transforming data with a powerful "group-by" engine;
# * High performance merging and joining of data sets;
# * Hierarchical axis indexing provides an intuitive way of working with high-dimensional data in a lower-dimensional data structure;
# * Time series-functionalities;
# * Highly optimized for performance, with critical code paths written in Cython or C.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Series
#
# Series are completely equivalent to 1D array but with axis labels and the possibility to store heterogeneous elements. Of paramount importance are the time-series, used to define time evolutions of a phenomenon.

# %%
from string import ascii_lowercase as letters

# Creating a series, accessing indexes, values and values by their index 
xs = pd.Series(np.arange(10)*0.5, index=tuple(letters[:10]))
print ("xs:", xs,'\n')
print ("xs indexes:",xs.index,'\n')
# Values of the Series are actually a numpy array
print ("xs values:", xs.values, type(xs.values),'\n')
print (xs['f'], xs.f, xs.h, '\n') #.label is dangerous
print (xs[['d', 'f', 'h']], '\n')
print (type(xs[['d', 'f', 'h']]), '\n')
# Out:
# xs: a    0.0
# b    0.5
# c    1.0
# d    1.5
# e    2.0
# f    2.5
# g    3.0
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# xs indexes: Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'], dtype='object')
#
# xs values: [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5] <class 'numpy.ndarray'>
#
# 2.5 2.5 3.5
#
# d    1.5
# f    2.5
# h    3.5
# dtype: float64
#
# <class 'pandas.core.series.Series'>

# %%
# Extracting elements and operations: same as numpy array
print (xs[:3],'\n')
print (xs[7:], '\n')
print (xs[::3], '\n')
print (xs[xs>3], '\n') #filtering: all elements greater than 3
print (np.exp(xs), '\n') #operations on the series
print (np.mean(xs), np.std(xs), '\n')
# Out:
# a    0.0
# b    0.5
# c    1.0
# dtype: float64
#
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# a    0.0
# d    1.5
# g    3.0
# j    4.5
# dtype: float64
#
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# a     1.000000
# b     1.648721
# c     2.718282
# d     4.481689
# e     7.389056
# f    12.182494
# g    20.085537
# h    33.115452
# i    54.598150
# j    90.017131
# dtype: float64
#
# 2.25 1.4361406616345072

# %%
# Series can be created from python dictionary too.
# Note that the elements can be whatever!
d = {'b' : 1, 'a' : 'cat', 'c' : [2,3]}
pd.Series(d)
# Out:
# b         1
# a       cat
# c    [2, 3]
# dtype: object

# %% [markdown]
# A key difference between Series and ndarray is that operations between Series automatically align the data based on label. Thus, you can write computations without considering whether the Series involved have the same labels.

# %%
s = pd.Series(np.random.randn(5), index=tuple(letters[:5]))
print(s)
s = s[1:] + s[:-1]
print(s)
# Out:
# a   -0.946391
# b   -1.452746
# c   -0.882946
# d    0.382240
# e    0.698257
# dtype: float64
# a         NaN
# b   -2.905492
# c   -1.765892
# d    0.764479
# e         NaN
# dtype: float64

# %% [markdown]
# ### Time series
#
# Time series are very often used to profile the behaviour of a quantity as a function of time. Pandas as a special index for that, `DatetimeIndex`, that can be created e.g. with the function `pd.data_range()`

# %%
# to define a date, the datetime module is very useful
import datetime as dt
date = dt.date.today()
print(date)

date = dt.datetime(2020,11,9,14,45,10,15)
print (date)

# otherwise, several notations are interpreted too
date = 'Nov 9 2020'
# or alternatively
date = '9/11/2020 14:45:00'
print (date)

days = pd.date_range(date, periods=7, freq='D')
print (days)

seconds = pd.date_range(date, periods=3600, freq='s')
print (seconds)
# Out:
# 2020-11-10
# 2020-11-09 14:45:10.000015
# 9/11/2020 14:45:00
# DatetimeIndex(['2020-09-11 14:45:00', '2020-09-12 14:45:00',
#                '2020-09-13 14:45:00', '2020-09-14 14:45:00',
#                '2020-09-15 14:45:00', '2020-09-16 14:45:00',
#                '2020-09-17 14:45:00'],
#               dtype='datetime64[ns]', freq='D')
# DatetimeIndex(['2020-09-11 14:45:00', '2020-09-11 14:45:01',
#                '2020-09-11 14:45:02', '2020-09-11 14:45:03',
#                '2020-09-11 14:45:04', '2020-09-11 14:45:05',
#                '2020-09-11 14:45:06', '2020-09-11 14:45:07',
#                '2020-09-11 14:45:08', '2020-09-11 14:45:09',
#                ...
#                '2020-09-11 15:44:50', '2020-09-11 15:44:51',
#                '2020-09-11 15:44:52', '2020-09-11 15:44:53',
#                '2020-09-11 15:44:54', '2020-09-11 15:44:55',
#                '2020-09-11 15:44:56', '2020-09-11 15:44:57',
#                '2020-09-11 15:44:58', '2020-09-11 15:44:59'],
#               dtype='datetime64[ns]', length=3600, freq='S')

# %% [markdown]
# To learn more about the frequency strings, please see this [link](http://pandas.pydata.org/pandas-docs/stable/timeseries.html#offset-aliases)
#
#
# Timestamped data is the most basic type of time series data that associates values with points in time. For pandas objects it means using the points in time.
#
# functions like `pd.to_datetime` can be used, for instance, when reading information as string from a dataset

# %%
tstamp = pd.Timestamp(dt.datetime(2020, 11, 9))

# internally it counts the nanoseconds from January 1st 19
#tstamp = pd.Timestamp(dt.datetime(1970, 1, 1, 0, 0, 0, 1))
print(tstamp.value)

# when creating a timestamp the format can be explicitly passed
ts = pd.to_datetime('2010/11/12', format='%Y/%m/%d')
print (type(ts))
print (ts)
ts = pd.to_datetime('12-11-2010 00:00', format='%d-%m-%Y %H:%M')
print (ts)
print (ts.value)
# Out:
# 1604880000000000000
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 2010-11-12 00:00:00
# 2010-11-12 00:00:00
# 1289520000000000000

# %% [markdown]
# A standard series can be created and (range of) elements can be used as indexes

# %%
tseries = pd.Series(np.random.normal(10, 1, len(days)), index=days)
# Extracting elements
print (tseries[0:4], '\n')
print (tseries['2020-11-9':'2020-11-11'], '\n') # Note - includes end time
# Out:
# 2020-09-11 14:45:00     9.130102
# 2020-09-12 14:45:00     8.840760
# 2020-09-13 14:45:00    10.920900
# 2020-09-14 14:45:00    10.862215
# Freq: D, dtype: float64
#
# Series([], Freq: D, dtype: float64)

# %% [markdown]
# `pd.to_datetime` can also be used to create a `DatetimeIndex`:

# %%
pd.to_datetime([1, 2, 3, 4], unit='D', origin=pd.Timestamp('1980-02-03'))
# Out:
# DatetimeIndex(['1980-02-04', '1980-02-05', '1980-02-06', '1980-02-07'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## DataFrame
#
# A pandas DataFrame is like a simple tabular spreadsheet. For future reference (or for people already familiar with R), a pandas DataFrame is very similar to the R DataFrame.
#
# Each column in a DataFrame is a Series object.
#
# The element can be whatever, missing data are dealt with too (as NaN)

# %% [markdown]
# ### DataFrame creation
#
# A DataFrame can be created implicitly, with, e.g., a DatatimeIndex object as index:

# %%
entries=10
dates=pd.date_range('11/9/2020 14:45:00',freq='h', periods=entries)
df = pd.DataFrame(np.random.randn(entries,4), index=dates, columns=['A','B','C','D'])
df
# Out:
#                             A         B         C         D
# 2020-11-09 14:45:00  0.598950  0.477331  0.796574  0.294155
# 2020-11-09 15:45:00 -1.235677 -0.776562 -0.726172 -0.807424
# 2020-11-09 16:45:00  0.852892  1.788828  0.857977 -0.023116
# 2020-11-09 17:45:00  0.920533  0.474999 -0.428176  0.321120
# 2020-11-09 18:45:00  1.908192  0.806297  1.212264 -0.119860
# 2020-11-09 19:45:00  0.571979 -0.605670  0.502277 -0.625289
# 2020-11-09 20:45:00 -0.269350  0.008578  1.020407  0.570718
# 2020-11-09 21:45:00  0.349574  1.643100  0.188519 -0.632292
# 2020-11-09 22:45:00 -1.281709  0.247841  0.087081  0.395196
# 2020-11-09 23:45:00  0.754881  1.621767 -0.271431  1.457069

# %% [markdown]
# or by means of a dictionary:

# %%
df2 = pd.DataFrame(
    { 'A' : 1.,
      'B' : pd.Timestamp('20130102'),
      'C' : pd.Series(1,index=range(4),dtype='float32'),
      'D' : np.arange(7,11),
      'E' : pd.Categorical(["test","train","test","train"]),
    }
    )
df2
# Out:
#      A          B    C   D      E
# 0  1.0 2013-01-02  1.0   7   test
# 1  1.0 2013-01-02  1.0   8  train
# 2  1.0 2013-01-02  1.0   9   test
# 3  1.0 2013-01-02  1.0  10  train

# %% [markdown]
# ### Viewing Data

# %%
df.head(2)
# Out:
#                             A         B         C         D
# 2020-11-09 14:45:00  0.388729  1.022583  0.389729  1.064360
# 2020-11-09 15:45:00  1.244399  1.117695  0.617095  0.881693

# %%
df.tail(4)
# Out:
#                             A         B         C         D
# 2020-11-09 20:45:00  0.743729  0.003440 -0.308891 -1.024886
# 2020-11-09 21:45:00 -0.750234  0.138953 -0.162734  1.680688
# 2020-11-09 22:45:00 -1.528067 -0.767727  1.156013 -1.399533
# 2020-11-09 23:45:00  1.486889  0.475685 -0.521606 -0.362895

# %%
df.index
# Out:
# DatetimeIndex(['2020-11-09 14:45:00', '2020-11-09 15:45:00',
#                '2020-11-09 16:45:00', '2020-11-09 17:45:00',
#                '2020-11-09 18:45:00', '2020-11-09 19:45:00',
#                '2020-11-09 20:45:00', '2020-11-09 21:45:00',
#                '2020-11-09 22:45:00', '2020-11-09 23:45:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 0.38872911,  1.02258298,  0.38972948,  1.06436021],
#        [ 1.24439851,  1.11769508,  0.61709523,  0.88169328],
#        [ 0.50152998,  0.41498847,  1.05374239,  2.39511764],
#        [ 0.9769984 , -0.59636826, -1.84824634,  3.38927444],
#        [ 1.40296462,  0.42045808, -0.34304586,  0.63584242],
#        [ 0.60788953,  0.90967956,  1.52492598, -0.34220322],
#        [ 0.74372934,  0.00344038, -0.30889051, -1.02488602],
#        [-0.75023378,  0.13895306, -0.16273398,  1.68068823],
#        [-1.52806726, -0.76772696,  1.15601349, -1.39953291],
#        [ 1.48688928,  0.47568456, -0.52160623, -0.36289545]])

# %%
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean    0
# 2020-11-09 19:45:00    0.571979
# 2020-11-09 20:45:00   -0.269350
# 2020-11-09 21:45:00    0.349574
# 2020-11-09 22:45:00   -1.281709
# 2020-11-09 23:45:00    0.754881
# Freq: H, Name: A, dtype: float64
#
# 2020-11-09 14:45:00    0.598950
# 2020-11-09 15:45:00   -1.235677
# 2020-11-09 16:45:00    0.852892
# 2020-11-09 17:45:00    0.920533
# 2020-11-09 18:45:00    1.908192
# 2020-11-09 19:45:00    0.571979
# 2020-11-09 20:45:00   -0.269350
# 2020-11-09 21:45:00    0.349574
# 2020-11-09 22:45:00   -1.281709
# 2020-11-09 23:45:00    0.754881
# Freq: H, Name: A, dtype: float64

# %%
# selecting rows by counting
print (df[0:3])

# or by index
print (df["2020-11-09 14:45:00":"2020-11-09 16:45:00"])
# Out:
#                             A         B         C         D
# 2020-11-09 14:45:00  0.598950  0.477331  0.796574  0.294155
# 2020-11-09 15:45:00 -1.235677 -0.776562 -0.726172 -0.807424
# 2020-11-09 16:45:00  0.852892  1.788828  0.857977 -0.023116
#                             A         B         C         D
# 2020-11-09 14:45:00  0.598950  0.477331  0.796574  0.294155
# 2020-11-09 15:45:00 -1.235677 -0.776562 -0.726172 -0.807424
# 2020-11-09 16:45:00  0.852892  1.788828  0.857977 -0.023116

# %% [markdown]
# ### Selection by label

# %%
# getting a cross section (part of the DataFrame) using a label
df.loc[dates[0]] #dates[0] is the first index
# Out:
# A    0.598950
# B    0.477331
# C    0.796574
# D    0.294155
# Name: 2020-11-09 14:45:00, dtype: float64

# %%
# selecting on a multi-axis by label:
df.loc[:,['A','B']]
# Out:
#                             A         B
# 2020-11-09 14:45:00  0.598950  0.477331
# 2020-11-09 15:45:00 -1.235677 -0.776562
# 2020-11-09 16:45:00  0.852892  1.788828
# 2020-11-09 17:45:00  0.920533  0.474999
# 2020-11-09 18:45:00  1.908192  0.806297
# 2020-11-09 19:45:00  0.571979 -0.605670
# 2020-11-09 20:45:00 -0.269350  0.008578
# 2020-11-09 21:45:00  0.349574  1.643100
# 2020-11-09 22:45:00 -1.281709  0.247841
# 2020-11-09 23:45:00  0.754881  1.621767

# %%
# showing label slicing, both endpoints are included:
df.loc['2020-11-09 18:45:00':'2020-11-09 20:45:00',['A','B']]
# Out:
#                             A         B
# 2020-11-09 18:45:00  1.908192  0.806297
# 2020-11-09 19:45:00  0.571979 -0.605670
# 2020-11-09 20:45:00 -0.269350  0.008578

# %%
# getting an individual element
print (df.loc[dates[1],'A'])

# equivalently
print (df.at[dates[1],'A'])
# Out:
# -1.2356770364042247
# -1.2356770364042247

# %% [markdown]
# ### Selecting by position

# %%
# select via the position of the passed integers:
print (df.iloc[3],'\n')

# notation similar to numpy/python
print (df.iloc[3:5,0:2])
# Out:
# A    0.920533
# B    0.474999
# C   -0.428176
# D    0.321120
# Name: 2020-11-09 17:45:00, dtype: float64
#
#                             A         B
# 2020-11-09 17:45:00  0.920533  0.474999
# 2020-11-09 18:45:00  1.908192  0.806297

# %%
# selecting raws 1,2 and 4 for columns 0 and 2
df.iloc[[1,2,4],[0,2]]
# Out:
#                             A         C
# 2020-11-09 15:45:00 -1.235677 -0.726172
# 2020-11-09 16:45:00  0.852892  0.857977
# 2020-11-09 18:45:00  1.908192  1.212264

# %%
# slicing rows explicitly
print (df.iloc[1:3,:],'\n')

# slicing columns explicitly
print (df.iloc[:,1:3])
# Out:
#                             A         B         C         D
# 2020-11-09 15:45:00 -1.235677 -0.776562 -0.726172 -0.807424
# 2020-11-09 16:45:00  0.852892  1.788828  0.857977 -0.023116
#
#                             B         C
# 2020-11-09 14:45:00  0.477331  0.796574
# 2020-11-09 15:45:00 -0.776562 -0.726172
# 2020-11-09 16:45:00  1.788828  0.857977
# 2020-11-09 17:45:00  0.474999 -0.428176
# 2020-11-09 18:45:00  0.806297  1.212264
# 2020-11-09 19:45:00 -0.605670  0.502277
# 2020-11-09 20:45:00  0.008578  1.020407
# 2020-11-09 21:45:00  1.643100  0.188519
# 2020-11-09 22:45:00  0.247841  0.087081
# 2020-11-09 23:45:00  1.621767 -0.271431

# %%
# selecting an individual element by position
df.iloc[1,1]
df.iat[1,1]
# Out:
# -0.7765624769305669

# %% [markdown]
# N.B. loc returns a copy! So original dataframe is not affected when using these.
# iloc returns instead a view -> be careful!

# %% [markdown]
# ### Boolean index
#
# Very powerful way of filtering out data with certain features. Notation is very similar to numpy arrays.

# %%
# Filter by a boolean condition on the values of a single column
df[df['B'] > 0]
# Out:
#                             A         B         C         D
# 2020-11-09 14:45:00  0.598950  0.477331  0.796574  0.294155
# 2020-11-09 16:45:00  0.852892  1.788828  0.857977 -0.023116
# 2020-11-09 17:45:00  0.920533  0.474999 -0.428176  0.321120
# 2020-11-09 18:45:00  1.908192  0.806297  1.212264 -0.119860
# 2020-11-09 20:45:00 -0.269350  0.008578  1.020407  0.570718
# 2020-11-09 21:45:00  0.349574  1.643100  0.188519 -0.632292
# 2020-11-09 22:45:00 -1.281709  0.247841  0.087081  0.395196
# 2020-11-09 23:45:00  0.754881  1.621767 -0.271431  1.457069

# %%
# Selecting on the basis of boolean conditions applied to the whole DataFrame
df[df>0]

# a DataFrame with the same shape is returned, with NaN's where condition is not met
# Out:
#                             A         B         C         D
# 2020-11-09 14:45:00  0.598950  0.477331  0.796574  0.294155
# 2020-11-09 15:45:00       NaN       NaN       NaN       NaN
# 2020-11-09 16:45:00  0.852892  1.788828  0.857977       NaN
# 2020-11-09 17:45:00  0.920533  0.474999       NaN  0.321120
# 2020-11-09 18:45:00  1.908192  0.806297  1.212264       NaN
# 2020-11-09 19:45:00  0.571979       NaN  0.502277       NaN
# 2020-11-09 20:45:00       NaN  0.008578  1.020407  0.570718
# 2020-11-09 21:45:00  0.349574  1.643100  0.188519       NaN
# 2020-11-09 22:45:00       NaN  0.247841  0.087081  0.395196
# 2020-11-09 23:45:00  0.754881  1.621767       NaN  1.457069

# %% [markdown]
# ### Setting
#
# Combination of selection and setting of values

# %%
# setting values by label (same as by position)
df.at[dates[0],'A'] = 0

# setting and assigning a numpy array
df.loc[:,'D'] = np.array([5] * len(df))

# defining a brend new column
df['E'] = np.arange(len(df))*0.5

# defining a brend new column by means of a pd.Series: indexes must be the same!
df['E prime'] = pd.Series(np.arange(len(df))*2, index=df.index)

# %%
def dcos(theta):
    theta = theta*(np.pi/180)
    return np.cos(theta)
 #apply operations columnwise: no loops -> much faster
df['cosine'] = pd.Series(df["E"].apply(dcos), index=df.index)
df
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2020-11-09 14:45:00  0.000000  0.477331  0.796574  5  0.0        0  1.000000
# 2020-11-09 15:45:00 -1.235677 -0.776562 -0.726172  5  0.5        2  0.999962
# 2020-11-09 16:45:00  0.852892  1.788828  0.857977  5  1.0        4  0.999848
# 2020-11-09 17:45:00  0.920533  0.474999 -0.428176  5  1.5        6  0.999657
# 2020-11-09 18:45:00  1.908192  0.806297  1.212264  5  2.0        8  0.999391
# 2020-11-09 19:45:00  0.571979 -0.605670  0.502277  5  2.5       10  0.999048
# 2020-11-09 20:45:00 -0.269350  0.008578  1.020407  5  3.0       12  0.998630
# 2020-11-09 21:45:00  0.349574  1.643100  0.188519  5  3.5       14  0.998135
# 2020-11-09 22:45:00 -1.281709  0.247841  0.087081  5  4.0       16  0.997564
# 2020-11-09 23:45:00  0.754881  1.621767 -0.271431  5  4.5       18  0.996917

# %%
# another example of global setting
df2=df.copy()
df2[df2>0] = -df2
df2
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2020-11-09 14:45:00  0.000000 -0.477331 -0.796574 -5  0.0        0 -1.000000
# 2020-11-09 15:45:00 -1.235677 -0.776562 -0.726172 -5 -0.5       -2 -0.999962
# 2020-11-09 16:45:00 -0.852892 -1.788828 -0.857977 -5 -1.0       -4 -0.999848
# 2020-11-09 17:45:00 -0.920533 -0.474999 -0.428176 -5 -1.5       -6 -0.999657
# 2020-11-09 18:45:00 -1.908192 -0.806297 -1.212264 -5 -2.0       -8 -0.999391
# 2020-11-09 19:45:00 -0.571979 -0.605670 -0.502277 -5 -2.5      -10 -0.999048
# 2020-11-09 20:45:00 -0.269350 -0.008578 -1.020407 -5 -3.0      -12 -0.998630
# 2020-11-09 21:45:00 -0.349574 -1.643100 -0.188519 -5 -3.5      -14 -0.998135
# 2020-11-09 22:45:00 -1.281709 -0.247841 -0.087081 -5 -4.0      -16 -0.997564
# 2020-11-09 23:45:00 -0.754881 -1.621767 -0.271431 -5 -4.5      -18 -0.996917

# %% [markdown]
# ### Dropping
#
# N.B.: dropping doesn't act permanently on the DataFrame, i.e. to get that do :
# ```python
# df = df.drop(....)
# ```

# %%
# Dropping by column
df.drop(['E prime'], axis=1) #this is a COPY, as every drop

#which is equivalent to
df.drop(columns=['E prime'])
# Out:
#                             A         B         C  D    E    cosine
# 2020-11-09 14:45:00  0.000000  0.477331  0.796574  5  0.0  1.000000
# 2020-11-09 15:45:00 -1.235677 -0.776562 -0.726172  5  0.5  0.999962
# 2020-11-09 16:45:00  0.852892  1.788828  0.857977  5  1.0  0.999848
# 2020-11-09 17:45:00  0.920533  0.474999 -0.428176  5  1.5  0.999657
# 2020-11-09 18:45:00  1.908192  0.806297  1.212264  5  2.0  0.999391
# 2020-11-09 19:45:00  0.571979 -0.605670  0.502277  5  2.5  0.999048
# 2020-11-09 20:45:00 -0.269350  0.008578  1.020407  5  3.0  0.998630
# 2020-11-09 21:45:00  0.349574  1.643100  0.188519  5  3.5  0.998135
# 2020-11-09 22:45:00 -1.281709  0.247841  0.087081  5  4.0  0.997564
# 2020-11-09 23:45:00  0.754881  1.621767 -0.271431  5  4.5  0.996917

# %%
# Dropping by raws
# safe and always working
df.drop(df.index[[1,2,3,4]])
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2020-11-09 14:45:
# 2020-11-09 22:45:00    3.578682
# 2020-11-09 23:45:00    4.371734
# Freq: H, dtype: float64

# %%
# global operations on columns
df.apply(np.cumsum)
# Out:
#                             A         B         C   D     E  E prime    cosine
# 2020-11-09 14:45:00  0.000000  0.477331  0.796574   5   0.0        0  1.000000
# 2020-11-09 15:45:00 -1.235677 -0.299231  0.070402  10   0.5        2  1.999962
# 2020-11-09 16:45:00 -0.382785  1.489596  0.928380  15   1.5        6  2.999810
# 2020-11-09 17:45:00  0.537748  1.964596  0.500203  20   3.0       12  3.999467
# 2020-11-09 18:45:00  2.445940  2.770893  1.712468  25   5.0       20  4.998858
# 2020-11-09 19:45:00  3.017920  2.165222  2.214745  30   7.5       30  5.997906
# 2020-11-09 20:45:00  2.748570  2.173801  3.235152  35  10.5       42  6.996536
# 2020-11-09 21:45:00  3.098143  3.816901  3.423671  40  14.0       56  7.994670
# 2020-11-09 22:45:00  1.816434  4.064741  3.510752  45  18.0       72  8.992234
# 2020-11-09 23:45:00  2.571315  5.686508  3.239322  50  22.5       90  9.989152

# %%
df
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2020-11-09 14:45:00  0.000000  0.477331  0.796574  5  0.0        0  1.000000
# 2020-11-09 15:45:00 -1.235677 -0.776562 -0.726172  5  0.5        2  0.999962
# 2020-11-09 16:45:00  0.852892  1.788828  0.857977  5  1.0        4  0.999848
# 2020-11-09 17:45:00  0.920533  0.474999 -0.428176  5  1.5        6  0.999657
# 2020-11-09 18:45:00  1.908192  0.806297  1.212264  5  2.0        8  0.999391
# 2020-11-09 19:45:00  0.571979 -0.605670  0.502277  5  2.5       10  0.999048
# 2020-11-09 20:45:00 -0.269350  0.008578  1.020407  5  3.0       12  0.998630
# 2020-11-09 21:45:00  0.349574  1.643100  0.188519  5  3.5       14  0.998135
# 2020-11-09 22:45:00 -1.281709  0.247841  0.087081  5  4.0       16  0.997564
# 2020-11-09 23:45:00  0.754881  1.621767 -0.271431  5  4.5       18  0.996917

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A           3.189901
# B           2.565390
# C           1.938436
# D           0.000000
# E           4.500000
# E prime    18.000000
# cosine      0.003083
# dtype: float64

# %%
# syntax is as usual similar to that of numpy arrays
df['A']+df['B']
# Out:
# 2020-11-09 14:45:00    0.477331
# 2020-11-09 15:45:00   -2.012240
# 2020-11-09 16:45:00    2.641719
# 2020-11-09 17:45:00    1.395533
# 2020-11-09 18:45:00    2.714489
# 2020-11-09 19:45:00   -0.033691
# 2020-11-09 20:45:00   -0.260772
# 2020-11-09 21:45:00    1.992674
# 2020-11-09 22:45:00   -1.033869
# 2020-11-09 23:45:00    2.376648
# Freq: H, dtype: float64

# %% [markdown]
# Let's play it hard and load (in memory) a (relatively) large dataset

# %%
# WARNING! link in past notebook was wrong!, (if needed) get the right file from:
#!wget https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt -P ~/data/

file_name="~/data/data_000637.txt"
data=pd.read_csv(file_name)
data
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 0           1     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1310715     1     0           62  3869211171         762        14
# 1310716     1     1            4  3869211171         763        11
# 1310717     1     0           64  3869211171         764         0
# 1310718     1     0          139  3869211171         769         0
# 1310719     1     0           61  3869211171         762        18
#
# [1310720 rows x 6 columns]

# %% [markdown]
# Let's now do some operations among (elements of) columns

# %%
# the one-liner killing it all
data['timens']=data['TDC_MEAS']*25/30+data['BX_COUNTER']*25

# %%
# the old slooow way
def conversion(data):
    result=[]
    for i in range(len(data)): 
        result.append(data.loc[data.index[i],'TDC_MEAS']*25/30.+data.loc[data.index[i],'BX_COUNTER']*25)
    return result

data['timens']=conversion(data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-c068bba4df3b> in <module>
#       6     return result
#       7
# ----> 8 data['timens']=conversion(data)
#
# <ipython-input-56-c068bba4df3b> in conversion(data)
#       3     result=[]
#       4     for i in range(len(data)):
# ----> 5         result.append(data.loc[data.index[i],'TDC_MEAS']*25/30.+data.loc[data.index[i],'BX_COUNTER']*25)
#       6     return result
#       7
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/range.py in __getitem__(self, key)
#     668             return self._simple_new(new_range, name=self.name)
#     669         elif is_integer(key):
# --> 670             new_key = int(key)
#     671             try:
#     672                 return self._range[new_key]
#
# KeyboardInterrupt:

# %% [markdown]
# ## Merge
#
# pandas provides various facilities for easily combining together Series, DataFrame, and Panel objects with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.
#
# ### Concat
#
# concatenation (adding rows) is straightforward

# %%
rdf = pd.DataFrame(np.random.randn(10, 4))
rdf
# Out:
#           0         1         2         3
# 0  0.274461  0.262041  1.221856 -0.035735
# 1 -0.519006  0.553547 -0.624220 -0.384831
# 2 -1.420242  0.332850  0.353048 -1.077549
# 3 -0.352516 -0.229573 -1.324538 -1.394095
# 4 -0.822434  0.583142 -1.396445  0.565178
# 5  0.400569  0.176030 -0.753956 -0.713647
# 6 -0.555158 -0.953278 -1.323677  0.657601
# 7  0.333920  0.789598  0.105364 -0.356546
# 8 -0.123841  1.949921  0.408683 -0.349889
# 9  1.014386  0.418823  0.228393 -0.597090

# %%
# divide it into pieaces raw-wise
pieces = [rdf[:3], rdf[3:7], rdf[7:]]
pieces
# Out:
# [          0         1         2         3
#  0  0.274461  0.262041  1.221856 -0.035735
#  1 -0.519006  0.553547 -0.624220 -0.384831
#  2 -1.420242  0.332850  0.353048 -1.077549,
#            0         1         2         3
#  3 -0.352516 -0.229573 -1.324538 -1.394095
#  4 -0.822434  0.583142 -1.396445  0.565178
#  5  0.400569  0.176030 -0.753956 -0.713647
#  6 -0.555158 -0.953278 -1.323677  0.657601,
#            0         1         2         3
#  7  0.333920  0.789598  0.105364 -0.356546
#  8 -0.123841  1.949921  0.408683 -0.349889
#  9  1.014386  0.418823  0.228393 -0.597090]

# %%
# put it back together
#pd.concat(pieces)

# indexes can be ignored
pd.concat(pieces, ignore_index=True)

# in case of dimension mismatch, Nan are added where needed
# Out:
#           0         1         2         3
# 0  0.274461  0.262041  1.221856 -0.035735
# 1 -0.519006  0.553547 -0.624220 -0.384831
# 2 -1.420242  0.332850  0.353048 -1.077549
# 3 -0.352516 -0.229573 -1.324538 -1.394095
# 4 -0.822434  0.583142 -1.396445  0.565178
# 5  0.400569  0.176030 -0.753956 -0.713647
# 6 -0.555158 -0.953278 -1.323677  0.657601
# 7  0.333920  0.789598  0.105364 -0.356546
# 8 -0.123841  1.949921  0.408683 -0.349889
# 9  1.014386  0.418823  0.228393 -0.597090

# %%
# appending a single row (as a Series)
s = rdf.iloc[3]
rdf.append(s, ignore_index=True)
rdf
# Out:
#           0         1         2         3
# 0  0.274461  0.262041  1.221856 -0.035735
# 1 -0.519006  0.553547 -0.624220 -0.384831
# 2 -1.420242  0.332850  0.353048 -1.077549
# 3 -0.352516 -0.229573 -1.324538 -1.394095
# 4 -0.822434  0.583142 -1.396445  0.565178
# 5  0.400569  0.176030 -0.753956 -0.713647
# 6 -0.555158 -0.953278 -1.323677  0.657601
# 7  0.333920  0.789598  0.105364 -0.356546
# 8 -0.123841  1.949921  0.408683 -0.349889
# 9  1.014386  0.418823  0.228393 -0.597090

# %% [markdown]
# ### Merge/Join
#
# SQL like operations on table can be performed on DataFrames. This is all rather sophisticated, refer to the [doc](https://pandas.pydata.org/pandas-docs/stable/merging.html#merging) for more info/examples

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})

pd.merge(left,right,on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
# ## Grouping
#
# By “group by” we are referring to a process involving one or more of the following steps:
#
# * Splitting the data into groups based on some criteria
# * Applying a function to each group independently
# * Combining the results into a data structure

# %%
gdf = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
                          'foo', 'bar', 'foo', 'foo'],
                    'B' : ['one', 'one', 'two', 'three',
                           'two', 'two', 'one', 'three'],
                    'C' : np.random.randn(8),
                    'D' : np.random.randn(8)})
gdf
# Out:
#      A      B         C         D
# 0  foo    one  0.845111  1.291345
# 1  bar    one  0.528016  1.459961
# 2  foo    two  1.203654 -0.642613
# 3  bar  three  0.688847 -0.942439
# 4  foo    two -1.009446  0.790151
# 5  bar    two -0.088920  0.659474
# 6  foo    one  1.780871 -0.533151
# 7  foo  three  0.580354 -0.602018

# %%
# Grouping and then applying the sum() 
# function to the resulting groups (effective only where number are there).
gdf.groupby('A').sum()
# Out:
#             C         D
# A
# bar  1.127943  1.176997
# foo  3.400543  0.303714

# %% [markdown]
# ## Multi-indexing
#
#
# Hierarchical / Multi-level indexing allows sophisticated data analysis on higher dimensional data. In essence, it enables you to store and manipulate data with an arbitrary number of dimensions in lower dimensional data structures like Series (1d) and DataFrame (2d).

# %%
tuples = list(zip(['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'],
          ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']))
multi_index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
print (multi_index,'\n')

s = pd.Series(np.random.randn(8), index=multi_index)
print (s)
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])
#
# first  second
# bar    one       1.055613
#        two      -0.334154
# baz    one      -1.447152
#        two      -0.654304
# foo    one       1.349186
#        two      -1.162860
# qux    one       0.504211
#        two       0.669158
# dtype: float64

# %%
# it enables further features of the groupby method,
# e.g. when group-by by multiple columns
gdf.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    0.528016  1.459961
#     three  0.688847 -0.942439
#     two   -0.088920  0.659474
# foo one    2.625982  0.758195
#     three  0.580354 -0.602018
#     two    0.194207  0.147537

# %%
# stack() method “compresses” a level in the DataFrame’s columns
gdf.groupby(['A','B']).sum().stack()
# Out:
# A    B
# bar  one    C    0.528016
#             D    1.459961
#      three  C    0.688847
#             D   -0.942439
#      two    C   -0.088920
#             D    0.659474
# foo  one    C    2.625982
#             D    0.758195
#      three  C    0.580354
#             D   -0.602018
#      two    C    0.194207
#             D    0.147537
# dtype: float64

# %% [markdown]
# ## Plotting
#
# Just a preview, more on the next lab class!

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts.cumsum().plot()

# %%
import matplotlib.pyplot as plt

pdf=pd.DataFrame(np.random.randn(1000, 4), index=ts.index,columns=['A', 'B', 'C', 'D'])
pdf = pdf.cumsum()
plt.figure(); pdf.plot(); plt.legend(loc='best')
