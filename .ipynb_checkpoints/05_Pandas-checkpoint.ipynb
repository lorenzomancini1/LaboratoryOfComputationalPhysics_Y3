# %% [markdown]
# # Pandas
#
# The `numpy` module is excellent for numerical computations, but to handle missing data or arrays with mixed types takes more work. The `pandas` module is currently the most widely used tool for data manipulation, providing high-performance, easy-to-use data structures and advanced data analysis tools.
#
# In particular `pandas` features:
#
# * A fast and efficient "DataFrame" object for data manipulation with integrated indexing;
# * Tools for reading and writing data between in-memory data structures and different formats (CSV, Excel, SQL, HDF5);
# * Intelligent data alignment and integrated handling of missing data;
# * Intelligent label-based slicing, fancy indexing, and subsetting of large data sets;
# * Aggregating or transforming data with a powerful "group-by" engine;
# * High performance merging and joining of data sets;
# * Hierarchical axis indexing provides an intuitive way of working with high-dimensional data in a lower-dimensional data structure;
# * Time series-functionalities;
# * Highly optimized for performance, with critical code paths written in Cython or C.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Series
#
# Series are completely equivalent to 1D array but with axis labels and the possibility to store heterogeneous elements. Of paramount importance are the time-series, used to define time evolutions of a phenomenon.

# %%
from string import ascii_lowercase as letters

# Creating a series, accessing indexes, values and values by their index 
xs = pd.Series(np.arange(10)*0.5, index=tuple(letters[:10]))
print ("xs:", xs,'\n')
print ("xs indexes:",xs.index,'\n')
# Values of the Series are actually a numpy array
print ("xs values:", xs.values, type(xs.values),'\n')
print (xs['f'], xs.f, xs.h, '\n')
print (xs[['d', 'f', 'h']], '\n')
print (type(xs[['d', 'f', 'h']]), '\n')
# Out:
# xs: a    0.0
# b    0.5
# c    1.0
# d    1.5
# e    2.0
# f    2.5
# g    3.0
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# xs indexes: Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'], dtype='object')
#
# xs values: [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5] <class 'numpy.ndarray'>
#
# 2.5 2.5 3.5
#
# d    1.5
# f    2.5
# h    3.5
# dtype: float64
#
# <class 'pandas.core.series.Series'>

# %%
# Extracting elements and operations: same as numpy array
print (xs[:3],'\n')
print (xs[7:], '\n')
print (xs[::3], '\n')
print (xs[xs>3], '\n')
print (np.exp(xs), '\n')
print (np.mean(xs), np.std(xs), '\n')
# Out:
# a    0.0
# b    0.5
# c    1.0
# dtype: float64
#
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# a    0.0
# d    1.5
# g    3.0
# j    4.5
# dtype: float64
#
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# a     1.000000
# b     1.648721
# c     2.718282
# d     4.481689
# e     7.389056
# f    12.182494
# g    20.085537
# h    33.115452
# i    54.598150
# j    90.017131
# dtype: float64
#
# 2.25 1.4361406616345072

# %%
# Series can be created from python dictionary too.
# Not that the elements can be whatever!
d = {'b' : 1, 'a' : 'cat', 'c' : [2,3]}
pd.Series(d)
# Out:
# b         1
# a       cat
# c    [2, 3]
# dtype: object

# %% [markdown]
# A key difference between Series and ndarray is that operations between Series automatically align the data based on label. Thus, you can write computations without considering whether the Series involved have the same labels.

# %%
s = pd.Series(np.random.randn(5), index=tuple(letters[:5]))
print(s)
s = s[1:] + s[:-1]
print(s)
# Out:
# a    0.298243
# b    0.152927
# c    1.555490
# d    0.709438
# e   -1.150944
# dtype: float64
# a         NaN
# b    0.305854
# c    3.110979
# d    1.418877
# e         NaN
# dtype: float64

# %% [markdown]
# ### Time series
#
# Time series are very often used to profile the behaviour of a quantity as a function of time. Pandas as a special index for that, `DatetimeIndex`, that can be created e.g. with the function `pd.data_range()`

# %%
# to define a date, the datetime module is very useful
import datetime as dt
date = dt.date.today()
print(date)

date = dt.datetime(2020,11,9,14,45,10,15)
print (date)

# otherwise, several notations are interpreted too
date = 'Nov 9 2020'
# or alternatively
date = '9/11/2020 14:45:00'
print (date)

days = pd.date_range(date, periods=7, freq='D')
print (days)

seconds = pd.date_range(date, periods=3600, freq='s')
print (seconds)
# Out:
# 2020-11-14
# 2020-11-09 14:45:10.000015
# 9/11/2020 14:45:00
# DatetimeIndex(['2020-09-11 14:45:00', '2020-09-12 14:45:00',
#                '2020-09-13 14:45:00', '2020-09-14 14:45:00',
#                '2020-09-15 14:45:00', '2020-09-16 14:45:00',
#                '2020-09-17 14:45:00'],
#               dtype='datetime64[ns]', freq='D')
# DatetimeIndex(['2020-09-11 14:45:00', '2020-09-11 14:45:01',
#                '2020-09-11 14:45:02', '2020-09-11 14:45:03',
#                '2020-09-11 14:45:04', '2020-09-11 14:45:05',
#                '2020-09-11 14:45:06', '2020-09-11 14:45:07',
#                '2020-09-11 14:45:08', '2020-09-11 14:45:09',
#                ...
#                '2020-09-11 15:44:50', '2020-09-11 15:44:51',
#                '2020-09-11 15:44:52', '2020-09-11 15:44:53',
#                '2020-09-11 15:44:54', '2020-09-11 15:44:55',
#                '2020-09-11 15:44:56', '2020-09-11 15:44:57',
#                '2020-09-11 15:44:58', '2020-09-11 15:44:59'],
#               dtype='datetime64[ns]', length=3600, freq='S')

# %% [markdown]
# To learn more about the frequency strings, please see this [link](http://pandas.pydata.org/pandas-docs/stable/timeseries.html#offset-aliases)
#
#
# Timestamped data is the most basic type of time series data that associates values with points in time. For pandas objects it means using the points in time.
#
# functions like `pd.to_datetime` can be used, for instance, when reading information as string from a dataset

# %%
tstamp = pd.Timestamp(dt.datetime(2020, 11, 9))

# internally it counts the nanoseconds from January 1st 19
#tstamp = pd.Timestamp(dt.datetime(1970, 1, 1, 0, 0, 0, 1))
print(tstamp.value)

# when creating a timestamp the format can be explicitly passed
ts = pd.to_datetime('2010/11/12', format='%Y/%m/%d')
print (type(ts))
print (ts)
ts = pd.to_datetime('12-11-2010 00:00', format='%d-%m-%Y %H:%M')
print (ts)
print (ts.value)
# Out:
# 1604880000000000000
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 2010-11-12 00:00:00
# 2010-11-12 00:00:00
# 1289520000000000000

# %% [markdown]
# A standard series can be created and (range of) elements can be used as indexes

# %%
tseries = pd.Series(np.random.normal(10, 1, len(days)), index=days)
# Extracting elements
print (tseries[0:4], '\n')
print (tseries['2020-11-9':'2020-11-11'], '\n') # Note - includes end time
# Out:
# 2020-09-11 14:45:00    10.579672
# 2020-09-12 14:45:00    10.306864
# 2020-09-13 14:45:00     9.834987
# 2020-09-14 14:45:00    11.556735
# Freq: D, dtype: float64
#
# Series([], Freq: D, dtype: float64)

# %% [markdown]
# `pd.to_datetime` can also be used to create a `DatetimeIndex`:

# %%
pd.to_datetime([1, 2, 3, 4], unit='D', origin=pd.Timestamp('1980-02-03'))
# Out:
# DatetimeIndex(['1980-02-04', '1980-02-05', '1980-02-06', '1980-02-07'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## DataFrame
#
# A pandas DataFrame is like a simple tabular spreadsheet. For future reference (or for people already familiar with R), a pandas DataFrame is very similar to the R DataFrame.
#
# Each column in a DataFrame is a Series object.
#
# The element can be whatever, missing data are dealt with too (as NaN)

# %% [markdown]
# ### DataFrame creation
#
# A DataFrame can be created implicitly, with, e.g., a DatatimeIndex object as index:

# %%
entries=10
dates=pd.date_range('11/9/2020 14:45:00',freq='h', periods=entries)
df = pd.DataFrame(np.random.randn(entries,4), index=dates, columns=['A','B','C','D'])
df
# Out:
#                             A         B         C         D
# 2020-11-09 14:45:00  0.679644 -0.203795  0.018748  0.273789
# 2020-11-09 15:45:00 -0.445461  1.437490  1.086058 -0.664284
# 2020-11-09 16:45:00  1.518213  1.519536  1.689133 -1.003262
# 2020-11-09 17:45:00 -1.057839  0.715916 -2.093069 -1.418185
# 2020-11-09 18:45:00 -1.111464 -2.738694  0.961283 -0.770514
# 2020-11-09 19:45:00  1.339463 -2.067029  1.908909 -2.451017
# 2020-11-09 20:45:00  0.607547 -0.894570 -0.056600 -0.850058
# 2020-11-09 21:45:00 -1.842722 -0.767321 -0.551776  0.007417
# 2020-11-09 22:45:00  0.918775 -0.482251 -0.323394  1.488886
# 2020-11-09 23:45:00 -0.567703  0.882424  1.011848 -0.206056

# %% [markdown]
# or by means of a dictionary:

# %%
df2 = pd.DataFrame(
    { 'A' : 1.,
      'B' : pd.Timestamp('20130102'),
      'C' : pd.Series(1,index=range(4),dtype='float32'),
      'D' : np.arange(7,11),
      'E' : pd.Categorical(["test","train","test","train"]),
    }
    )
df2
# Out:
#      A          B    C   D      E
# 0  1.0 2013-01-02  1.0   7   test
# 1  1.0 2013-01-02  1.0   8  train
# 2  1.0 2013-01-02  1.0   9   test
# 3  1.0 2013-01-02  1.0  10  train

# %% [markdown]
# ### Viewing Data

# %%
df.head()
# Out:
#                             A         B         C         D
# 2020-11-09 14:45:00  0.679644 -0.203795  0.018748  0.273789
# 2020-11-09 15:45:00 -0.445461  1.437490  1.086058 -0.664284
# 2020-11-09 16:45:00  1.518213  1.519536  1.689133 -1.003262
# 2020-11-09 17:45:00 -1.057839  0.715916 -2.093069 -1.418185
# 2020-11-09 18:45:00 -1.111464 -2.738694  0.961283 -0.770514

# %%
df.tail(4)
# Out:
#                             A         B         C         D
# 2020-11-09 20:45:00  0.607547 -0.894570 -0.056600 -0.850058
# 2020-11-09 21:45:00 -1.842722 -0.767321 -0.551776  0.007417
# 2020-11-09 22:45:00  0.918775 -0.482251 -0.323394  1.488886
# 2020-11-09 23:45:00 -0.567703  0.882424  1.011848 -0.206056

# %%
df.index
# Out:
# DatetimeIndex(['2020-11-09 14:45:00', '2020-11-09 15:45:00',
#                '2020-11-09 16:45:00', '2020-11-09 17:45:00',
#                '2020-11-09 18:45:00', '2020-11-09 19:45:00',
#                '2020-11-09 20:45:00', '2020-11-09 21:45:00',
#                '2020-11-09 22:45:00', '2020-11-09 23:45:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 0.67964367, -0.20379512,  0.01874803,  0.2737888 ],
#        [-0.44546103,  1.43749044,  1.08605819, -0.66428394],
#        [ 1.51821341,  1.51953641,  1.68913261, -1.00326247],
#        [-1.05783919,  0.71591558, -2.09306934, -1.41818524],
#        [-1.11146364, -2.73869392,  0.96128314, -0.77051433],
#        [ 1.33946323, -2.06702881,  1.90890856, -2.45101726],
#        [ 0.60754726, -0.8945696 , -0.05660043, -0.85005825],
#        [-1.84272219, -0.76732063, -0.55177589,  0.00741686],
#        [ 0.91877489, -0.48225094, -0.3233942 ,  1.48888644],
#        [-0.56770271,  0.88242433,  1.0118484 , -0.20605634]])

# %%
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.003845  -0.259829   0.365114  -0.559329
# std     1.156858   1.430915   1.205772   1.053492
# min    -1.842722  -2.738694  -2.093069  -2.451017
# 25%    -0.935305  -0.862757  -0.256696  -0.964961
# 50%     0.081043  -0.343023   0.490016  -0.717399
# 75%     0.858992   0.840797   1.067506  -0.045951
# max     1.518213   1.519536   1.908909   1.488886

# %%
df.T
# Out:
#    2020-11-09 14:45:00  2020-11-09 15:45:00  2020-11-09 16:45:00  \
# A             0.679644            -0.445461             1.518213
# B            -0.203795             1.437490             1.519536
# C             0.018748             1.086058             1.689133
# D             0.273789            -0.664284            -1.003262
#
#    2020-11-09 17:45:00  2020-11-09 18:45:00  2020-11-09 19:45:00  \
# A            -1.057839            -1.111464             1.339463
# B             0.715916            -2.738694            -2.067029
# C            -2.093069             0.961283             1.908909
# D            -1.418185            -0.770514            -2.451017
#
#    2020-11-09 20:45:00  2020-11-09 21:45:00  2020-11-09 22:45:00  \
# A             0.607547            -1.842722             0.918775
# B            -0.894570            -0.767321            -0.482251
# C            -0.056600            -0.551776            -0.323394
# D            -0.850058             0.007417             1.488886
#
#    2020-11-09 23:45:00
# A            -0.567703
# B             0.882424
# C             1.011848
# D            -0.206056

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#                             D         C         B         A
# 2020-11-09 14:45:00  0.273789  0.018748 -0.203795  0.679644
# 2020-11-09 15:45:00 -0.664284  1.086058  1.437490 -0.445461
# 2020-11-09 16:45:00 -1.003262  1.689133  1.519536  1.518213
# 2020-11-09 17:45:00 -1.418185 -2.093069  0.715916 -1.057839
# 2020-11-09 18:45:00 -0.770514  0.961283 -2.738694 -1.111464
# 2020-11-09 19:45:00 -2.451017  1.908909 -2.067029  1.339463
# 2020-11-09 20:45:00 -0.850058 -0.056600 -0.894570  0.607547
# 2020-11-09 21:45:00  0.007417 -0.551776 -0.767321 -1.842722
# 2020-11-09 22:45:00  1.488886 -0.323394 -0.482251  0.918775
# 2020-11-09 23:45:00 -0.206056  1.011848  0.882424 -0.567703

# %%
df.sort_values(by="C")
# Out:
#                             A         B         C         D
# 2020-11-09 17:45:00 -1.057839  0.715916 -2.093069 -1.418185
# 2020-11-09 21:45:00 -1.842722 -0.767321 -0.551776  0.007417
# 2020-11-09 22:45:00  0.918775 -0.482251 -0.323394  1.488886
# 2020-11-09 20:45:00  0.607547 -0.894570 -0.056600 -0.850058
# 2020-11-09 14:45:00  0.679644 -0.203795  0.018748  0.273789
# 2020-11-09 18:45:00 -1.111464 -2.738694  0.961283 -0.770514
# 2020-11-09 23:45:00 -0.567703  0.882424  1.011848 -0.206056
# 2020-11-09 15:45:00 -0.445461  1.437490  1.086058 -0.664284
# 2020-11-09 16:45:00  1.518213  1.519536  1.689133 -1.003262
# 2020-11-09 19:45:00  1.339463 -2.067029  1.908909 -2.451017

# %% [markdown]
# ## Selection
#
# ### Getting slices
#
# The following show how to get part of the DataFrame (i.e. not just the elements)

# %%
## standard and safe
print (df['A'],'\n')

## equivalent but dangerous (imagine blank spaces in the name of the column..)
print (df.A)
# Out:
# 2020-11-09 14:45:00    0.679644
# 2020-11-09 15:45:00   -0.445461
# 2020-11-09 16:45:00    1.518213
# 2020-11-09 17:45:00   -1.057839
# 2020-11-09 18:45:00   -1.111464
# 2020-11-09 19:45:00    1.339463
# 2020-11-09 20:45:00    0.607547
# 2020-11-09 21:45:00   -1.842722
# 2020-11-09 22:45:00    0.918775
# 2020-11-09 23:45:00   -0.567703
# Freq: H, Name: A, dtype: float64
#
# 2020-11-09 14:45:00    0.679644
# 2020-11-09 15:45:00   -0.445461
# 2020-11-09 16:45:00    1.518213
# 2020-11-09 17:45:00   -1.057839
# 2020-11-09 18:45:00   -1.111464
# 2020-11-09 19:45:00    1.339463
# 2020-11-09 20:45:00    0.607547
# 2020-11-09 21:45:00   -1.842722
# 2020-11-09 22:45:00    0.918775
# 2020-11-09 23:45:00   -0.567703
# Freq: H, Name: A, dtype: float64

# %%
# selecting rows by counting
print (df[0:3])

# or by index
print (df["2020-11-09 14:45:00":"2020-11-09 16:45:00"])
# Out:
#                             A         B         C         D
# 2020-11-09 14:45:00  0.679644 -0.203795  0.018748  0.273789
# 2020-11-09 15:45:00 -0.445461  1.437490  1.086058 -0.664284
# 2020-11-09 16:45:00  1.518213  1.519536  1.689133 -1.003262
#                             A         B         C         D
# 2020-11-09 14:45:00  0.679644 -0.203795  0.018748  0.273789
# 2020-11-09 15:45:00 -0.445461  1.437490  1.086058 -0.664284
# 2020-11-09 16:45:00  1.518213  1.519536  1.689133 -1.003262

# %% [markdown]
# ### Selection by label

# %%
# getting a cross section (part of the DataFrame) using a label
df.loc[dates[0]]
# Out:
# A    0.679644
# B   -0.203795
# C    0.018748
# D    0.273789
# Name: 2020-11-09 14:45:00, dtype: float64

# %%
# selecting on a multi-axis by label:
df.loc[:,['A','B']]
# Out:
#                             A         B
# 2020-11-09 14:45:00  0.679644 -0.203795
# 2020-11-09 15:45:00 -0.445461  1.437490
# 2020-11-09 16:45:00  1.518213  1.519536
# 2020-11-09 17:45:00 -1.057839  0.715916
# 2020-11-09 18:45:00 -1.111464 -2.738694
# 2020-11-09 19:45:00  1.339463 -2.067029
# 2020-11-09 20:45:00  0.607547 -0.894570
# 2020-11-09 21:45:00 -1.842722 -0.767321
# 2020-11-09 22:45:00  0.918775 -0.482251
# 2020-11-09 23:45:00 -0.567703  0.882424

# %%
# showing label slicing, both endpoints are included:
df.loc['2020-11-09 18:45:00':'2020-11-09 20:45:00',['A','B']]
# Out:
#                             A         B
# 2020-11-09 18:45:00 -1.111464 -2.738694
# 2020-11-09 19:45:00  1.339463 -2.067029
# 2020-11-09 20:45:00  0.607547 -0.894570

# %%
# getting an individual element
print (df.loc[dates[1],'A'])

# equivalently
print (df.at[dates[1],'A'])
# Out:
# -0.4454610310094751
# -0.4454610310094751

# %% [markdown]
# ### Selecting by position

# %%
# select via the position of the passed integers:
print (df.iloc[3],'\n')

# notation similar to numpy/python
print (df.iloc[3:5,0:2])
# Out:
# A   -1.057839
# B    0.715916
# C   -2.093069
# D   -1.418185
# Name: 2020-11-09 17:45:00, dtype: float64
#
#                             A         B
# 2020-11-09 17:45:00 -1.057839  0.715916
# 2020-11-09 18:45:00 -1.111464 -2.738694

# %%
# selecting raws 1,2 and 4 for columns 0 and 2
df.iloc[[1,2,4],[0,2]]
# Out:
#                             A         C
# 2020-11-09 15:45:00 -0.445461  1.086058
# 2020-11-09 16:45:00  1.518213  1.689133
# 2020-11-09 18:45:00 -1.111464  0.961283

# %%
# slicing rows explicitly
print (df.iloc[1:3,:],'\n')

# slicing columns explicitly
print (df.iloc[:,1:3])
# Out:
#                             A         B         C         D
# 2020-11-09 15:45:00 -0.445461  1.437490  1.086058 -0.664284
# 2020-11-09 16:45:00  1.518213  1.519536  1.689133 -1.003262
#
#                             B         C
# 2020-11-09 14:45:00 -0.203795  0.018748
# 2020-11-09 15:45:00  1.437490  1.086058
# 2020-11-09 16:45:00  1.519536  1.689133
# 2020-11-09 17:45:00  0.715916 -2.093069
# 2020-11-09 18:45:00 -2.738694  0.961283
# 2020-11-09 19:45:00 -2.067029  1.908909
# 2020-11-09 20:45:00 -0.894570 -0.056600
# 2020-11-09 21:45:00 -0.767321 -0.551776
# 2020-11-09 22:45:00 -0.482251 -0.323394
# 2020-11-09 23:45:00  0.882424  1.011848

# %%
# selecting an individual element by position
df.iloc[1,1]
df.iat[1,1]
# Out:
# 1.4374904447138348

# %% [markdown]
# ### Boolean index
#
# Very powerful way of filtering out data with certain features. Notation is very similar to numpy arrays.

# %%
# Filter by a boolean condition on the values of a single column
df[df['B'] > 0]
# Out:
#                             A         B         C         D
# 2020-11-09 15:45:00 -0.445461  1.437490  1.086058 -0.664284
# 2020-11-09 16:45:00  1.518213  1.519536  1.689133 -1.003262
# 2020-11-09 17:45:00 -1.057839  0.715916 -2.093069 -1.418185
# 2020-11-09 23:45:00 -0.567703  0.882424  1.011848 -0.206056

# %%
# Selecting on the basis of boolean conditions applied to the whole DataFrame
df[df>0]

# a DataFrame with the same shape is returned, with NaN's where condition is not met
# Out:
#                             A         B         C         D
# 2020-11-09 14:45:00  0.679644       NaN  0.018748  0.273789
# 2020-11-09 15:45:00       NaN  1.437490  1.086058       NaN
# 2020-11-09 16:45:00  1.518213  1.519536  1.689133       NaN
# 2020-11-09 17:45:00       NaN  0.715916       NaN       NaN
# 2020-11-09 18:45:00       NaN       NaN  0.961283       NaN
# 2020-11-09 19:45:00  1.339463       NaN  1.908909       NaN
# 2020-11-09 20:45:00  0.607547       NaN       NaN       NaN
# 2020-11-09 21:45:00       NaN       NaN       NaN  0.007417
# 2020-11-09 22:45:00  0.918775       NaN       NaN  1.488886
# 2020-11-09 23:45:00       NaN  0.882424  1.011848       NaN

# %% [markdown]
# ### Setting
#
# Combination of selection and setting of values

# %%
# setting values by label (same as by position)
df.at[dates[0],'A'] = 0

# setting and assigning a numpy array
df.loc[:,'D'] = np.array([5] * len(df))

# defining a brand new column
df['E'] = np.arange(len(df))*0.5

# defining a brand new column by means of a pd.Series: indexes must be the same!
df['E prime'] = pd.Series(np.arange(len(df))*2, index=df.index)

# %%
def dcos(theta):
    theta = theta*(np.pi/180)
    return np.cos(theta)
 
df['cosine'] = pd.Series(df["E"].apply(dcos), index=df.index)
df
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2020-11-09 14:45:00  0.000000 -0.203795  0.018748  5  0.0        0  1.000000
# 2020-11-09 15:45:00 -0.445461  1.437490  1.086058  5  0.5        2  0.999962
# 2020-11-09 16:45:00  1.518213  1.519536  1.689133  5  1.0        4  0.999848
# 2020-11-09 17:45:00 -1.057839  0.715916 -2.093069  5  1.5        6  0.999657
# 2020-11-09 18:45:00 -1.111464 -2.738694  0.961283  5  2.0        8  0.999391
# 2020-11-09 19:45:00  1.339463 -2.067029  1.908909  5  2.5       10  0.999048
# 2020-11-09 20:45:00  0.607547 -0.894570 -0.056600  5  3.0       12  0.998630
# 2020-11-09 21:45:00 -1.842722 -0.767321 -0.551776  5  3.5       14  0.998135
# 2020-11-09 22:45:00  0.918775 -0.482251 -0.323394  5  4.0       16  0.997564
# 2020-11-09 23:45:00 -0.567703  0.882424  1.011848  5  4.5       18  0.996917

# %%
# another example of global setting
df2=df.copy()
df2[df2>0] = -df2
df2
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2020-11-09 14:45:00  0.000000 -0.203795 -0.018748 -5  0.0        0 -1.000000
# 2020-11-09 15:45:00 -0.445461 -1.437490 -1.086058 -5 -0.5       -2 -0.999962
# 2020-11-09 16:45:00 -1.518213 -1.519536 -1.689133 -5 -1.0       -4 -0.999848
# 2020-11-09 17:45:00 -1.057839 -0.715916 -2.093069 -5 -1.5       -6 -0.999657
# 2020-11-09 18:45:00 -1.111464 -2.738694 -0.961283 -5 -2.0       -8 -0.999391
# 2020-11-09 19:45:00 -1.339463 -2.067029 -1.908909 -5 -2.5      -10 -0.999048
# 2020-11-09 20:45:00 -0.607547 -0.894570 -0.056600 -5 -3.0      -12 -0.998630
# 2020-11-09 21:45:00 -1.842722 -0.767321 -0.551776 -5 -3.5      -14 -0.998135
# 2020-11-09 22:45:00 -0.918775 -0.482251 -0.323394 -5 -4.0      -16 -0.997564
# 2020-11-09 23:45:00 -0.567703 -0.882424 -1.011848 -5 -4.5      -18 -0.996917

# %% [markdown]
# ### Dropping
#
# N.B.: dropping doesn't act permanently on the DataFrame, i.e. to get that do :
# ```python
# df = df.drop(....)
# ```

# %%
# Dropping by column
df.drop(['E prime'], axis=1)

#which is equivalent to
df.drop(columns=['E prime'])
# Out:
#                             A         B         C  D    E    cosine
# 2020-11-09 14:45:00  0.000000 -0.203795  0.018748  5  0.0  1.000000
# 2020-11-09 15:45:00 -0.445461  1.437490  1.086058  5  0.5  0.999962
# 2020-11-09 16:45:00  1.518213  1.519536  1.689133  5  1.0  0.999848
# 2020-11-09 17:45:00 -1.057839  0.715916 -2.093069  5  1.5  0.999657
# 2020-11-09 18:45:00 -1.111464 -2.738694  0.961283  5  2.0  0.999391
# 2020-11-09 19:45:00  1.339463 -2.067029  1.908909  5  2.5  0.999048
# 2020-11-09 20:45:00  0.607547 -0.894570 -0.056600  5  3.0  0.998630
# 2020-11-09 21:45:00 -1.842722 -0.767321 -0.551776  5  3.5  0.998135
# 2020-11-09 22:45:00  0.918775 -0.482251 -0.323394  5  4.0  0.997564
# 2020-11-09 23:45:00 -0.567703  0.882424  1.011848  5  4.5  0.996917

# %%
# Dropping by raws
# safe and always working
df.drop(df.index[[1,2,3,4]])
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2020-11-09 14:45:00  0.000000 -0.203795  0.018748  5  0.0        0  1.000000
# 2020-11-09 19:45:00  1.339463 -2.067029  1.908909  5  2.5       10  0.999048
# 2020-11-09 20:45:00  0.607547 -0.894570 -0.056600  5  3.0       12  0.998630
# 2020-11-09 21:45:00 -1.842722 -0.767321 -0.551776  5  3.5       14  0.998135
# 2020-11-09 22:45:00  0.918775 -0.482251 -0.323394  5  4.0       16  0.997564
# 2020-11-09 23:45:00 -0.567703  0.882424  1.011848  5  4.5       18  0.996917

# %%
# something like df.drop('index_name') 
# would work but the type of index must be specificed, 
# in particular with DatetimeIndex
df.drop(pd.to_datetime("2020-11-09 22:45:00"))
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2020-11-09 14:45:00  0.000000 -0.203795  0.018748  5  0.0        0  1.000000
# 2020-11-09 15:45:00 -0.445461  1.437490  1.086058  5  0.5        2  0.999962
# 2020-11-09 16:45:00  1.518213  1.519536  1.689133  5  1.0        4  0.999848
# 2020-11-09 17:45:00 -1.057839  0.715916 -2.093069  5  1.5        6  0.999657
# 2020-11-09 18:45:00 -1.111464 -2.738694  0.961283  5  2.0        8  0.999391
# 2020-11-09 19:45:00  1.339463 -2.067029  1.908909  5  2.5       10  0.999048
# 2020-11-09 20:45:00  0.607547 -0.894570 -0.056600  5  3.0       12  0.998630
# 2020-11-09 21:45:00 -1.842722 -0.767321 -0.551776  5  3.5       14  0.998135
# 2020-11-09 23:45:00 -0.567703  0.882424  1.011848  5  4.5       18  0.996917

# %% [markdown]
# ## Missing data
#
# pandas primarily uses the value np.nan to represent missing data. It is by default not included in computations.

# %%
df_wNan = df[df>0]
df_wNan
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2020-11-09 14:45:00       NaN       NaN  0.018748  5  NaN      NaN  1.000000
# 2020-11-09 15:45:00       NaN  1.437490  1.086058  5  0.5      2.0  0.999962
# 2020-11-09 16:45:00  1.518213  1.519536  1.689133  5  1.0      4.0  0.999848
# 2020-11-09 17:45:00       NaN  0.715916       NaN  5  1.5      6.0  0.999657
# 2020-11-09 18:45:00       NaN       NaN  0.961283  5  2.0      8.0  0.999391
# 2020-11-09 19:45:00  1.339463       NaN  1.908909  5  2.5     10.0  0.999048
# 2020-11-09 20:45:00  0.607547       NaN       NaN  5  3.0     12.0  0.998630
# 2020-11-09 21:45:00       NaN       NaN       NaN  5  3.5     14.0  0.998135
# 2020-11-09 22:45:00  0.918775       NaN       NaN  5  4.0     16.0  0.997564
# 2020-11-09 23:45:00       NaN  0.882424  1.011848  5  4.5     18.0  0.996917

# %%
# dropping rows with at least a Nan
df_wNan.dropna(how='any')
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2020-11-09 16:45:00  1.518213  1.519536  1.689133  5  1.0      4.0  0.999848

# %%
# getting a mask
df_wNan.isna()
#df_wNan.notna()
# Out:
#                          A      B      C      D      E  E prime  cosine
# 2020-11-09 14:45:00   True   True  False  False   True     True   False
# 2020-11-09 15:45:00   True  False  False  False  False    False   False
# 2020-11-09 16:45:00  False  False  False  False  False    False   False
# 2020-11-09 17:45:00   True  False   True  False  False    False   False
# 2020-11-09 18:45:00   True   True  False  False  False    False   False
# 2020-11-09 19:45:00  False   True  False  False  False    False   False
# 2020-11-09 20:45:00  False   True   True  False  False    False   False
# 2020-11-09 21:45:00   True   True   True  False  False    False   False
# 2020-11-09 22:45:00  False   True   True  False  False    False   False
# 2020-11-09 23:45:00   True  False  False  False  False    False   False

# %%
# filling missing data
df_wNan.fillna(value=0)
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2020-11-09 14:45:00  0.000000  0.000000  0.018748  5  0.0      0.0  1.000000
# 2020-11-09 15:45:00  0.000000  1.437490  1.086058  5  0.5      2.0  0.999962
# 2020-11-09 16:45:00  1.518213  1.519536  1.689133  5  1.0      4.0  0.999848
# 2020-11-09 17:45:00  0.000000  0.715916  0.000000  5  1.5      6.0  0.999657
# 2020-11-09 18:45:00  0.000000  0.000000  0.961283  5  2.0      8.0  0.999391
# 2020-11-09 19:45:00  1.339463  0.000000  1.908909  5  2.5     10.0  0.999048
# 2020-11-09 20:45:00  0.607547  0.000000  0.000000  5  3.0     12.0  0.998630
# 2020-11-09 21:45:00  0.000000  0.000000  0.000000  5  3.5     14.0  0.998135
# 2020-11-09 22:45:00  0.918775  0.000000  0.000000  5  4.0     16.0  0.997564
# 2020-11-09 23:45:00  0.000000  0.882424  1.011848  5  4.5     18.0  0.996917

# %% [markdown]
# Fill gaps forward or backward by propagating non-NA values forward or backward:

# %%
df_wNan.fillna(method='pad')
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2020-11-09 14:45:00       NaN       NaN  0.018748  5  NaN      NaN  1.000000
# 2020-11-09 15:45:00       NaN  1.437490  1.086058  5  0.5      2.0  0.999962
# 2020-11-09 16:45:00  1.518213  1.519536  1.689133  5  1.0      4.0  0.999848
# 2020-11-09 17:45:00  1.518213  0.715916  1.689133  5  1.5      6.0  0.999657
# 2020-11-09 18:45:00  1.518213  0.715916  0.961283  5  2.0      8.0  0.999391
# 2020-11-09 19:45:00  1.339463  0.715916  1.908909  5  2.5     10.0  0.999048
# 2020-11-09 20:45:00  0.607547  0.715916  1.908909  5  3.0     12.0  0.998630
# 2020-11-09 21:45:00  0.607547  0.715916  1.908909  5  3.5     14.0  0.998135
# 2020-11-09 22:45:00  0.918775  0.715916  1.908909  5  4.0     16.0  0.997564
# 2020-11-09 23:45:00  0.918775  0.882424  1.011848  5  4.5     18.0  0.996917

# %% [markdown]
# ## Operations
#
# Here comes the most relevant advantage of DataFrame. Operations on columns are extremly fast, almost as fast as the actual operation between elements in a row

# %%
# Some statistics (mean() just as an example)
# raws
print (df.mean(axis=0),'\n')
# columns
print (df.mean(axis=1),'\n')
# Out:
# A         -0.064119
# B         -0.259829
# C          0.365114
# D          5.000000
# E          2.250000
# E prime    9.000000
# cosine     0.998915
# dtype: float64
#
# 2020-11-09 14:45:00    0.830708
# 2020-11-09 15:45:00    1.511150
# 2020-11-09 16:45:00    2.246676
# 2020-11-09 17:45:00    1.580666
# 2020-11-09 18:45:00    1.872931
# 2020-11-09 19:45:00    2.811484
# 2020-11-09 20:45:00    2.950715
# 2020-11-09 21:45:00    2.905188
# 2020-11-09 22:45:00    3.730099
# 2020-11-09 23:45:00    4.260498
# Freq: H, dtype: float64

# %%
# global operations on columns
df.apply(np.cumsum)
# Out:
#                             A         B         C   D     E  E prime    cosine
# 2020-11-09 14:45:00  0.000000 -0.203795  0.018748   5   0.0        0  1.000000
# 2020-11-09 15:45:00 -0.445461  1.233695  1.104806  10   0.5        2  1.999962
# 2020-11-09 16:45:00  1.072752  2.753232  2.793939  15   1.5        6  2.999810
# 2020-11-09 17:45:00  0.014913  3.469147  0.700869  20   3.0       12  3.999467
# 2020-11-09 18:45:00 -1.096550  0.730453  1.662153  25   5.0       20  4.998858
# 2020-11-09 19:45:00  0.242913 -1.336575  3.571061  30   7.5       30  5.997906
# 2020-11-09 20:45:00  0.850460 -2.231145  3.514461  35  10.5       42  6.996536
# 2020-11-09 21:45:00 -0.992262 -2.998466  2.962685  40  14.0       56  7.994670
# 2020-11-09 22:45:00 -0.073487 -3.480717  2.639291  45  18.0       72  8.992234
# 2020-11-09 23:45:00 -0.641190 -2.598292  3.651139  50  22.5       90  9.989152

# %%
df
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2020-11-09 14:45:00  0.000000 -0.203795  0.018748  5  0.0        0  1.000000
# 2020-11-09 15:45:00 -0.445461  1.437490  1.086058  5  0.5        2  0.999962
# 2020-11-09 16:45:00  1.518213  1.519536  1.689133  5  1.0        4  0.999848
# 2020-11-09 17:45:00 -1.057839  0.715916 -2.093069  5  1.5        6  0.999657
# 2020-11-09 18:45:00 -1.111464 -2.738694  0.961283  5  2.0        8  0.999391
# 2020-11-09 19:45:00  1.339463 -2.067029  1.908909  5  2.5       10  0.999048
# 2020-11-09 20:45:00  0.607547 -0.894570 -0.056600  5  3.0       12  0.998630
# 2020-11-09 21:45:00 -1.842722 -0.767321 -0.551776  5  3.5       14  0.998135
# 2020-11-09 22:45:00  0.918775 -0.482251 -0.323394  5  4.0       16  0.997564
# 2020-11-09 23:45:00 -0.567703  0.882424  1.011848  5  4.5       18  0.996917

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A           3.360936
# B           4.258230
# C           4.001978
# D           0.000000
# E           4.500000
# E prime    18.000000
# cosine      0.003083
# dtype: float64

# %%
# syntax is as usual similar to that of numpy arrays
df['A']+df['B']
# Out:
# 2020-11-09 14:45:00   -0.203795
# 2020-11-09 15:45:00    0.992029
# 2020-11-09 16:45:00    3.037750
# 2020-11-09 17:45:00   -0.341924
# 2020-11-09 18:45:00   -3.850158
# 2020-11-09 19:45:00   -0.727566
# 2020-11-09 20:45:00   -0.287022
# 2020-11-09 21:45:00   -2.610043
# 2020-11-09 22:45:00    0.436524
# 2020-11-09 23:45:00    0.314722
# Freq: H, dtype: float64

# %% [markdown]
# Let's play it hard and load (in memory) a (relatively) large dataset

# %%
# WARNING! link in past notebook was wrong!, (if needed) get the right file from:
#!wget https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt -P ~/data/

file_name="data/data_000637.txt"
data=pd.read_csv(file_name)
data
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 0           1     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1310715     1     0           62  3869211171         762        14
# 1310716     1     1            4  3869211171         763        11
# 1310717     1     0           64  3869211171         764         0
# 1310718     1     0          139  3869211171         769         0
# 1310719     1     0           61  3869211171         762        18
#
# [1310720 rows x 6 columns]

# %% [markdown]
# Let's now do some operations among (elements of) columns

# %%
# the one-liner killing it all
data['timens']=data['TDC_MEAS']*25/30+data['BX_COUNTER']*25

# %%
# the old slooow way
def conversion(data):
    result=[]
    for i in range(len(data)): 
        result.append(data.loc[data.index[i],'TDC_MEAS']*25/30.+data.loc[data.index[i],'BX_COUNTER']*25)
    return result

data['timens']=conversion(data)

# %% [markdown]
# ## Merge
#
# pandas provides various facilities for easily combining together Series, DataFrame, and Panel objects with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.
#
# ### Concat
#
# concatenation (adding rows) is straightforward

# %%
rdf = pd.DataFrame(np.random.randn(10, 4))
rdf
# Out:
#           0         1         2         3
# 0  0.554476 -0.130396  0.369875  0.187163
# 1  0.118848  1.149626 -0.609481 -0.402669
# 2  0.321524  1.424562 -0.204010  0.945864
# 3  1.604355 -1.109769 -0.866693 -0.705840
# 4 -0.290629  0.302255  0.790326  0.358254
# 5  0.473846  0.356359  0.927009 -0.409093
# 6  0.248884 -0.912268 -0.280109 -0.850566
# 7 -0.011048  0.823146  1.499735  0.149060
# 8  1.653936 -0.957964 -0.367865  0.534189
# 9  0.959993  1.177844 -0.660999  0.438315

# %%
# divide it into pieaces row-wise
pieces = [rdf[:3], rdf[3:7], rdf[7:]]
pieces
# Out:
# [          0         1         2         3
#  0  0.554476 -0.130396  0.369875  0.187163
#  1  0.118848  1.149626 -0.609481 -0.402669
#  2  0.321524  1.424562 -0.204010  0.945864,
#            0         1         2         3
#  3  1.604355 -1.109769 -0.866693 -0.705840
#  4 -0.290629  0.302255  0.790326  0.358254
#  5  0.473846  0.356359  0.927009 -0.409093
#  6  0.248884 -0.912268 -0.280109 -0.850566,
#            0         1         2         3
#  7 -0.011048  0.823146  1.499735  0.149060
#  8  1.653936 -0.957964 -0.367865  0.534189
#  9  0.959993  1.177844 -0.660999  0.438315]

# %%
# put it back together
#pd.concat(pieces)

# indexes can be ignored
pd.concat(pieces, ignore_index=True)

# in case of dimension mismatch, Nan are added where needed
# Out:
#           0         1         2         3
# 0  0.554476 -0.130396  0.369875  0.187163
# 1  0.118848  1.149626 -0.609481 -0.402669
# 2  0.321524  1.424562 -0.204010  0.945864
# 3  1.604355 -1.109769 -0.866693 -0.705840
# 4 -0.290629  0.302255  0.790326  0.358254
# 5  0.473846  0.356359  0.927009 -0.409093
# 6  0.248884 -0.912268 -0.280109 -0.850566
# 7 -0.011048  0.823146  1.499735  0.149060
# 8  1.653936 -0.957964 -0.367865  0.534189
# 9  0.959993  1.177844 -0.660999  0.438315

# %%
# appending a single row (as a Series)
s = rdf.iloc[3]
rdf.append(s, ignore_index=True)
rdf
# Out:
#           0         1         2         3
# 0  0.554476 -0.130396  0.369875  0.187163
# 1  0.118848  1.149626 -0.609481 -0.402669
# 2  0.321524  1.424562 -0.204010  0.945864
# 3  1.604355 -1.109769 -0.866693 -0.705840
# 4 -0.290629  0.302255  0.790326  0.358254
# 5  0.473846  0.356359  0.927009 -0.409093
# 6  0.248884 -0.912268 -0.280109 -0.850566
# 7 -0.011048  0.823146  1.499735  0.149060
# 8  1.653936 -0.957964 -0.367865  0.534189
# 9  0.959993  1.177844 -0.660999  0.438315

# %% [markdown]
# ### Merge/Join
#
# SQL like operations on table can be performed on DataFrames. This is all rather sophisticated, refer to the [doc](https://pandas.pydata.org/pandas-docs/stable/merging.html#merging) for more info/examples

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})

pd.merge(left,right,on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
# ## Grouping
#
# By “group by” we are referring to a process involving one or more of the following steps:
#
# * Splitting the data into groups based on some criteria
# * Applying a function to each group independently
# * Combining the results into a data structure

# %%
gdf = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
                          'foo', 'bar', 'foo', 'foo'],
                    'B' : ['one', 'one', 'two', 'three',
                           'two', 'two', 'one', 'three'],
                    'C' : np.random.randn(8),
                    'D' : np.random.randn(8)})
gdf
# Out:
#      A      B         C         D
# 0  foo    one  1.177799 -2.344878
# 1  bar    one -0.151080 -1.203319
# 2  foo    two  0.765022  1.323676
# 3  bar  three -0.433995 -0.837964
# 4  foo    two  0.001563  0.431163
# 5  bar    two -1.751762  0.952915
# 6  foo    one  1.818894  1.152256
# 7  foo  three -0.157476  0.127140

# %%
# Grouping and then applying the sum() 
# function to the resulting groups (effective only where number are there).
gdf.groupby('A').sum()
# Out:
#             C         D
# A
# bar -2.336837 -1.088368
# foo  3.605802  0.689357

# %% [markdown]
# ## Multi-indexing
#
#
# Hierarchical / Multi-level indexing allows sophisticated data analysis on higher dimensional data. In essence, it enables you to store and manipulate data with an arbitrary number of dimensions in lower dimensional data structures like Series (1d) and DataFrame (2d).

# %%
tuples = list(zip(['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'],
          ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']))
multi_index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
print (multi_index,'\n')

s = pd.Series(np.random.randn(8), index=multi_index)
print (s)
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])
#
# first  second
# bar    one      -0.624914
#        two      -0.185906
# baz    one      -0.047860
#        two       1.016310
# foo    one      -0.111875
#        two       0.561231
# qux    one      -0.827139
#        two      -1.747531
# dtype: float64

# %%
# it enables further features of the groupby method,
# e.g. when group-by by multiple columns
gdf.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.151080 -1.203319
#     three -0.433995 -0.837964
#     two   -1.751762  0.952915
# foo one    2.996693 -1.192622
#     three -0.157476  0.127140
#     two    0.766585  1.754839

# %%
# stack() method “compresses” a level in the DataFrame’s columns
gdf.groupby(['A','B']).sum().stack()
# Out:
# A    B
# bar  one    C   -0.151080
#             D   -1.203319
#      three  C   -0.433995
#             D   -0.837964
#      two    C   -1.751762
#             D    0.952915
# foo  one    C    2.996693
#             D   -1.192622
#      three  C   -0.157476
#             D    0.127140
#      two    C    0.766585
#             D    1.754839
# dtype: float64

# %% [markdown]
# ## Plotting
#
# Just a preview, more on the next lab class!

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts.cumsum().plot()

# %%
import matplotlib.pyplot as plt

pdf=pd.DataFrame(np.random.randn(1000, 4), index=ts.index,columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
plt.figure(); df.plot(); plt.legend(loc='best')
