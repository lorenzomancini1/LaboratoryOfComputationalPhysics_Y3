# %% [markdown]
# # Pandas
#
# The `numpy` module is excellent for numerical computations, but to handle missing data or arrays with mixed types takes more work. The `pandas` module is currently the most widely used tool for data manipulation, providing high-performance, easy-to-use data structures and advanced data analysis tools.
#
# In particular `pandas` features:
#
# * A fast and efficient "DataFrame" object for data manipulation with integrated indexing;
# * Tools for reading and writing data between in-memory data structures and different formats (CSV, Excel, SQL, HDF5);
# * Intelligent data alignment and integrated handling of missing data;
# * Intelligent label-based slicing, fancy indexing, and subsetting of large data sets;
# * Aggregating or transforming data with a powerful "group-by" engine;
# * High performance merging and joining of data sets;
# * Hierarchical axis indexing provides an intuitive way of working with high-dimensional data in a lower-dimensional data structure;
# * Time series-functionalities;
# * Highly optimized for performance, with critical code paths written in Cython or C.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Series
#
# Series are completely equivalent to 1D array but with axis labels and the possibility to store heterogeneous elements. Of paramount importance are the time-series, used to define time evolutions of a phenomenon.

# %%
from string import ascii_lowercase as letters

# Creating a series, accessing indexes, values and values by their index 
xs = pd.Series(np.arange(10)*0.5, index=tuple(letters[:10]))
print ("xs:", xs,'\n')
print ("xs indexes:",xs.index,'\n')
# Values of the Series are actually a numpy array
print ("xs values:", xs.values, type(xs.values),'\n')
print (xs['f'], xs.f, xs.h, '\n')
print (xs[['d', 'f', 'h']], '\n')
print (type(xs[['d', 'f', 'h']]), '\n')
# Out:
# xs: a    0.0
# b    0.5
# c    1.0
# d    1.5
# e    2.0
# f    2.5
# g    3.0
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# xs indexes: Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'], dtype='object')
#
# xs values: [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5] <class 'numpy.ndarray'>
#
# 2.5 2.5 3.5
#
# d    1.5
# f    2.5
# h    3.5
# dtype: float64
#
# <class 'pandas.core.series.Series'>

# %%
# Extracting elements and operations: same as numpy array
print (xs[:3],'\n')
print (xs[7:], '\n')
print (xs[::3], '\n')
print (xs[xs>3], '\n')
print (np.exp(xs), '\n')
print (np.mean(xs), np.std(xs), '\n')
# Out:
# a    0.0
# b    0.5
# c    1.0
# dtype: float64
#
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# a    0.0
# d    1.5
# g    3.0
# j    4.5
# dtype: float64
#
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# a     1.000000
# b     1.648721
# c     2.718282
# d     4.481689
# e     7.389056
# f    12.182494
# g    20.085537
# h    33.115452
# i    54.598150
# j    90.017131
# dtype: float64
#
# 2.25 1.4361406616345072

# %%
# Series can be created from python dictionary too.
# Not that the elements can be whatever!
d = {'b' : 1, 'a' : 'cat', 'c' : [2,3]}
pd.Series(d)
# Out:
# b         1
# a       cat
# c    [2, 3]
# dtype: object

# %% [markdown]
# A key difference between Series and ndarray is that operations between Series automatically align the data based on label. Thus, you can write computations without considering whether the Series involved have the same labels.

# %%
s = pd.Series(np.random.randn(5), index=tuple(letters[:5]))
print(s)
s = s[1:] + s[:-1]
print(s)
# Out:
# a   -0.031226
# b    1.476452
# c    0.449779
# d   -1.748810
# e   -2.058912
# dtype: float64
# a         NaN
# b    2.952904
# c    0.899558
# d   -3.497620
# e         NaN
# dtype: float64

# %% [markdown]
# ### Time series
#
# Time series are very often used to profile the behaviour of a quantity as a function of time. Pandas as a special index for that, `DatetimeIndex`, that can be created e.g. with the function `pd.data_range()`

# %%
# to define a date, the datetime module is very useful
import datetime as dt
date = dt.date.today()
print(date)

date = dt.datetime(2020,11,9,14,45,10,15)
print (date)

# otherwise, several notations are interpreted too
date = 'Nov 9 2020'
# or alternatively
date = '9/11/2020 14:45:00'
print (date)

days = pd.date_range(date, periods=7, freq='D')
print (days)

seconds = pd.date_range(date, periods=3600, freq='s')
print (seconds)
# Out:
# 2020-11-14
# 2020-11-09 14:45:10.000015
# 9/11/2020 14:45:00
# DatetimeIndex(['2020-09-11 14:45:00', '2020-09-12 14:45:00',
#                '2020-09-13 14:45:00', '2020-09-14 14:45:00',
#                '2020-09-15 14:45:00', '2020-09-16 14:45:00',
#                '2020-09-17 14:45:00'],
#               dtype='datetime64[ns]', freq='D')
# DatetimeIndex(['2020-09-11 14:45:00', '2020-09-11 14:45:01',
#                '2020-09-11 14:45:02', '2020-09-11 14:45:03',
#                '2020-09-11 14:45:04', '2020-09-11 14:45:05',
#                '2020-09-11 14:45:06', '2020-09-11 14:45:07',
#                '2020-09-11 14:45:08', '2020-09-11 14:45:09',
#                ...
#                '2020-09-11 15:44:50', '2020-09-11 15:44:51',
#                '2020-09-11 15:44:52', '2020-09-11 15:44:53',
#                '2020-09-11 15:44:54', '2020-09-11 15:44:55',
#                '2020-09-11 15:44:56', '2020-09-11 15:44:57',
#                '2020-09-11 15:44:58', '2020-09-11 15:44:59'],
#               dtype='datetime64[ns]', length=3600, freq='S')

# %% [markdown]
# To learn more about the frequency strings, please see this [link](http://pandas.pydata.org/pandas-docs/stable/timeseries.html#offset-aliases)
#
#
# Timestamped data is the most basic type of time series data that associates values with points in time. For pandas objects it means using the points in time.
#
# functions like `pd.to_datetime` can be used, for instance, when reading information as string from a dataset

# %%
tstamp = pd.Timestamp(dt.datetime(2020, 11, 9))

# internally it counts the nanoseconds from January 1st 19
#tstamp = pd.Timestamp(dt.datetime(1970, 1, 1, 0, 0, 0, 1))
print(tstamp.value)

# when creating a timestamp the format can be explicitly passed
ts = pd.to_datetime('2010/11/12', format='%Y/%m/%d')
print (type(ts))
print (ts)
ts = pd.to_datetime('12-11-2010 00:00', format='%d-%m-%Y %H:%M')
print (ts)
print (ts.value)
# Out:
# 1604880000000000000
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 2010-11-12 00:00:00
# 2010-11-12 00:00:00
# 1289520000000000000

# %% [markdown]
# A standard series can be created and (range of) elements can be used as indexes

# %%
tseries = pd.Series(np.random.normal(10, 1, len(days)), index=days)
# Extracting elements
print (tseries[0:4], '\n')
print (tseries['2020-9-11':'2020-11-11'], '\n') # Note - includes end time
# Out:
# 2020-09-11 14:45:00    11.467934
# 2020-09-12 14:45:00    10.870849
# 2020-09-13 14:45:00     9.729155
# 2020-09-14 14:45:00    10.450606
# Freq: D, dtype: float64
#
# 2020-09-11 14:45:00    11.467934
# 2020-09-12 14:45:00    10.870849
# 2020-09-13 14:45:00     9.729155
# 2020-09-14 14:45:00    10.450606
# 2020-09-15 14:45:00    11.644317
# 2020-09-16 14:45:00    11.418473
# 2020-09-17 14:45:00    12.012553
# Freq: D, dtype: float64

# %% [markdown]
# `pd.to_datetime` can also be used to create a `DatetimeIndex`:

# %%
pd.to_datetime([1, 2, 3, 4], unit='D', origin=pd.Timestamp('1980-02-03'))
# Out:
# DatetimeIndex(['1980-02-04', '1980-02-05', '1980-02-06', '1980-02-07'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## DataFrame
#
# A pandas DataFrame is like a simple tabular spreadsheet. For future reference (or for people already familiar with R), a pandas DataFrame is very similar to the R DataFrame.
#
# Each column in a DataFrame is a Series object.
#
# The element can be whatever, missing data are dealt with too (as NaN)

# %% [markdown]
# ### DataFrame creation
#
# A DataFrame can be created implicitly, with, e.g., a DatatimeIndex object as index:

# %%
entries=10
dates=pd.date_range('11/9/2020 14:45:00',freq='h', periods=entries)
df = pd.DataFrame(np.random.randn(entries,4), index=dates, columns=['A','B','C','D'])
df
# Out:
#                             A         B         C         D
# 2020-11-09 14:45:00 -1.506871 -0.070660  0.244426  0.304958
# 2020-11-09 15:45:00 -0.621287  0.319224  1.054339 -2.162325
# 2020-11-09 16:45:00 -0.306904  0.526743  0.912932  0.561229
# 2020-11-09 17:45:00  0.322092 -0.806109  0.133703 -0.803893
# 2020-11-09 18:45:00 -0.840765 -0.441135  0.113223 -0.250786
# 2020-11-09 19:45:00 -0.597688  1.234663 -0.579476  0.447045
# 2020-11-09 20:45:00  1.697386  0.114363  0.535038 -0.120407
# 2020-11-09 21:45:00  0.475338  1.975175 -0.133902 -0.219472
# 2020-11-09 22:45:00  1.087983 -0.350937 -0.345168  0.691863
# 2020-11-09 23:45:00  0.466976 -0.145367 -0.820518 -0.070321

# %% [markdown]
# or by means of a dictionary:

# %%
df2 = pd.DataFrame(
    { 'A' : 1.,
      'B' : pd.Timestamp('20130102'),
      'C' : pd.Series(1,index=range(4),dtype='float32'),
      'D' : np.arange(7,11),
      'E' : pd.Categorical(["test","train","test","train"]),
    }
    )
df2
# Out:
#      A          B    C   D      E
# 0  1.0 2013-01-02  1.0   7   test
# 1  1.0 2013-01-02  1.0   8  train
# 2  1.0 2013-01-02  1.0   9   test
# 3  1.0 2013-01-02  1.0  10  train

# %% [markdown]
# ### Viewing Data

# %%
df.head(2)
# Out:
#                             A         B         C         D
# 2020-11-09 14:45:00 -1.506871 -0.070660  0.244426  0.304958
# 2020-11-09 15:45:00 -0.621287  0.319224  1.054339 -2.162325

# %%
df.tail(4)
# Out:
#                             A         B         C         D
# 2020-11-09 20:45:00  1.697386  0.114363  0.535038 -0.120407
# 2020-11-09 21:45:00  0.475338  1.975175 -0.133902 -0.219472
# 2020-11-09 22:45:00  1.087983 -0.350937 -0.345168  0.691863
# 2020-11-09 23:45:00  0.466976 -0.145367 -0.820518 -0.070321

# %%
df.index
# Out:
# DatetimeIndex(['2020-11-09 14:45:00', '2020-11-09 15:45:00',
#                '2020-11-09 16:45:00', '2020-11-09 17:45:00',
#                '2020-11-09 18:45:00', '2020-11-09 19:45:00',
#                '2020-11-09 20:45:00', '2020-11-09 21:45:00',
#                '2020-11-09 22:45:00', '2020-11-09 23:45:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([
# 2020-11-09 22:45:00 -0.207212  1.766691
# 2020-11-09 23:45:00  1.937120 -1.244881

# %%
# showing label slicing, both endpoints are included:
df.loc['2020-11-09 18:45:00':'2020-11-09 20:45:00',['A','B']]
# Out:
#                             A         B
# 2020-11-09 18:45:00 -0.142798 -1.531724
# 2020-11-09 19:45:00 -0.484632 -0.887011
# 2020-11-09 20:45:00 -0.800991 -0.092105

# %%
# getting an individual element
print (df.loc[dates[1],'A'])

# equivalently
print (df.at[dates[1],'A'])
# Out:
# 1.1098202803213753
# 1.1098202803213753

# %% [markdown]
# ### Selecting by position

# %%
# select via the position of the passed integers:
print (df.iloc[3],'\n')

# notation similar to numpy/python
print (df.iloc[3:5,0:2])
# Out:
# A    2.232818
# B    0.868361
# C   -0.501061
# D    0.073010
# Name: 2020-11-09 17:45:00, dtype: float64
#
#                             A         B
# 2020-11-09 17:45:00  2.232818  0.868361
# 2020-11-09 18:45:00 -0.142798 -1.531724

# %%
# selecting raws 1,2 and 4 for columns 0 and 2
df.iloc[[1,2,4],[0,2]]
# Out:
#                             A         C
# 2020-11-09 15:45:00  1.109820  1.191852
# 2020-11-09 16:45:00  1.331603  0.888289
# 2020-11-09 18:45:00 -0.142798  0.628306

# %%
# slicing rows explicitly
print (df.iloc[1:3,:],'\n')

# slicing columns explicitly
print (df.iloc[:,1:3])
# Out:
#                             A         B         C         D
# 2020-11-09 15:45:00  1.109820  0.322345  1.191852  1.176413
# 2020-11-09 16:45:00  1.331603  1.033331  0.888289  0.509745
#
#                             B         C
# 2020-11-09 14:45:00  0.092392  0.016491
# 2020-11-09 15:45:00  0.322345  1.191852
# 2020-11-09 16:45:00  1.033331  0.888289
# 2020-11-09 17:45:00  0.868361 -0.501061
# 2020-11-09 18:45:00 -1.531724  0.628306
# 2020-11-09 19:45:00 -0.887011 -0.731823
# 2020-11-09 20:45:00 -0.092105  0.332445
# 2020-11-09 21:45:00  0.469820 -2.384792
# 2020-11-09 22:45:00  1.766691 -2.155176
# 2020-11-09 23:45:00 -1.244881  0.838765

# %%
# selecting an individual element by position
df.iloc[1,1]
df.iat[1,1]
# Out:
# 0.32234454370522553

# %% [markdown]
# ### Boolean index
#
# Very powerful way of filtering out data with certain features. Notation is very similar to numpy arrays.

# %%
# Filter by a boolean condition on the values of a single column
df[df['B'] > 0]
# Out:
#                             A         B         C         D
# 2020-11-09 14:45:00 -0.289615  0.092392  0.016491  0.377073
# 2020-11-09 15:45:00  1.109820  0.322345  1.191852  1.176413
# 2020-11-09 16:45:00  1.331603  1.033331  0.888289  0.509745
# 2020-11-09 17:45:00  2.232818  0.868361 -0.501061  0.073010
# 2020-11-09 21:45:00 -0.350264  0.469820 -2.384792  0.055280
# 2020-11-09 22:45:00 -0.207212  1.766691 -2.155176 -0.653786

# %%
# Selecting on the basis of boolean conditions applied to the whole DataFrame
df[df>0]

# a DataFrame with the same shape is returned, with NaN's where condition is not met
# Out:
#                             A         B         C         D
# 2020-11-09 14:45:00       NaN  0.092392  0.016491  0.377073
# 2020-11-09 15:45:00  1.109820  0.322345  1.191852  1.176413
# 2020-11-09 16:45:00  1.331603  1.033331  0.888289  0.509745
# 2020-11-09 17:45:00  2.232818  0.868361       NaN  0.073010
# 2020-11-09 18:45:00       NaN       NaN  0.628306       NaN
# 2020-11-09 19:45:00       NaN       NaN       NaN  0.613445
# 2020-11-09 20:45:00       NaN       NaN  0.332445  0.869749
# 2020-11-09 21:45:00       NaN  0.469820       NaN  0.055280
# 2020-11-09 22:45:00       NaN  1.766691       NaN       NaN
# 2020-11-09 23:45:00  1.937120       NaN  0.838765       NaN

# %% [markdown]
# ### Setting
#
# Combination of selection and setting of values

# %%
# setting values by label (same as by position)
df.at[dates[0],'A'] = 0

# setting and assigning a numpy array
df.loc[:,'D'] = np.array([5] * len(df))

# defining a brend new column
df['E'] = np.arange(len(df))*0.5

# defining a brend new column by means of a pd.Series: indexes must be the same!
df['E prime'] = pd.Series(np.arange(len(df))*2, index=df.index)
# Out:
#                             A         B         C  D    E  E prime
# 2020-11-09 14:45:00  0.000000  0.092392  0.016491  5  0.0        0
# 2020-11-09 15:45:00  1.109820  0.322345  1.191852  5  0.5        2
# 2020-11-09 16:45:00  1.331603  1.033331  0.888289  5  1.0        4
# 2020-11-09 17:45:00  2.232818  0.868361 -0.501061  5  1.5        6
# 2020-11-09 18:45:00 -0.142798 -1.531724  0.628306  5  2.0        8
# 2020-11-09 19:45:00 -0.484632 -0.887011 -0.731823  5  2.5       10
# 2020-11-09 20:45:00 -0.800991 -0.092105  0.332445  5  3.0       12
# 2020-11-09 21:45:00 -0.350264  0.469820 -2.384792  5  3.5       14
# 2020-11-09 22:45:00 -0.207212  1.766691 -2.155176  5  4.0       16
# 2020-11-09 23:45:00  1.937120 -1.244881  0.838765  5  4.5       18

# %%
def dcos(theta):
    theta = theta*(np.pi/180)
    return np.cos(theta)
 
df['cosine'] = pd.Series(df["E"].apply(dcos), index=df.index)
df
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2020-11-09 14:45:00  0.000000  0.092392  0.016491  5  0.0        0  1.000000
# 2020-11-09 15:45:00  1.109820  0.322345  1.191852  5  0.5        2  0.999962
# 2020-11-09 16:45:00  1.331603  1.033331  0.888289  5  1.0        4  0.999848
# 2020-11-09 17:45:00  2.232818  0.868361 -0.501061  5  1.5        6  0.999657
# 2020-11-09 18:45:00 -0.142798 -1.531724  0.628306  5  2.0        8  0.999391
# 2020-11-09 19:45:00 -0.484632 -0.887011 -0.731823  5  2.5       10  0.999048
# 2020-11-09 20:45:00 -0.800991 -0.092105  0.332445  5  3.0       12  0.998630
# 2020-11-09 21:45:00 -0.350264  0.469820 -2.384792  5  3.5       14  0.998135
# 2020-11-09 22:45:00 -0.207212  1.766691 -2.155176  5  4.0       16  0.997564
# 2020-11-09 23:45:00  1.937120 -1.244881  0.838765  5  4.5       18  0.996917

# %%
# another example of global setting
df2=df.copy()
df2[df2>0] = -df2
df2
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2020-11-09 14:45:00  0.000000 -0.092392 -0.016491 -5  0.0        0 -1.000000
# 2020-11-09 15:45:00 -1.109820 -0.322345 -1.191852 -5 -0.5       -2 -0.999962
# 2020-11-09 16:45:00 -1.331603 -1.033331 -0.888289 -5 -1.0       -4 -0.999848
# 2020-11-09 17:45:00 -2.232818 -0.868361 -0.501061 -5 -1.5       -6 -0.999657
# 2020-11-09 18:45:00 -0.142798 -1.531724 -0.628306 -5 -2.0       -8 -0.999391
# 2020-11-09 19:45:00 -0.484632 -0.887011 -0.731823 -5 -2.5      -10 -0.999048
# 2020-11-09 20:45:00 -0.800991 -0.092105 -0.332445 -5 -3.0      -12 -0.998630
# 2020-11-09 21:45:00 -0.350264 -0.469820 -2.384792 -5 -3.5      -14 -0.998135
# 2020-11-09 22:45:00 -0.207212 -1.766691 -2.155176 -5 -4.0      -16 -0.997564
# 2020-11-09 23:45:00 -1.937120 -1.244881 -0.838765 -5 -4.5      -18 -0.996917

# %% [markdown]
# ### Dropping
#
# N.B.: dropping doesn't act permanently on the DataFrame, i.e. to get that do :
# ```python
# df = df.drop(....)
# ```

# %%
# Dropping by column
df.drop(['E prime'], axis=1)

#which is equivalent to
df.drop(columns=['E prime'])
# Out:
#                             A         B         C  D    E    cosine
# 2020-11-09 14:45:00  0.000000  0.092392  0.016491  5  0.0  1.000000
# 2020-11-09 15:45:00  1.109820  0.322345  1.191852  5  0.5  0.999962
# 2020-11-09 16:45:00  1.331603  1.033331  0.888289  5  1.0  0.999848
# 2020-11-09 17:45:00  2.232818  0.868361 -0.501061  5  1.5  0.999657
# 2020-11-09 18:45:00 -0.142798 -1.531724  0.628306  5  2.0  0.999391
# 2020-11-09 19:45:00 -0.484632 -0.887011 -0.731823  5  2.5  0.999048
# 2020-11-09 20:45:00 -0.800991 -0.092105  0.332445  5  3.0  0.998630
# 2020-11-09 21:45:00 -0.350264  0.469820 -2.384792  5  3.5  0.998135
# 2020-11-09 22:45:00 -0.207212  1.766691 -2.155176  5  4.0  0.997564
# 2020-11-09 23:45:00  1.937120 -1.244881  0.838765  5  4.5  0.996917

# %%
# Dropping by raws
# safe and always working
df.drop(df.index[[1,2,3,4]])
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2020-11-09 14:45:00  0.000000  0.092392  0.016491  5  0.0        0  1.000000
# 2020-11-09 19:45:00 -0.484632 -0.887011 -0.731823  5  2.5       10  0.999048
# 2020-11-09 20:45:00 -0.800991 -0.092105  0.332445  5  3.0       12  0.998630
# 2020-11-09 21:45:00 -0.350264  0.469820 -2.384792  5  3.5       14  0.998135
# 2020-11-09 22:45:00 -0.207212  1.766691 -2.155176  5  4.0       16  0.997564
# 2020-11-09 23:45:00  1.937120 -1.244881  0.838765  5  4.5       18  0.996917

# %%
# something like df.drop('index_name') 
# would work but the type of index must be specificed, 
# in particular with DatetimeIndex
df.drop(pd.to_datetime("2020-11-09 22:45:00"))
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2020-11-09 14:45:
df
# Out:
#                             A         B         C  D    E  E prime    cosine
# 2020-11-09 14:45:00  0.000000  0.092392  0.016491  5  0.0        0  1.000000
# 2020-11-09 15:45:00  1.109820  0.322345  1.191852  5  0.5        2  0.999962
# 2020-11-09 16:45:00  1.331603  1.033331  0.888289  5  1.0        4  0.999848
# 2020-11-09 17:45:00  2.232818  0.868361 -0.501061  5  1.5        6  0.999657
# 2020-11-09 18:45:00 -0.142798 -1.531724  0.628306  5  2.0        8  0.999391
# 2020-11-09 19:45:00 -0.484632 -0.887011 -0.731823  5  2.5       10  0.999048
# 2020-11-09 20:45:00 -0.800991 -0.092105  0.332445  5  3.0       12  0.998630
# 2020-11-09 21:45:00 -0.350264  0.469820 -2.384792  5  3.5       14  0.998135
# 2020-11-09 22:45:00 -0.207212  1.766691 -2.155176  5  4.0       16  0.997564
# 2020-11-09 23:45:00  1.937120 -1.244881  0.838765  5  4.5       18  0.996917

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A           3.033809
# B           3.298415
# C           3.576645
# D           0.000000
# E           4.500000
# E prime    18.000000
# cosine      0.003083
# dtype: float64

# %%
# syntax is as usual similar to that of numpy arrays
df['A']+df['B']
# Out:
# 2020-11-09 14:45:00    0.092392
# 2020-11-09 15:45:00    1.432165
# 2020-11-09 16:45:00    2.364934
# 2020-11-09 17:45:00    3.101179
# 2020-11-09 18:45:00   -1.674522
# 2020-11-09 19:45:00   -1.371643
# 2020-11-09 20:45:00   -0.893096
# 2020-11-09 21:45:00    0.119556
# 2020-11-09 22:45:00    1.559479
# 2020-11-09 23:45:00    0.692238
# Freq: H, dtype: float64

# %% [markdown]
# Let's play it hard and load (in memory) a (relatively) large dataset

# %%
# WARNING! link in past notebook was wrong!, (if needed) get the right file from:
# !wget https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt -P ~/data/


file_name="/data/data_000637.txt"
data=pd.read_csv(file_name)
data
# Out:
# --2020-11-09 15:59:35--  https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt
# Resolving www.dropbox.com... 162.125.69.1
# Connecting to www.dropbox.com|162.125.69.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/xvjzaxzz3ysphme/data_000637.txt [following]
# --2020-11-09 15:59:36--  https://www.dropbox.com/s/raw/xvjzaxzz3ysphme/data_000637.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc2bf07f112d2f4c30ca966ff481.dl.dropboxusercontent.com/cd/0/inline/BC7GLc7Lx3nzg7zER_eY01aWYfhgN_7v-khpNSlmS0FQYFRpCkPZUi5bv75QuXSFONF-GatRtOYDZd0CEBMNAgTmcIpXt-QrDpk8pI8-biB7KZO8AnPoQeBP8jUwPvsmGEw/file# [following]
# --2020-11-09 15:59:36--  https://uc2bf07f112d2f4c30ca966ff481.dl.dropboxusercontent.com/cd/0/inline/BC7GLc7Lx3nzg7zER_eY01aWYfhgN_7v-khpNSlmS0FQYFRpCkPZUi5bv75QuXSFONF-GatRtOYDZd0CEBMNAgTmcIpXt-QrDpk8pI8-biB7KZO8AnPoQeBP8jUwPvsmGEw/file
# Resolving uc2bf07f112d2f4c30ca966ff481.dl.dropboxusercontent.com... 162.125.69.15
# Connecting to uc2bf07f112d2f4c30ca966ff481.dl.dropboxusercontent.com|162.125.69.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33179236 (32M) [text/plain]
# Saving to: '/Users/mattiaceravolo/data/data_000637.txt.1'
#
# data_000637.txt.1   100%[===================>]  31.64M   288KB/s    in 1m 54s
#
# 2020-11-09 16:01:31 (285 KB/s) - '/Users/mattiaceravolo/data/data_000637.txt.1' saved [33179236/33179236]
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-73-bf677f4488ee> in <module>
#       4
#       5 file_name="~/data/data_000637.txt"
# ----> 6 data=pd.read_csv(file_name)
#       7 data
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xdb in position 0: invalid continuation byte

# %% [markdown]
# Let's now do some operations among (elements of) columns

# %%
# the one-liner killing it all
data['timens']=data['TDC_MEAS']*25/30+data['BX_COUNTER']*25

# %%
# the old slooow way
def conversion(data):
    result=[]
    for i in range(len(data)): 
        result.append(data.loc[data.index[i],'TDC_MEAS']*25/30.+data.loc[data.index[i],'BX_COUNTER']*25)
    return result

data['timens']=conversion(data)

# %% [markdown]
# ## Merge
#
# pandas provides various facilities for easily combining together Series, DataFrame, and Panel objects with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.
#
# ### Concat
#
# concatenation (adding rows) is straightforward

# %%
rdf = pd.DataFrame(np.random.randn(10, 4))
rdf

# %%
# divide it into pieaces raw-wise
pieces = [rdf[:3], rdf[3:7], rdf[7:]]
pieces

# %%
# put it back together
#pd.concat(pieces)

# indexes can be ignored
pd.concat(pieces, ignore_index=True)

# in case of dimension mismatch, Nan are added where needed

# %%
# appending a single row (as a Series)
s = rdf.iloc[3]
rdf.append(s, ignore_index=True)
rdf

# %% [markdown]
# ### Merge/Join
#
# SQL like operations on table can be performed on DataFrames. This is all rather sophisticated, refer to the [doc](https://pandas.pydata.org/pandas-docs/stable/merging.html#merging) for more info/examples

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})

pd.merge(left,right,on="key")

# %% [markdown]
# ## Grouping
#
# By “group by” we are referring to a process involving one or more of the following steps:
#
# * Splitting the data into groups based on some criteria
# * Applying a function to each group independently
# * Combining the results into a data structure

# %%
gdf = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
                          'foo', 'bar', 'foo', 'foo'],
                    'B' : ['one', 'one', 'two', 'three',
                           'two', 'two', 'one', 'three'],
                    'C' : np.random.randn(8),
                    'D' : np.random.randn(8)})
gdf

# %%
# Grouping and then applying the sum() 
# function to the resulting groups (effective only where number are there).
gdf.groupby('A').sum()

# %% [markdown]
# ## Multi-indexing
#
#
# Hierarchical / Multi-level indexing allows sophisticated data analysis on higher dimensional data. In essence, it enables you to store and manipulate data with an arbitrary number of dimensions in lower dimensional data structures like Series (1d) and DataFrame (2d).

# %%
tuples = list(zip(['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'],
          ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']))
multi_index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
print (multi_index,'\n')

s = pd.Series(np.random.randn(8), index=multi_index)
print (s)

# %%
# it enables further features of the groupby method,
# e.g. when group-by by multiple columns
gdf.groupby(['A','B']).sum()

# %%
# stack() method “compresses” a level in the DataFrame’s columns
gdf.groupby(['A','B']).sum().stack()

# %% [markdown]
# ## Plotting
#
# Just a preview, more on the next lab class!

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts.cumsum().plot()

# %%
import matplotlib.pyplot as plt

pdf=pd.DataFrame(np.random.randn(1000, 4), index=ts.index,columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
plt.figure(); df.plot(); plt.legend(loc='best')
