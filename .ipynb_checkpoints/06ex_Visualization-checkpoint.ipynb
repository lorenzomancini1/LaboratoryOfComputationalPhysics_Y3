# %% [markdown]
# 1\. **Kernel Density Estimate**
#
# Produce a KDE for a given distribution (by hand, not using seaborn!):
#
# * Fill a numpy array, x,  of len(N) (with N=O(100)) with a variable normally distributed, with a given mean a standard deviation
# * Fill an histogram in pyplot taking properly care about the aesthetic
#    * use a meaningful number of bins
#    * set a proper y axis label
#    * set proper value of y axis major ticks labels (e.g. you want to display only integer labels)
#    * display the histograms as data points with errors (the error being the poisson uncertainty)
# * for every element of x, create a gaussian with the mean corresponding the element value and std as a parameter that can be tuned. The std default value should be:
# $$ 1.06 * x.std() * x.size ^{-\frac{1}{5.}} $$
# you can use the scipy function `stats.norm()` for that.
# * In a separate plot (to be placed beside the original histogram), plot all the gaussian functions so obtained
# * Sum (with np.sum()) all the gaussian functions and normalize the result such that the integral matches the integral of the original histogram. For that you could use the `scipy.integrate.trapz()` method

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline

import numpy as np
import numpy.random as npr
from scipy import stats
import scipy

# %%
#parameters definition:

mu = 0.
sigma = 1.
N = 100

# %%
x = np.random.randn(N)*sigma + mu

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

entries, edges, _ = ax1.hist(x, bins=13,range = [-3,3], label='x', color='c')
bin_centers = 0.5 * (edges[:-1] + edges[1:])
ax1.errorbar(bin_centers, entries, yerr=(1/np.sqrt(entries)), fmt='r.', label='err')
ax1.set_title("Gaussian hist", fontsize=10, verticalalignment='bottom')
ax1.set_xlabel("x")
ax1.set_ylabel("counts")
ax1.set_xlim(-4, 4)
ax1.set_ylim(0, 30)
ax1.legend()




#define funcion for standard deviation

def Sigma(x,s):
    y = 1.06*s*pow(np.size(x),-0.2)
    return y

X = np.linspace(-2.5,2.5,100)
Y = []
for i in range(N):
    Y.append(stats.norm.pdf(X, loc=x[i], scale = Sigma(x,sigma)**2))
ax2.plot(X, Y, '-r', lw=1, alpha=0.2, label='norm pdf')
ax2.set_title('gaussian functon, random mean',fontsize=10, verticalalignment='bottom')
ax2.set_xlabel('x')
ax2.set_ylabel('g(x)')
ax2.yaxis.tick_right()
ax2.yaxis.set_label_position("right")





I1 = N                   #original hist integral equal to number of entries
I2 = np.sum(scipy.integrate.trapz(Y))   #sum integral of all pdfs
k = I2/I1   #resize factor

for i in range(len(Y)): Y[i]*=k   #resize gaussian distributions array
# Out:
# <ipython-input-32-b8a6f1adf0b7>:5: RuntimeWarning: divide by zero encountered in true_divide
#   ax1.errorbar(bin_centers, entries, yerr=(1/np.sqrt(entries)), fmt='r.', label='err')

# %% [markdown]
# 2\. **Color-coded scatter plot**
#
# Produce a scatter plot out of a dataset with two categories
#
# * Write a function that generate a 2D datasets of 2 categories. Each category should distribute as a 2D gaussian with a given mean and std (clearly it is better to have different values means..)
# * Display the dataset in a scatter plot marking the two categories with different marker colors.
#
# An example is given below
#
# You can try to make the procedure more general by allowing a given number $n\ge 2$ of categories

# %%
def gen(mu, sigma, n):
    x = np.random.multivariate_normal(mu, sigma, n)
    return x

mu_x = [9.0, 12.0]
sigma_x = [[0.4,0.2],[0.2,0.3]]
mu_y = [11.0, 11.0]
sigma_y = [[0.6,0.1],[0.1,0.2]]
n = 1000
X = gen(mu_x, sigma_x, n)    #generate first array
Y = gen(mu_y, sigma_y, n)    #generate second array

# %%
import matplotlib.patches as mpatches

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(1, 1, 1, aspect=1)
ax.scatter(x=X[:,0], y=X[:,1], c='red', label='red variable')
ax.scatter(x=Y[:,0], y=Y[:,1], c='gold', label='gold variable')

ax.set_xlabel('$x_1$',fontsize=15)
ax.set_ylabel('$x_2$',fontsize=15)
ax.set_title('Simulation of two normally distributed variables',fontsize=15)

ax.tick_params(which='major', width=1.0)
ax.tick_params(which='major', length=5)
ax.tick_params(which='minor', width=1.0)
ax.tick_params(which='minor', length=5)

ax.set_xlim(6, 14)
ax.set_ylim(9, 14)

ax.plot([6, 14], [12, 12], color='red', linestyle=':', linewidth=1,label='red mean')
ax.plot([9, 9], [6, 14], color='red', linestyle=':', linewidth=1)
ax.plot([6, 14], [11, 11], color='gold', linestyle=':', linewidth=1, label = 'gold mean')
ax.plot([11, 11], [6, 14], color='gold', linestyle=':', linewidth=1)

plt.legend(prop={'size': 14})


plt.show()

# %%
#! wget https://www.dropbox.com/s/u4y3k4kk5tc7j46/two_categories_scatter_plot.png
from IPython.display import Image
Image('two_categories_scatter_plot.png')

# %% [markdown]
# 3\. **Profile plot**
#
# Produce a profile plot from a scatter plot.
# * Download the following dataset and load it as a pandas dataframe:
# ```bash
# wget https://www.dropbox.com/s/hgnvyj9abatk8g6/residuals_261.npy
# ```
# Note that you should use the `np.load()` function to load the file as a numpy array, call the `.item()` method, and then pass it to the `pd.DataFrame()` constructor.
# * Inspect the dataset, you'll find two variables (features)
# * Clean the sample by selecting the entries (rows) with the variable "residual" in absolute value smaller than 2
# * perform a linear regression of "residuals" versus "distances" using `scipy.stats.linregress()`
# * plot a seaborn jointplot of  "residuals" versus "distances", having seaborn performing a linear regression. The result of the regression should be displayed on the plot
# * Fill 3 numpy arrays
#   * x, serving as an array of bin centers for the "distance" variable. It should range from 0 to 20 with reasonable number of steps (bins)
#   * y, the mean values of the "residuals", estimated in slices (bins) of "distance"
#   * erry, the standard deviation of the  of the "residuals", estimated in slices (bins) of "distance"
# * Plot the profile plot on top of the scatter plot

# %%
#! wget https://www.dropbox.com/s/hgnvyj9abatk8g6/residuals_261.npy

# %%
import pandas as pd

datafile = '/Users/ale/LaboratoryOfComputationalPhysics_Y3/residuals_261.npy'

data = np.load(datafile, allow_pickle=True)
df = pd.DataFrame(data.item())
df = df[abs(df['residuals']) < 2.]
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(df.distances,df.residuals)

# %%
import seaborn as sns

# %%
sns.jointplot(data=df, x="distances", y="residuals", kind="reg", color='lightgreen', line_kws={"color": "magenta","linewidth":3,"label":'sns reg'})

bin_edges = np.histogram_bin_edges(df.distances, bins="auto", range = (0,20))
n = len(bin_edges)

x = np.empty(n-1)
y = np.empty(n-1)
erry = np.empty(n-1)
for i in range(n-1):
    dfi = df[(df['distances'] > bin_edges[i]) & (df['distances'] < bin_edges[i+1])]
    x[i] = np.mean([bin_edges[i],bin_edges[i+1]])
    y[i] = np.mean(dfi.residuals)
    erry[i] = np.std(dfi.residuals)

plt.errorbar(x,y,yerr=erry,ecolor = 'blue', label = 'erry', marker='o', mfc='red',
         mec='black', ms=1, mew=4, capsize = 2)
X = np.array([df.distances.min(),df.distances.max()])
plt.plot(X, intercept + slope*X, color = 'gold', linestyle = ':', linewidth = 3, label='scipy fit')
plt.legend()
