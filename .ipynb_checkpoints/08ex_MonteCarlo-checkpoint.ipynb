# %% [markdown]
# 1\. **Radioactive decay chain**
#
# ${\rm Tl}^{208}$ decays to ${\rm Pb}^{208}$ with a half-lieve of 3.052 minutes. Suppose to start with a sample of 1000 Thallium atoms and 0 of Lead atoms.
#
# * Take steps in time of 1 second and at each time-step decide whether each Tl atom has decayed or not, accordingly to the probability $p(t)=1-2^{-t/\tau}$. Subtract the total number of Tl atoms that decayed at each step from the Tl sample and add them to the Lead one. Plot the evolution of the two sets as a function of time
# * Repeat the exercise by means of the inverse transform method: draw 1000 random numbers from the non-uniform probability distribution $p(t)=2^{-t/\tau}\frac{\ln 2}{\tau}$ to represent the times of decay of the 1000 Tl atoms. Make a plot showing the number of atoms that have not decayed as a function of time

# %%
import numpy as np
import pandas as pd
from scipy import stats


import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %precision 4


tau = 3052

def p(t, tau):
    return 1-2**(-t/tau)

x = np.arange(10000)
prob_disp = p(x,tau)


record_decayed = []
tallium = pd.DataFrame(np.random.uniform(size=(1000,1)))
for t in range(10000):
    prob = p(t, tau)
    tallium_len = len(tallium)
    tallium[tallium.iloc[:,0]<prob] = -1
    tallium = tallium.drop(tallium[tallium[0] == -1].index)
    decayed = tallium_len - len(tallium)
    record_decayed.append(decayed)

record_lead = np.cumsum(record_decayed)
record_tallium = 1000-record_lead

fig, ax = plt.subplots(figsize=(8,5))
ax.plot(record_lead, label='lead')
ax.plot(record_tallium, label='tallium')
ax.set_xlabel("time")
ax.set_ylabel("atoms")
ax.legend()

# %%
def inverse(t, tau):
    return -tau*np.log2(1 - t) 

u = np.random.random(2000)
v = inverse(u, 3052*60)

plt.hist(v, histtype='step', label='Tallium')
plt.plot(np.sort(inverse(u, 3052*60)), (1-(np.sort(u)))*1000, label='inverse cdf')
plt.legend()
plt.grid(linestyle=':', color='lightgray')

# %% [markdown]
# 2\. **Rutherford Scattering**
#
# The scattering angle $\theta$ of $\alpha$ particles hitting a positively charged nucleus of a Gold atom ($Z=79$) follows the rule:
#
# $$
# \tan{\frac{1}{2} \theta} = \frac{Z e^2} {2\pi \epsilon_0 E b}
# $$
#
# where $E=7.7$ MeV and $b$ beam is the impact parameter. The beam is represented by a 2D gaussian distribution with $\sigma=a_0/100$ for both coordinates ($a_0$ being the Bohr radius). Assume 1 million $\alpha$ particles are shot on the gold atom.
#
# Computing the fraction of particles that "bounce back",i.e. those particle whose scattering angle is greater than $\pi/2$ (which set a condition on the impact parameter $b$)

# %%
E = 7.7 * 1.60218e-13
a = 5.29e-11 
eps_0 = 8.85e-12 
sigma = a/100
n = int(1e6) 
Z = 79 
e = -1.6e-19

z = np.random.random(n)
the = 2*np.pi*np.random.random(n)
r = np.sqrt(-2*np.log(z))
x = r*np.cos(the)*sigma
y = r*np.sin(the)*sigma

b = np.array(np.linalg.norm(np.array(list(zip(x, y))), axis=1)) 

theta = 2*np.arctan((Z*e**2)/(2*np.pi*eps_0*E*b)) 

bounce_back = np.sum(theta > np.pi/2)/n 

print(bounce_back)
# Out:
# 0.001563

# %% [markdown]
# 3\. **Monte Carlo integration: hit/miss vs mean value method**
#
# Consider the function
#
# $$f(x) =\sin^2{\frac{1}{x(2-x)}}$$
#
# * Compute the integral of $f(x)$ between 0 and 2 with the hit/miss method. Evaluate the error of your estimate
# * Repeat the integral with the mean value method. Evaluate the error and compare it with the previous one

# %%
def func(x):
    return (np.sin(1/(x*(2-x))))**2
interval = [0,2]
N = 10000

x = np.random.random(N)*(interval[1]-interval[0])
y = np.random.random(N)
hit_miss = (interval[1]-interval[0])*np.sum(func(x))/N

I = np.trapz(func(x), x)

print('integral of f(x) between 0 and 2 with the hit/miss method', hit_miss, ' and error is ',np.abs(I-hit_miss))


x = 2*np.random.random(N)
mean_value = (interval[1]-interval[0])*np.sum(func(x))/N

print('integral with mean value method', mean_value, 'and error is', np.abs(I-mean_value))
print('The mean value method is slightly more precise than the hit/miss method')
# Out:
# integral of f(x) between 0 and 2 with the hit/miss method 1.450207536578041  and error is  14.695254998024009
# integral with mean value method 1.4481976117201143 and error is 14.693245073166082
# The mean value method is slightly more precise than the hit/miss method

# %% [markdown]
# 4\. **Monte Carlo integration in high dimension**
#
# * Start of by computing the area of a circle of unit radius, by integrating the function
#
# $$
# f(x,y)=
# \left\{
# \begin{array}{ll}
#       1 & x^2+y^2\le 1 \\
#       0 & {\rm elsewhere}
# \end{array}
# \right.
# $$
#
# * Generalize the result for a 10D sphere

# %%
def func(x,y):
    result = np.zeros(np.shape(x))
    result[x**2+y**2 <= 1] = 1
    return result
    
N = 10000000
def func_2d():
    x = np.random.uniform(-1,1,(1,N))
    y = np.random.uniform(-1,1,(1,N))
    return 2**2*np.sum(func(x,y))/N

print("2d circle area: ",func_2d())


def func(x):
    return np.sum(x**2, axis=0) <= 1

def integral(dim):
    x = np.random.uniform(-1,1, (dim, N))
    return 2**dim*np.sum(func(x))/N

N = 1000000

print("integral 10d sphere:" ,integral(10))
# Out:
# 2d circle area:  3.141956
# integral 10d sphere: 2.59072

# %% [markdown]
# 5\. **Monte Carlo integration with importance sampling**
#
# Calculate the value of the integral:
#
# $$
# I=\int_0^1 \frac{x^{-1/2}}{e^x+1} dx
# $$
#
# using the importance sampling method with $w(x)=1/\sqrt{x}$. You should get a result about 0.84
