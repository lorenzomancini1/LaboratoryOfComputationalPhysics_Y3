# %% [markdown]
# 1\. **Radioactive decay chain**
#
# ${\rm Tl}^{208}$ decays to ${\rm Pb}^{208}$ with a half-lieve of 3.052 minutes. Suppose to start with a sample of 1000 Thallium atoms and 0 of Lead atoms.
#
# * Take steps in time of 1 second and at each time-step decide whether each Tl atom has decayed or not, accordingly to the probability $p(t)=1-2^{-t/\tau}$. Subtract the total number of Tl atoms that decayed at each step from the Tl sample and add them to the Lead one. Plot the evolution of the two sets as a function of time
# * Repeat the exercise by means of the inverse transform method: draw 1000 random numbers from the non-uniform probability distribution $p(t)=2^{-t/\tau}\frac{\ln 2}{\tau}$ to represent the times of decay of the 1000 Tl atoms. Make a plot showing the number of atoms that have not decayed as a function of time

# %%
import numpy as np
from scipy import linalg as la
import matplotlib.pyplot as plt
from scipy.interpolate import UnivariateSpline
from scipy import optimize
import pandas as pd
from scipy import integrate

# %%
decay_time=3.052*60
time=np.arange(1,100)
n_tl=[1000]
n_pb=[0]

for t in time:
    cas_ev=np.random.random(n_tl[t-1])
    prob=1-2**(-t/decay_time)
    decays_number=cas_ev.copy()
    mask=cas_ev<(prob)
    decays_number[mask]=1
    decays_number[decays_number!=1]=0
    tot_dec=int(np.sum(decays_number))
    n_tl.append(n_tl[t-1]-tot_dec)
    n_pb.append(n_pb[t-1]+tot_dec)

t_t=np.arange(0,100)
plt.plot(t_t,n_tl,label='Tallium')
plt.plot(t_t,n_pb,label='Lead')

plt.xlabel('Time')
plt.ylabel('Abundance')
plt.legend()

# %%
def f_prob (t):
    return 2**(-t/decay_time)*np.log(2)/decay_time

def cum_prob (t):
    return 1-2**(-t/decay_time)

def inv_cum_prob (x):
    return -np.log(1-x)*decay_time/np.log(2)

cas_n=np.random.random(10000)
mc_decays=inv_cum_prob(cas_n)

prob_time=np.linspace(0,2500,10000)

plt.hist(mc_decays,histtype='step', bins=100, density=True, linewidth=2)
plt.plot(prob_time,f_prob(prob_time))
plt.xlim(0,2500)
plt.xlabel('Time')
plt.ylabel('Number of decays')
# Out:
# Text(0, 0.5, 'Number of decays')

# %% [markdown]
# 2\. **Rutherford Scattering**
#
# The scattering angle $\theta$ of $\alpha$ particles hitting a positively charged nucleus of a Gold atom ($Z=79$) follows the rule:
#
# $$
# \tan{\frac{1}{2} \theta} = \frac{Z e^2} {2\pi \epsilon_0 E b}
# $$
#
# where $E=7.7$ MeV and $b$ beam is the impact parameter. The beam is represented by a 2D gaussian distribution with $\sigma=a_0/100$ for both coordinates ($a_0$ being the Bohr radius). Assume 1 million $\alpha$ particles are shot on the gold atom.
#
# Computing the fraction of particles that "bounce back",i.e. those particle whose scattering angle is greater than $\pi/2$ (which set a condition on the impact parameter $b$)

# %%
a0=5.29e-11
sigma=a0/100
p_n=10000
x=np.random.normal(0,sigma,p_n)
y=np.random.normal(0,sigma,p_n)
b=np.sqrt(x**2+y**2)
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.hist(b,bins=50)
plt.title('Distances form the center')

def scatt_angle (b,Z=89,e=1.6021e-19,e0=8.85e-12,E=7.7*1.6021e-19*(10**6)):
    return 2*np.arctan((Z*e**2)/(2*np.pi*e0*E*b))

plt.subplot(122)
plt.hist(scatt_angle(b),bins=100)
plt.title('Scattering angles')

print('Fraction of bounced particles: ',int(scatt_angle(b)[scatt_angle(b)>(np.pi/2)].size)/p_n, ' = ', int(scatt_angle(b)[scatt_angle(b)>(np.pi/2)].size), ' over ', p_n)
# Out:
# Fraction of bounced particles:  0.0017  =  17  over  10000

# %% [markdown]
# 3\. **Monte Carlo integration: hit/miss vs mean value method**
#
# Consider the function
#
# $$f(x) =\sin^2{\frac{1}{x(2-x)}}$$
#
# * Compute the integral of $f(x)$ between 0 and 2 with the hit/miss method. Evaluate the error of your estimate
# * Repeat the integral with the mean value method. Evaluate the error and compare it with the previous one

# %%
def f (x):
    return np.sin(1/(x*(2-x)))**2

N_list=[100,1000,10000,100000,1000000]

print('Miss/hit method')
mhm=[]
for N in N_list:
    count=0
    for i in range(N):
        x=2*np.random.random()
        y=np.random.random()
        if y<f(x): count+=1
    I=2*count/N
    print('For N=',N, 'Integral=',I)
    mhm.append(I)
    
print('Mean value method')
mvm=[]
for N in N_list:
    x=np.random.random(N)*2
    I=((2-0)/N)*np.sum(f(x))
    print('For N=',N, 'Integral=',I)
    mvm.append(I)
    

x_int=np.sort(np.random.random(100000)*2)
corr_int=integrate.quad(f,0,2)
print('\n', 'Precise integral: ', corr_int[0],'error: ', corr_int[1], '\n')

print('Differences:')
i=0
dmhm,dmvm=[],[]
for N in N_list:
    print('For N=',N, 'delta_mhm=',corr_int[0]-mhm[i],' delta_mvm=',corr_int[0]-mvm[i])
    dmhm.append(corr_int[0]-mhm[i])
    dmvm.append(corr_int[0]-mvm[i])
    i+=1
    
plt.plot(np.log10(N_list),dmhm,label='Miss/hit')
plt.plot(np.log10(N_list),dmvm,label='Mean value')
plt.legend()
plt.xlabel('Log$_{10}$N')
plt.ylabel('Errors')
# Out:
# Miss/hit method
# For N= 100 Integral= 1.46
# For N= 1000 Integral= 1.434
# For N= 10000 Integral= 1.4602
# For N= 100000 Integral= 1.44942
# For N= 1000000 Integral= 1.451528
# Mean value method
# For N= 100 Integral= 1.394699605190755
# For N= 1000 Integral= 1.4566156447151557
# For N= 10000 Integral= 1.4466875060464612
# For N= 100000 Integral= 1.450749580451635
# For N= 1000000 Integral= 1.451780558868595
#
#  Precise integral:  1.4516877509810684 error:  0.002712378152591422
#
# Differences:
# For N= 100 delta_mhm= -0.008312249018931572  delta_mvm= 0.056988145790313416
# For N= 1000 delta_mhm= 0.01768775098106845  delta_mvm= -0.0049278937340873075
# For N= 10000 delta_mhm= -0.00851224901893155  delta_mvm= 0.0050002449346071565
# For N= 100000 delta_mhm= 0.0022677509810684615  delta_mvm= 0.0009381705294333464
# For N= 1000000 delta_mhm= 0.00015975098106846275  delta_mvm= -9.280788752663582e-05
# ...

# %% [markdown]
# 4\. **Monte Carlo integration in high dimension**
#
# * Start of by computing the area of a circle of unit radius, by integrating the function
#
# $$
# f(x,y)=
# \left\{
# \begin{array}{ll}
#       1 & x^2+y^2\le 1 \\
#       0 & {\rm elsewhere}
# \end{array}
# \right.
# $$
#
# * Generalize the result for a 10D sphere

# %%
dim=10
ns=1000000
x=(np.random.random((dim,ns))*2)-1

def sph_f (x):
    return np.sum(x**2,axis=0)


dist=sph_f(x)
plt.hist(dist,bins=50)

counts=0
for d in dist:
    if d<1:
        counts+=1
        
print('Computational area:', (counts/ns)*(2**dim))
print('Algebric area: ', 1/120*np.pi**5)
# Out:
# Computational area: 2.566144
# Algebric area:  2.550164039877345

# %% [markdown]
# 5\. **Monte Carlo integration with importance sampling**
#
# Calculate the value of the integral:
#
# $$
# I=\int_0^1 \frac{x^{-1/2}}{e^x+1} dx
# $$
#
# using the importance sampling method with $w(x)=1/\sqrt{x}$. You should get a result about 0.84

# %%
def f (x):
    return pow(x,-(1/2))/(np.exp(x)+1)

print(f(0.1),f(1))

def w(x):
    return 1/(pow(x,1/2))

x=np.linspace(1e-10,1,100000)
plt.plot(x,f(x))
plt.ylim(0,10)
plt.grid(True)
#plt.yticks(np.linspace(1,10,10))

N_list=[100,1000,10000,100000,1000000]
w_int=integrate.quad(w,0,1)
print(integrate.quad(f,0,1))
print(w_int)
for N in N_list:
    x=np.linspace(1e-30,1,N)
    rapp=(f(x))/(w(x))
    print(np.average(rapp))
    I=(1./N)*(np.sum(f(x)/w(x)))*w_int[0]
    print('For N=',N, 'Integral=',I)
    mvm.append(I)
print(rapp)
print(w(x))
print(f(x))
# Out:
# 1.5021477035503799 0.2689414213699951
# (0.8389329600133838, 1.9939605522267811e-13)
# (1.9999999999999984, 5.773159728050814e-15)
# 0.37993179461394005
# For N= 100 Integral= 0.7598635892278796
# 0.3798900827128249
# For N= 1000 Integral= 0.7597801654256492
# 0.3798859516079813
# For N= 10000 Integral= 0.759771903215962
# 0.37988553889434384
# For N= 100000 Integral= 0.7597710777886872
# 0.37988549762694457
# For N= 1000000 Integral= 0.7597709952538886
# [0.5        0.49999975 0.4999995  ... 0.26894181 0.26894162 0.26894142]
# [1.00000000e+15 9.99999500e+02 7.07106428e+02 ... 1.00000100e+00
#  1.00000050e+00 1.00000000e+00]
# [5.00000000e+14 4.99999500e+02 3.53552860e+02 ... 2.68942084e-01
#  2.68941752e-01 2.68941421e-01]
