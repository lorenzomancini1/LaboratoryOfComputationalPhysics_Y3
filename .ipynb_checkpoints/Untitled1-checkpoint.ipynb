# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# always useful
import numpy as np
from scipy import stats
from math import pi

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_title('Curva di Lorenz',fontsize=16)
ax.set_ylabel('Frazione di ricchezza Y(X)',fontsize=16)
ax.set_xlabel('Frazione di popolazione X',fontsize=16)
data = np.sort(np.random.gamma(1,size=10000))
x = np.arange(1,data.size+1)/data.size
y = np.cumsum(data)/data.sum()
ax.plot(x,y,c = 'black', lw = 3, label = "Distribuzione esponenziale $e^{-x}$")
ax.plot(np.linspace(0,1,10),np.linspace(0,1,10),linestyle = 'dashed', c  = 'black', lw = 3, label = "Curva di uguaglianza")
ax.plot(np.linspace(0,1,10),1 - np.linspace(0,1,10), c  = 'blue', lw = 3, label = "Y=1-X")
ax.legend(loc = 'best')
x0 = x[np.absolute((1 - x - y)).argmin()]
y0 = y[np.absolute((1 - x - y)).argmin()]
ax.plot([x0,x0],[y0,0], c = 'red', lw = 3)
ax.annotate('$X* = k$', xy=(x0, 0), xytext=(x0 + 0.1,y0/2 + 0.15),
            arrowprops=dict(facecolor='black', shrink=0.05),fontsize=16
            )
# Out:
# Text(0.7821, 0.3089381721523459, '$X* = k$')

# %%
x[np.absolute((1 - x - y)).argmin()]
# Out:
# 0.6844

# %%
x0
# Out:
# 0.6323

# %%
# Out:
# array([9.999e-01, 9.998e-01, 9.997e-01, ..., 2.000e-04, 1.000e-04,
#        0.000e+00])

# %%
y
# Out:
# array([1.20180166e-05, 2.48280250e-05, 3.77427957e-05, ...,
#        9.99362112e-01, 9.99672349e-01, 1.00000000e+00])
