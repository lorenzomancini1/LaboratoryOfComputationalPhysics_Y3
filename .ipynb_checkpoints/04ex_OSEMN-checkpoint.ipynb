# %% [markdown]
# # OSEMN Exercises

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %% [markdown]
# 1\. Create a random list of number and then save it to a text file named "simple_data.txt"

# %%
import random

#Random list of numbers
N = 10 #length of the list
randomlist = [random.randint(1,20) for i in range(0,N)]

file_name1 = "simple_data.txt"

file1 = open(file_name1,"w+")

#Save list to file
with open(file_name1, "w") as output:
    output.write(str(randomlist))

file1.close()

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
#Random matrix of 5x5
random_matrix = np.random.randint(10, size=(5, 5))

file_name2 = "data.txt"

file2 = open(file_name2,"w+")

#Save matrix to file
with open(file_name2, "w") as output:
    output.write(str(random_matrix))

file2.close()

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
with open("data.txt","r") as file3:
    
    with open("data.csv","w") as file4:
        
        for line in file3:
            l=line.split()
            
            for i in l:
                file4.write(i)
                file4.write(",") #cvs = comma separated values

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number.
# Each line correspond to a credit card number.
# Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding
#
# **hint**: use the `chr()` function to convert a number to a char

# %%
file_name3 = "credit_card.dat"

lst = [] #lst will contain all the line
num_line = 0

with open(file_name3,'r') as file:
    
    for line in file:
        
        lst.append(line)
        num_line += 1 #num_line counts the line
        
L = len(lst[0]) #number of bit in each line (except the last one)

index = list(range(0,L,6))[:-1] #A list of multiple of 6 (because one character is composed by 6 bits)

num = []
for j in range(0,num_line-2): #I remove the last line. In this way I do not consider the last line of 4 bits
    
    for i in range(0,len(index)-1): #I remove the last two elements. In this way I do not consider the last 4 bits of padding
        
        num_bin = lst[j][index[i]:index[i+1]] #I consider 6 bits at time
        num_dec = int(str(num_bin),2) #I convert this 6 bits in a decimal number
        temp = chr(num_dec) #I convert this number to char
        num.append(temp)
        
    num_str = ' '.join([str(elem) for elem in num])
    print("Credit card number:",num_str)
    num = []
# Out:
# Credit card number: 7 6 4 8   5 6 7 3   3 7 7 5   2 2 7
# Credit card number: 3 2 5 7   8 2 4 7   3 3 5 4   2 2 6
# Credit card number: 2 7 2 2   0 0 0 1   4 0 1 1   6 6 5
# Credit card number: 0 6 6 1   3 0 6 3   3 7 4 2   3 1 5
# Credit card number: 0 4 3 2   1 6 0 8   1 4 6 2   4 7 4
# Credit card number: 5 8 2 7   2 0 2 7   8 7 8 5   7 3 0
# Credit card number: 5 7 7 4   8 5 2 8   2 0 8 7   1 1 1
# Credit card number: 8 1 4 0   1 2 1 0   6 3 5 2   2 8 4
# Credit card number: 5 7 6 4   1 1 3 3   7 3 0 1   7 1 0
# Credit card number: 6 4 5 6   1 7 3 7   4 1 2 6   6 7 2
# Credit card number: 1 2 2 8   8 6 3 1   7 3 8 2   0 0 0
# Credit card number: 7 0 5 1   0 1 6 0   5 3 7 4   3 1 6
# Credit card number: 0 6 1 8   3 5 8 7   1 6 3 0   6 3 7
# Credit card number: 1 5 4 5   5 4 5 4   7 4 4 4   5 6 3
# Credit card number: 6 7 3 5   3 1 1 6   3 2 0 2   6 8 3
# Credit card number: 7 2 8 7   5 0 1 1   1 5 4 7   8 4 1
# Credit card number: 7 0 3 3   2 6 0 7   3 3 2 8   4 2 0
# ...

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %%
import json

data = json.load(open('user_data.json'))

# Filter python objects with list comprehensions
output_dict = [x for x in data if x['CreditCardType'] == 'American Express']

# Transform python object back into json
out = json.dumps(output_dict)

#Save the result to file
file5 = open("user_data.txt","w+")
with open("user_data.txt", "w") as output:
    output.write(out)

with open("user_data.txt","r") as file6:
    
    with open("user_data.csv","w") as file7:      
        for line in file6:
            l=line.split()
            
        for i in l:
            file7.write(i)
            file7.write(",") #cvs = comma separated values

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe wath yuou see

# %%
#Load the file from this url
url = 'https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1'
df = pd.read_csv(url)

#1) Explore the data
file8 = open("mushrooms.txt","w+")

with open("mushrooms.txt", "w") as output:
    
    output.write(df.to_string())

#2) Draw the istogram of the 'class' field.

import matplotlib.pyplot as plt

array = df.to_numpy()
class_field = array[:,0]
# %matplotlib inline
plt.hist(class_field)
plt.title("Class")
plt.show()

#The graph is an istogram, so the values of x are not only 0 or 1. Indeed, the first column goes from x=0 to x=0.1
#and the second goes from x=0.9 to x=1. (Values of x are a range)

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %%
#Load the file from this url
url1 = 'https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1'
df1 = pd.read_csv(url1)

#Plot a scatter plot of all possible combination between:
df1.columns=['label','features_1','features_2','features_3','features_4','features_5','features_6','features_7','features_8',
            'features_9','features_10','features_11','features_12','features_13','features_14','features_15','features_16',
            'features_17','features_18','features_19','features_20']

#features_1 and features_2

# %matplotlib inline
df1.plot.scatter('features_1','features_2')
plt.title("Scatter plot features_1 vs features_2")

#features_1 and features_3

df1.plot.scatter('features_1','features_3')
plt.title("Scatter plot features_1 vs features_3")

#features_2 and features_3

df1.plot.scatter('features_2','features_3')
plt.title("Scatter plot features_2 vs features_3")
# Out:
# Text(0.5, 1.0, 'Scatter plot features_2 vs features_3')

# %% [markdown]
# 8\. Load the same file of point 6, and convert the file to json with Pandas.

# %%
#Load the file from this url
url2 = 'https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1'
df2 = pd.read_csv(url2)

#Convert the file to json with Pandas
with open('temp.json', 'w') as f:
    f.write(df2.to_json(orient='records', lines=True))
