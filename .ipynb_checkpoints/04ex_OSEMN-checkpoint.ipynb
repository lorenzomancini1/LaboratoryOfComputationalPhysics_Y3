# %% [markdown]
# # OSEMN Exercises

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
import numpy.random as npr
import json, csv

# %% [markdown]
# 1\. Create a random list of number and then save it to a text file named "simple_data.txt"

# %%
npr.seed(123)
r= npr.rand(8)
np.savetxt('simple_data.txt', r, delimiter = ',')

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
npr.seed(456)
m= npr.rand(5,5) 
np.savetxt('data.txt', m, delimiter = ',')

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
with open('data.txt', 'r') as in_file:
    stripped = (line.strip() for line in in_file)
    lines = (line.split(",") for line in stripped if line)
    with open('data.csv', 'w') as out_file:
        writer = csv.writer(out_file)
        writer.writerow(["","","","",""])
        writer.writerows(lines)

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number.
# Each line correspond to a credit card number.
# Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding
#
# **hint**: use the `chr()` function to convert a number to a char

# %%
with open('credit_card.dat','rb') as f:
    word_size = 6
    rows = f.readlines()
    rows = [x.strip() for x in rows] 
    credit_card_numbers = np.empty((50,19), dtype=str)
    for j in range(0,51):   
        for i in range(0, len(rows[j])-4, word_size):
            credit_card_numbers [j][int(i/6)] = chr(int(rows[j][i:i+word_size],2))
                
print(credit_card_numbers)
# Out:
# [['7' '6' '4' '8' ' ' '5' '6' '7' '3' ' ' '3' '7' '7' '5' ' ' '2' '2' '7'
#   '1']
#  ['3' '2' '5' '7' ' ' '8' '2' '4' '7' ' ' '3' '3' '5' '4' ' ' '2' '2' '6'
#   '6']
#  ['2' '7' '2' '2' ' ' '0' '0' '0' '1' ' ' '4' '0' '1' '1' ' ' '6' '6' '5'
#   '2']
#  ['0' '6' '6' '1' ' ' '3' '0' '6' '3' ' ' '3' '7' '4' '2' ' ' '3' '1' '5'
#   '0']
#  ['0' '4' '3' '2' ' ' '1' '6' '0' '8' ' ' '1' '4' '6' '2' ' ' '4' '7' '4'
#   '2']
#  ['5' '8' '2' '7' ' ' '2' '0' '2' '7' ' ' '8' '7' '8' '5' ' ' '7' '3' '0'
#   '3']
#  ['5' '7' '7' '4' ' ' '8' '5' '2' '8' ' ' '2' '0' '8' '7' ' ' '1' '1' '1'
#   '7']
#  ['8' '1' '4' '0' ' ' '1' '2' '1' '0' ' ' '6' '3' '5' '2' ' ' '2' '8' '4'
#   '5']
#  ['5' '7' '6' '4' ' ' '1' '1' '3' '3' ' ' '7' '3' '0' '1' ' ' '7' '1' '0'
#   '0']
#  ['6' '4' '5' '6' ' ' '1' '7' '3' '7' ' ' '4' '1' '2' '6' ' ' '6' '7' '2'
#   '6']
#  ['1' '2' '2' '8' ' ' '8' '6' '3' '1' ' ' '7' '3' '8' '2' ' ' '0' '0' '0'
#   '0']
# ...

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %%
user_list = json.load(open('user_data.json'))
american_exp_list = [x for x in user_list if x['CreditCardType'] == 'American Express']
with open("american_exp.csv", 'w', newline='') as f:
    keys = list((american_exp_list[0]).keys())
    writer = csv.DictWriter(f, fieldnames=keys)
    writer.writeheader()
    for i in range(len(american_exp_list)):
            writer.writerow(american_exp_list[i])

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe wath yuou see

# %%
mushrooms_cat=pd.read_csv("https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1")
mushrooms_cat
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
def bins_labels(bins, **kwargs):
    bin_w = (max(bins) - min(bins)) / (len(bins) - 1)
    plt.xticks(np.arange(min(bins)+bin_w/2, max(bins), bin_w), bins, **kwargs)
    plt.xlim(bins[0], bins[-1])
    
bins = range(3)
plt.hist(mushrooms_cat['class'], bins=bins, edgecolor='black')
bins_labels(bins, fontsize=15)
plt.xlabel("Classe")
plt.ylabel("Occorrenze")
plt.show()

print("I funghi sono quasi equamente divisi fra classe 0 (4208 elementi) \ne 1 (3916 elementi)")
# Out:
# I funghi sono quasi equamente divisi fra classe 0 (4208 elementi)
# e 1 (3916 elementi)

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %%
regr_gen=pd.read_csv("https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1")
regr_gen
# Out:
#            label  features_1  features_2  features_3  features_4  features_5  \
# 0     -89.243497    2.175170   -0.285786   -0.603396   -0.627453   -0.686474
# 1     230.050125    1.481941   -1.327870   -0.543583   -0.303578    1.552964
# 2    -286.844411   -1.154394   -0.178649   -1.636646    0.239353   -0.684994
# 3     364.552862    0.197665    1.455707    1.562205    2.168207    0.053335
# 4     515.460006    0.596676    0.969860    1.294158   -0.404728    2.145297
# ...          ...         ...         ...         ...         ...         ...
# 1995 -328.100239   -1.820929    1.358539   -2.494838    0.828299    0.199255
# 1996  -62.960036   -0.883712   -0.063687   -0.418704   -0.872601    0.363769
# 1997  -90.262252   -0.021394   -0.312864   -0.730848   -1.341482   -0.720862
# 1998  -74.333901   -0.041909   -0.862731   -1.232011    1.268843    0.093043
# 1999    8.321454   -1.056364    0.259247    0.307835    1.094903    0.472395
#
# ...

# %%
regr_gen.plot.scatter('features_1','features_2')
regr_gen.plot.scatter('features_1','features_3', color="green")
regr_gen.plot.scatter('features_2','features_3', color="orange")

# %% [markdown]
# 8\. Load the same file of point 6, and convert the file to json with Pandas.

# %%
mush_cat_df= pd.DataFrame(pd.read_csv("https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1", sep = ",", header = 0, index_col = False))
mush_cat_df.to_json("mush_cat_json.json", orient = "records", date_format = "epoch", double_precision = 10, force_ascii = True, date_unit = "ms", default_handler = None)
