# %% [markdown]
# # OSEMN Exercises

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

# %% [markdown]
# 1\. Create a random list of number and then save it to a text file named "simple_data.txt"

# %%
elist = np.random.random_sample((15))
fout = open("simple_data.txt","a")
fout.write(str(elist))
fout.close()

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
matrix2 = np.random.random_sample((5,5))
fout    = open("matrix.txt","w")
fout.write(str(matrix2))
fout.close()

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
fin     = open("matrix.txt","r")
matrix3 = fin.read()
matrix3 = matrix3.replace("[", "")
matrix3 = matrix3.replace("]", "")
matrix3 = matrix3.replace("'", "")
matrix3 = matrix3.replace("\n", "")
matrix3 = matrix3.replace(" ", ",")
fout    = open("matrix.csv","w")
fout.write(matrix3)
fout.close()
fin.close()

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number.
# Each line correspond to a credit card number.
# Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding
#
# **hint**: use the `chr()` function to convert a number to a char

# %%
with open('credit_card.dat', 'r') as file:
    file_content = file.read()

    
fileout = ''

for line in range(0, len(file_content) - 4, 119):
    line_position = file_content[line:line + 119]
    for word in range(0, 119 - 4, 6):
            word_position = word*6
            num = line_position[word : word + 6]
            if num == '':
                fileout += ''
            elif num=='100000':
                fileout += '-'
            else:
                fileout += chr(int(num,2))

print(fileout)
# Out:
# 7648-5673-3775-2271
# 3257-8247-3354-2266
# 2722-0001-4011-6652
# 0661-3063-3742-3150
# 0432-1608-1462-4742
# 5827-2027-8785-7303
# 5774-8528-2087-1117
# 8140-1210-6352-2845
# 5764-1133-7301-7100
# 6456-1737-4126-6726
# 1228-8631-7382-0000
# 7051-0160-5374-3166
# 0618-3587-1630-6376
# 1545-5454-7444-5636
# 6735-3116-3202-6834
# 7287-5011-1547-8413
# 7033-2607-3328-4200
# 2568-5244-1874-5024
# 1684-2253-7570-7118
# 0672-2576-0575-6631
# 6332-8353-8787-1340
# 1813-3361-1175-4211
# 2477-6450-8840-2368
# 5512-3505-2563-1326
# 3083-7882-0621-0025
# 4521-5148-8045-0334
# 7563-3654-8713-5787
# 8324-2664-0476-5561
# 0565-2504-7168-3510
# 5107-5507-1767-0738
# 2462-1821-2448-1443
# 2788-0638-6861-6554
# 5851-5873-5474-0547
# 0670-1004-4013-2655
# 5874-5506-3048-0806
# 2805-5401-8462-1260
# 5083-8406-6310-1862
# 1076-1445-3013-2266
# 8440-4804-4844-5277
# 4758-6141-0686-1387
# 7586-0675-0315-2568
# 2544-1258-7432-5165
# 3474-5023-4434-5626
# 1410-0270-0434-5086
# 7315-4446-1104-4215
# ...

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %%
import json
import pandas as pd
data = json.load(open('user_data.json'))
a =[data[i] for i in range(len(data)) if data[i]["CreditCardType"]=="American Express"]
df = pd.DataFrame(a)
df.to_csv("creditcard.csv")

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe wath yuou see

# %%
c = pd.read_csv("https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1")
plt.hist(c['class'])
plt.show()

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %%
c = pd.read_csv("https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1")
plt.scatter(c['features_1'],c['features_2'])
plt.show()
plt.scatter(c['features_2'],c['features_1'])
plt.show()
plt.scatter(c['features_2'],c['features_3'])
plt.show()
plt.scatter(c['features_3'],c['features_1'])
plt.show()
plt.scatter(c['features_1'],c['features_3'])
plt.show()

# %% [markdown]
# 8\. Load the same file of point 6, and convert the file to json with Pandas.

# %%
# file_n = "mushroom_categorized.csv"
dat = filename = pd.read_csv("https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1")
a=dat.to_json("mush_catego.json")
