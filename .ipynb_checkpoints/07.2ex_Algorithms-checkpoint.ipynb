# %% [markdown]
# 1\. **Maximum wind speed prediction at the Sprogø station**
#
# The exercise goal is to predict the maximum wind speed occurring every 50 years even if no measure exists for such a period. The available data are only measured over 21 years at the Sprogø meteorological station located in Denmark.
#
# The annual maxima are supposed to fit a normal probability density function. However such function is not going to be estimated because it gives a probability from a wind speed maxima. Finding the maximum wind speed occurring every 50 years requires the opposite approach, the result needs to be found from a defined probability. That is the quantile function role and the exercise goal will be to find it. In the current model, it is supposed that the maximum wind speed occurring every 50 years is defined as the upper 2% quantile.
#
# By definition, the quantile function is the inverse of the cumulative distribution function. The latter describes the probability distribution of an annual maxima. In the exercise, the cumulative probability $p_i$ for a given year i is defined as $p_i = i/(N+1)$ with $N = 21$, the number of measured years. Thus it will be possible to calculate the cumulative probability of every measured wind speed maxima. From those experimental points, the scipy.interpolate module will be very useful for fitting the quantile function. Finally the 50 years maxima is going to be evaluated from the cumulative probability of the 2% quantile.
#
# Practically, load the dataset:
#
# ```python
# import numpy as np
# max_speeds = np.load('max-speeds.npy')
# years_nb = max_speeds.shape[0]
# ```
#
# Compute then the cumulative probability $p_i$ (`cprob`) and sort the maximum speeds from the data. Use then the  UnivariateSpline from scipy.interpolate to define a quantile function and thus estimate the probabilities.
#
# In the current model, the maximum wind speed occurring every 50 years is defined as the upper 2% quantile. As a result, the cumulative probability value will be:
#
# ```python
# fifty_prob = 1. - 0.02
# ```
#
# So the storm wind speed occurring every 50 years can be guessed as:
#
# ``` python
# fifty_wind = quantile_func(fifty_prob)
# ```

# %%
import numpy as np
import scipy.interpolate
import calendar
from scipy import optimize
from scipy import fftpack
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
max_speeds = np.load('max-speeds.npy')
years_nb = max_speeds.shape[0]
cprob = (np.arange(years_nb, dtype=np.float32) + 1)/(years_nb + 1)
sorted_max_speeds=np.sort(max_speeds)
quantile_function=scipy.interpolate.UnivariateSpline(cprob,sorted_max_speeds)
fifty_prob=1.-0.02
fifty_wind=quantile_function(fifty_prob)
fig,ax=plt.subplots(figsize=(12,7))
ax.set_title('Maximum wind speed prediction',fontsize=20)
ax.set_xlabel('wind speed maxima', size=14)
ax.set_ylabel('cumulative probability', size=14)
prob=np.linspace(0,1,1000)
fitted_cprob=quantile_function(prob)
data=ax.scatter(sorted_max_speeds,cprob,label='measurements')
fit=ax.plot(fitted_cprob,prob,label='fitted cumulative function',color='orange')
v50=ax.plot(fifty_wind,fifty_prob,'o',color='red',markersize=13,label='maximum wind speed predicted')
ax.legend(loc='best',prop={'size': 14})
string='maximum wind speed predicted= %.4f'%(fifty_wind)
ax.text(26,0,string,fontsize=14)
plt.show()

# %% [markdown]
# 2\. **Curve fitting of temperature in Alaska**
#
# The temperature extremes in Alaska for each month, starting in January, are given by (in degrees Celcius):
#
# max:  17,  19,  21,  28,  33,  38, 37,  37,  31,  23,  19,  18
#
# min: -62, -59, -56, -46, -32, -18, -9, -13, -25, -46, -52, -58
#
# * Plot these temperature extremes.
# * Define a function that can describe min and max temperatures.
# * Fit this function to the data with scipy.optimize.curve_fit().
# * Plot the result. Is the fit reasonable? If not, why?
# * Is the time offset for min and max temperatures the same within the fit accuracy?

# %%
#Plot the temperature extremes.
max_temperatures=np.array([17, 19, 21, 28, 33, 38, 37, 37, 31, 23, 19, 18])
min_temperatures=np.array([-62, -59, -56, -46, -32, -18, -9, -13, -25, -46, -52, -58])
months=np.array([calendar.month_name[i] for i in range(1,13)])
months_num=np.array([i for i in range (0,12)])
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2,figsize=(16,7))
ax1.set_title('Temperatures Maxima',fontsize=20)
ax1.set_ylabel('temperature(°C)',size=14)
ax1.set_xticklabels(months,rotation=45)
ax1.scatter(months,max_temperatures,label='maxima',color='orange')

ax2.set_title('Temperatures Minima',fontsize=20)
ax2.set_ylabel('temperature(°C)',size=14)
ax2.yaxis.set_label_position("right")
ax2.yaxis.tick_right()
ax2.set_xticklabels(months,rotation=45)
ax2.scatter(months,min_temperatures,label='minima')

#Define a function that can describe min and max temperatures.
def f(x,A,mean,std,offset):
    return offset+A*np.exp(-((x-mean)/std)**2)
    
#Fit this function to the data with scipy.optimize.curve_fit() and plot the results.

pars_max,cov_max=optimize.curve_fit(f,months_num,max_temperatures,[20,7,5,17])
days=np.linspace(0,11,365)
ax1.plot(days, f(days, pars_max[0], pars_max[1],pars_max[2],pars_max[3]),label='Fitted maxima temperatures')
ax1.legend(loc='best',prop={'size':12})

pars_min,cov_min=optimize.curve_fit(f,months_num,min_temperatures,[50, 7, 5,-60])
ax2.plot(days, f(days,pars_min[0],pars_min[1],pars_min[2],pars_min[3]), label='Fitted minima temperatures',color='green')
ax2.legend(loc='best',prop={'size':12})
plt.show()

print('the time offests for minima and maxima are respectively:\n{:.4f} with an error of {:.4f}\n{:.4f} with an error of {:.4f}'.format(pars_min[1],cov_min[1,1],pars_max[1],cov_max[1,1]))
if np.abs(pars_min[1]-pars_max[1])>=cov_min[1,1]+cov_max[1,1]:
    print('So the time offets in the 2 cases are not the same within the fit accurancy')
else:
    print('So the time offets in the 2 cases are the same within the fit accurancy')
# Out:
# the time offests for minima and maxima are respectively:
# 6.1645 with an error of 0.0022
# 5.7358 with an error of 0.0063
# So the time offets in the 2 cases are not the same within the fit accurancy

# %% [markdown]
# 3\. **2D minimization of a six-hump camelback function**
#
# $$
# f(x,y) = \left(4-2.1x^2+\frac{x^4}{3} \right) x^2 +xy + (4y^2 -4)y^2
# $$
#
# has multiple global and local minima. Find the global minima of this function.
#
# Hints:
#
# * Variables can be restricted to $-2 < x < 2$ and $-1 < y < 1$.
# * Use numpy.meshgrid() and pylab.imshow() to find visually the regions.
# * Use scipy.optimize.minimize(), optionally trying out several of its methods.
#
# How many global minima are there, and what is the function value at those points? What happens for an initial guess of $(x, y) = (0, 0)$ ?

# %%
def f(x):
    return (4-2.1*np.power(x[0],2)+np.power(x[0],4)/3)*np.power(x[0],2)+x[0]*x[1]+(4*np.power(x[1],2)-4)*np.power(x[1],2)
x=np.linspace(-2,2,1000)
y=np.linspace(-1,1,500)
xg, yg = np.meshgrid(x, y)
plt.figure(figsize=(16,8))
plt.imshow(f([xg, yg]),cmap='jet', extent=[-2, 2, -1, 1])
plt.colorbar()
plt.xlabel('x',size=20)
plt.ylabel('y',size=20)
plt.title('2D six hump',fontsize=25)
plt.show()

# %%
minima=[[0,0.75],[0,-0.75]]
results=[optimize.minimize(f,x0) for x0 in minima]
print('The function has {} global minima.'.format(len(results)))
gmin=np.array([results[i].x for i in range(2)])
for result in results:
    print('The function has a minimum in x={:.4f},y={:.4f} in which f={:.4f}.'.format(result.x[0],result.x[1],f(result.x)))
result1=optimize.minimize(f,[0,0])
print('For an initial guess of x,y=(0,0) the optimize.minimize() minimization gives a minimum in x={},y={} in which the function is f={} that is not a minimum.'.format(result1.x[0],result1.x[1],f(result1.x)))
# Out:
# The function has 2 global minima.
# The function has a minimum in x=-0.0898,y=0.7127 in which f=-1.0316.
# The function has a minimum in x=0.0898,y=-0.7127 in which f=-1.0316.
# For an initial guess of x,y=(0,0) the optimize.minimize() minimization gives a minimum in x=0.0,y=0.0 in which the function is f=0.0 that is not a minimum.

# %%
plt.figure(figsize=(16,8))
plt.imshow(f([xg, yg]),cmap='jet', extent=[-2, 2, -1, 1])
plt.colorbar()
plt.xlabel('x',size=20)
plt.ylabel('y',size=20)
plt.title('2D six hump',fontsize=25)
plt.scatter(gmin[:,0],gmin[:,1],color='red',label='global minima')
plt.scatter(result1.x[0],result1.x[1],color='yellow',label='initial guess x,y=(0,0)')
plt.legend(loc='best',prop={'size':14})
plt.show()

# %% [markdown]
# 4\. **FFT of a simple dataset**
#
# Performe a periodicity analysis on the lynxs-hares population

# %%
data=np.loadtxt("populations.txt")
years=data[:,0]
hares=data[:,1]
linxes=data[:,2]
carrots=data[:,3]
plt.figure(figsize=(12,7))
plt.plot(years,hares,label='hares')
plt.plot(years,linxes,label='linxes')
plt.plot(years,carrots,label='carrots')
plt.legend(loc='best',prop={'size':14})
plt.xlabel('years',size=18)
plt.ylabel('populations',size=18)
plt.show()

hfft=fftpack.fft(hares)
lfft=fftpack.fft(linxes)
cfft=fftpack.fft(carrots)
hfft=np.abs(hfft)
lfft=np.abs(lfft)
cfft=np.abs(cfft)

sample_freq = fftpack.fftfreq(years.size)
pos_mask = np.where(sample_freq > 0)
freqs = sample_freq[pos_mask]
period=1/freqs
hfft=hfft[pos_mask]
lfft=lfft[pos_mask]
cfft=cfft[pos_mask]

plt.figure(figsize=(12, 7))
plt.scatter(period, hfft)
plt.scatter(period,lfft)
plt.scatter(period,cfft)
plt.xlabel('Period (years)',size=18)
plt.ylabel('Power',size=18)
plt.show()

print('As the plot displays the data have a period around ten years.')
# Out:
# As the plot displays the data have a period around ten years.

# %% [markdown]
# 5\. **FFT of an image**
#
# * Examine the provided image `moonlanding.png`, which is heavily contaminated with periodic noise. In this exercise, we aim to clean up the noise using the Fast Fourier Transform.
# * Load the image using pylab.imread().
# * Find and use the 2-D FFT function in scipy.fftpack, and plot the spectrum (Fourier transform of) the image. Do you have any trouble visualising the spectrum? If so, why?
# * The spectrum consists of high and low frequency components. The noise is contained in the high-frequency part of the spectrum, so set some of those components to zero (use array slicing).
# * Apply the inverse Fourier transform to see the resulting image.

# %%
moon=plt.imread('moonlanding.png')
plt.figure(figsize=(12,7))
plt.title('Original image',fontsize=20)
plt.imshow(moon,cmap='gray')
plt.show()

fft=fftpack.fft2(moon)
power=np.abs(fft)
#first try: plotting the image's fourier transform
plt.figure(figsize=(12,7))
plt.imshow(power,cmap='viridis',vmin=2.5)
plt.title('Fourier trasform',fontsize=20)
plt.colorbar()
plt.show()
print('The difficulties in visualizing the spectrum are due to the fact that the spectrum range is too wide.')
#second try:plotting the logarithm of the image's Fourier trasform
plt.figure(figsize=(12,7))
plt.imshow(np.log(power),cmap='viridis',vmin=3)
plt.title('Fourier trasform',fontsize=20)
plt.colorbar()
plt.show()
print('Plotting the logarithm of the image\'s Fourier trasform result in a "flattened version" of the spectrum more usefull for visualization.')
#The spectrum consists of high and low frequency components.
#The noise is contained in the high-frequency part of the spectrum.
filtered_fft=fft.copy()
#Low frequencies lie in the corners of the spectrum: setting to zero all the Fourier transoform elements but the corners
filtered_fft[60:440,:]=0
filtered_fft[:,60:590]=0
#Apply the inverse Fourier transform to see the resulting image.
filtered_moon=fftpack.ifft2(filtered_fft).real
plt.figure(figsize=(12,7))
plt.imshow(filtered_moon,cmap='gray')
plt.title('Filtered image',fontsize=20)
plt.show()
# Out:
# The difficulties in visualizing the spectrum are due to the fact that the spectrum range is too wide.
# Plotting the logarithm of the image's Fourier trasform result in a "flattened version" of the spectrum more usefull for visualization.
