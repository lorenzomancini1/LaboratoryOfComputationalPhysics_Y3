# %% [markdown]
# 1\. **Maximum wind speed prediction at the Sprogø station**
#
# The exercise goal is to predict the maximum wind speed occurring every 50 years even if no measure exists for such a period. The available data are only measured over 21 years at the Sprogø meteorological station located in Denmark.
#
# The annual maxima are supposed to fit a normal probability density function. However such function is not going to be estimated because it gives a probability from a wind speed maxima. Finding the maximum wind speed occurring every 50 years requires the opposite approach, the result needs to be found from a defined probability. That is the quantile function role and the exercise goal will be to find it. In the current model, it is supposed that the maximum wind speed occurring every 50 years is defined as the upper 2% quantile.
#
# By definition, the quantile function is the inverse of the cumulative distribution function. The latter describes the probability distribution of an annual maxima. In the exercise, the cumulative probability $p_i$ for a given year i is defined as $p_i = i/(N+1)$ with $N = 21$, the number of measured years. Thus it will be possible to calculate the cumulative probability of every measured wind speed maxima. From those experimental points, the scipy.interpolate module will be very useful for fitting the quantile function. Finally the 50 years maxima is going to be evaluated from the cumulative probability of the 2% quantile.
#
# Practically, load the dataset:
#
# ```python
# import numpy as np
# max_speeds = np.load('max-speeds.npy')
# years_nb = max_speeds.shape[0]
# ```
#
# Compute then the cumulative probability $p_i$ (`cprob`) and sort the maximum speeds from the data. Use then the  UnivariateSpline from scipy.interpolate to define a quantile function and thus estimate the probabilities.
#
# In the current model, the maximum wind speed occurring every 50 years is defined as the upper 2% quantile. As a result, the cumulative probability value will be:
#
# ```python
# fifty_prob = 1. - 0.02
# ```
#
# So the storm wind speed occurring every 50 years can be guessed as:
#
# ``` python
# fifty_wind = quantile_func(fifty_prob)
# ```

# %%
import numpy as np
from scipy.interpolate import UnivariateSpline
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
max_speeds = np.load('max-speeds.npy')
years_nb = max_speeds.shape[0]

cprob = (1 + np.arange(years_nb))/(years_nb + 1)
max_speeds.sort()

quantile = UnivariateSpline(cprob, max_speeds)
fifty_prob = 1. - 0.02
fifty_wind = quantile(fifty_prob)

y = np.linspace(0, 1, 100)
plt.scatter(max_speeds, cprob)
plt.plot(quantile(y), y, 'b--')
plt.scatter(fifty_wind, fifty_prob, color='r')
plt.show()
print("Max wind speed occurring every 50 years is guessed to be:", fifty_wind)
# Out:
# Max wind speed occurring every 50 years is guessed to be: 32.97989844019469

# %% [markdown]
# 2\. **Curve fitting of temperature in Alaska**
#
# The temperature extremes in Alaska for each month, starting in January, are given by (in degrees Celcius):
#
# max:  17,  19,  21,  28,  33,  38, 37,  37,  31,  23,  19,  18
#
# min: -62, -59, -56, -46, -32, -18, -9, -13, -25, -46, -52, -58
#
# * Plot these temperature extremes.
# * Define a function that can describe min and max temperatures.
# * Fit this function to the data with scipy.optimize.curve_fit().
# * Plot the result. Is the fit reasonable? If not, why?
# * Is the time offset for min and max temperatures the same within the fit accuracy?

# %%
from scipy.optimize import curve_fit

temperatures = [[ 17, 19, 21, 28, 33, 38, 37, 37, 31, 23, 19, 18],
                [-62, -59, -56, -46, -32, -18, -9, -13, -25, -46, -52, -58]]
months = np.arange(12) + 1

def f(x, a, b, c, d):
    return np.sin(a*x + b)*c + d

min_par, _ = curve_fit(f, months, temperatures[1], p0=[0.5,-1,40,-40])
max_par, _ = curve_fit(f, months, temperatures[0], p0=[0.5,-1,40,-40])

x = np.linspace(1,12,100)
plt.bar(months, temperatures[0], color='orange')
plt.bar(months, temperatures[1], color='cornflowerblue')

plt.plot(x,f(x, *min_par), 'r')
plt.plot(x,f(x, *max_par), 'r')
plt.show()

print('Max temperatures coeff:', max_par)
print('Min temperatures coeff:', min_par)
print('\nThe time offset it not the same, one is the %.1f%% of the other' %(max_par[1]*100/min_par[1]))
# Out:
# Max temperatures coeff: [ 0.59227423 -2.41092996 10.58169956 27.94963524]
# Min temperatures coeff: [  0.60132131  -2.71842467  25.14961869 -36.71255285]
#
# The time offset it not the same, one is the 88.7% of the other

# %% [markdown]
# 3\. **2D minimization of a six-hump camelback function**
#
# $$
# f(x,y) = \left(4-2.1x^2+\frac{x^4}{3} \right) x^2 +xy + (4y^2 -4)y^2
# $$
#
# has multiple global and local minima. Find the global minima of this function.
#
# Hints:
#
# * Variables can be restricted to $-2 < x < 2$ and $-1 < y < 1$.
# * Use numpy.meshgrid() and pylab.imshow() to find visually the regions.
# * Use scipy.optimize.minimize(), optionally trying out several of its methods.
#
# How many global minima are there, and what is the function value at those points? What happens for an initial guess of $(x, y) = (0, 0)$ ?

# %%
from scipy.optimize import minimize

def f(x):
    return (4.-2.1*x[0]*x[0] + x[0]**4 /3)*x[0]*x[0] + x[0]*x[1] + (4*x[1]*x[1] - 4)*x[1]*x[1]

dom = np.meshgrid(np.linspace(-2,2,100), np.linspace(-1,1,100))

plt.imshow(f(dom))
#plt.imshow(f(dom[0],dom[1]))
#plt.imshow(f(np.linspace(-2,2,100),np.linspace(-1,1,100)[:,np.newaxis]))
plt.colorbar()
plt.show()

u_solution = minimize(f, x0=[0,1])
l_solution = minimize(f, x0=[0,-1])

print("There are two global minima in this function")
print("-with value %.4f at the coordinates [%.4f, %.4f]" %(u_solution.fun, u_solution.x[0], u_solution.x[1]))
print("-with value %.4f at the coordinates [%.4f, %.4f]" %(l_solution.fun, l_solution.x[0], l_solution.x[1]))
print("\nInitializing the algorithm at [0,0] leads to a false minima: the [0.0] is a saddle point.")
# Out:
# There are two global minima in this function
# -with value -1.0316 at the coordinates [-0.0898, 0.7127]
# -with value -1.0316 at the coordinates [0.0898, -0.7127]
#
# Initializing the algorithm at [0,0] leads to a false minima: the [0.0] is a saddle point.

# %% [markdown]
# 4\. **FFT of a simple dataset**
#
# Performe a periodicity analysis on the lynxs-hares population

# %%
from scipy import fftpack

data = np.loadtxt('populations.txt')
year, hares, lynxes, carrots = data.T 

carrots_fft = fftpack.fft(carrots)
carrots_pw  = np.abs(carrots_fft)
lynxes_fft  = fftpack.fft(lynxes)
lynxes_pw   = np.abs(lynxes_fft)
hares_fft   = fftpack.fft(hares)
hares_pw    = np.abs(hares_fft)

sample_freq = fftpack.fftfreq(carrots.size, d=1.)

gridsize = (1, 2)
fig = plt.figure(figsize=(14, 6))

ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=1, rowspan=1)
ax1.plot(year, carrots, 'r', label='carrots')
ax1.plot(year, lynxes, 'g', label='lynxes')
ax1.plot(year, hares, 'b', label='hares')
ax1.set_xticks(year[year%2 == 0])
ax1.legend()
ax1.set_title('Populations over time')

ax2 = plt.subplot2grid(gridsize, (0,1), colspan=1, rowspan=1)
ax2.plot(np.sort(sample_freq), carrots_pw[sample_freq.argsort()], 'r', label='carrot')
ax2.plot(np.sort(sample_freq), lynxes_pw[sample_freq.argsort()], 'g', label='lynxes')
ax2.plot(np.sort(sample_freq), hares_pw[sample_freq.argsort()], 'b', label='hares')
ax2.legend()
ax2.set_title('Frequency analysis')

plt.show()

# %% [markdown]
# 5\. **FFT of an image**
#
# * Examine the provided image `moonlanding.png`, which is heavily contaminated with periodic noise. In this exercise, we aim to clean up the noise using the Fast Fourier Transform.
# * Load the image using pylab.imread().
# * Find and use the 2-D FFT function in scipy.fftpack, and plot the spectrum (Fourier transform of) the image. Do you have any trouble visualising the spectrum? If so, why?
# * The spectrum consists of high and low frequency components. The noise is contained in the high-frequency part of the spectrum, so set some of those components to zero (use array slicing).
# * Apply the inverse Fourier transform to see the resulting image.

# %%
from IPython.display import Image

#Image("moonlanding.png")

pic = plt.imread('moonlanding.png')

pic_fft = fftpack.fft2(pic)
pic_pw  = np.abs(pic_fft)

gridsize = (3, 2)
fig = plt.figure(figsize=(16, 20))

ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=1, rowspan=1)
ax1.imshow(pic, cmap='Greys_r')
ax1.set_title('Original image')

ax2 = plt.subplot2grid(gridsize, (0, 1), colspan=1, rowspan=1)
ax2.imshow(np.log(pic_pw))
#ax2.colorbar()
ax2.set_title('Log spectrum')

ax3 = plt.subplot2grid(gridsize, (1,0), colspan=2, rowspan=2)
ax3.imshow(pic_pw)
ax3.set_title('Large spectrum')

plt.tight_layout()
plt.show()

# %% [markdown]
# Thinking in one dimension, the intensities pattern follows the frequencies f, sorted like:
#
# f = \[0, 1, ..., max, min, ..., -1\]

# %%
cut = [0.14, 0.12, 0.1, 0.08]
row, col = np.shape(pic_fft)

gridsize = (2, 2)
fig = plt.figure(figsize=(16, 12))

pic_fft[int(row*cut[0]):int(row*(1-cut[0])), :] = 0
pic_fft[:, int(col*cut[0]):int(col*(1-cut[0]))] = 0
pic_filt = fftpack.ifft2(pic_fft)

ax1 = plt.subplot2grid(gridsize, (0,0), colspan=1, rowspan=1)
ax1.imshow(np.real(pic_filt), cmap='Greys_r')
ax1.set_title('Cutting %.1f%% frequencies' %((1-cut[0]*2)*100))


pic_fft[int(row*cut[1]):int(row*(1-cut[1])), :] = 0
pic_fft[:, int(col*cut[1]):int(col*(1-cut[1]))] = 0
pic_filt = fftpack.ifft2(pic_fft)

ax1 = plt.subplot2grid(gridsize, (0,1), colspan=1, rowspan=1)
ax1.imshow(np.real(pic_filt), cmap='Greys_r')
ax1.set_title('Cutting %.1f%% frequencies' %((1-cut[1]*2)*100))


pic_fft[int(row*cut[2]):int(row*(1-cut[2])), :] = 0
pic_fft[:, int(col*cut[2]):int(col*(1-cut[2]))] = 0
pic_filt = fftpack.ifft2(pic_fft)

ax1 = plt.subplot2grid(gridsize, (1,0), colspan=1, rowspan=1)
ax1.imshow(np.real(pic_filt), cmap='Greys_r')
ax1.set_title('Cutting %.1f%% frequencies' %((1-cut[2]*2)*100))


pic_fft[int(row*cut[3]):int(row*(1-cut[3])), :] = 0
pic_fft[:, int(col*cut[3]):int(col*(1-cut[3]))] = 0
pic_filt = fftpack.ifft2(pic_fft)

ax1 = plt.subplot2grid(gridsize, (1,1), colspan=1, rowspan=1)
ax1.imshow(np.real(pic_filt), cmap='Greys_r')
ax1.set_title('Cutting %.1f%% frequencies' %((1-cut[3]*2)*100))

plt.show()
