# %% [markdown]
# 1\. **Maximum wind speed prediction at the Sprogø station**
#
# The exercise goal is to predict the maximum wind speed occurring every 50 years even if no measure exists for such a period. The available data are only measured over 21 years at the Sprogø meteorological station located in Denmark.
#
# The annual maxima are supposed to fit a normal probability density function. However such function is not going to be estimated because it gives a probability from a wind speed maxima. Finding the maximum wind speed occurring every 50 years requires the opposite approach, the result needs to be found from a defined probability. That is the quantile function role and the exercise goal will be to find it. In the current model, it is supposed that the maximum wind speed occurring every 50 years is defined as the upper 2% quantile.
#
# By definition, the quantile function is the inverse of the cumulative distribution function. The latter describes the probability distribution of an annual maxima. In the exercise, the cumulative probability $p_i$ for a given year i is defined as $p_i = i/(N+1)$ with $N = 21$, the number of measured years. Thus it will be possible to calculate the cumulative probability of every measured wind speed maxima. From those experimental points, the scipy.interpolate module will be very useful for fitting the quantile function. Finally the 50 years maxima is going to be evaluated from the cumulative probability of the 2% quantile.
#
# Practically, load the dataset:
#
# ```python
# import numpy as np
# max_speeds = np.load('max-speeds.npy')
# years_nb = max_speeds.shape[0]
# ```
#
# Compute then the cumulative probability $p_i$ (`cprob`) and sort the maximum speeds from the data. Use then the  UnivariateSpline from scipy.interpolate to define a quantile function and thus estimate the probabilities.
#
# In the current model, the maximum wind speed occurring every 50 years is defined as the upper 2% quantile. As a result, the cumulative probability value will be:
#
# ```python
# fifty_prob = 1. - 0.02
# ```
#
# So the storm wind speed occurring every 50 years can be guessed as:
#
# ``` python
# fifty_wind = quantile_func(fifty_prob)
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import UnivariateSpline
from scipy import stats
from scipy import optimize
import pandas as pd
from scipy import fftpack

# %%
max_speeds = np.load('Data/max-speeds.npy')
years_nb = max_speeds.shape[0]
cprob = (np.arange(years_nb, dtype='float') + 1)/(years_nb + 1)
sorted_speeds = np.sort(max_speeds)
quantile_func = UnivariateSpline(cprob, sorted_speeds)
probs = np.linspace(0, 1, 100)
fitted_speeds = quantile_func(probs)
fifty_prob = 1. - 0.02
max_speed = quantile_func(fifty_prob)
print('Max speed:', max_speed)
plt.scatter(sorted_speeds, cprob)
plt.plot(fitted_speeds, probs, ls='--', color='red')
plt.xlabel('max speed per year [m/s]')
plt.ylabel('cumulative prob')
plt.axvline(max_speed, ls='--', color='g')
plt.text(28.5, 0.4, '$V_{max} = %.2f \, m/s$' % max_speed)
# Out:
# Max speed: 32.97989844019469
# Text(28.5, 0.4, '$V_{max} = 32.98 \\, m/s$')

# %% [markdown]
# 2\. **Curve fitting of temperature in Alaska**
#
# The temperature extremes in Alaska for each month, starting in January, are given by (in degrees Celcius):
#
# max:  17,  19,  21,  28,  33,  38, 37,  37,  31,  23,  19,  18
#
# min: -62, -59, -56, -46, -32, -18, -9, -13, -25, -46, -52, -58
#
# * Plot these temperature extremes.
# * Define a function that can describe min and max temperatures.
# * Fit this function to the data with scipy.optimize.curve_fit().
# * Plot the result. Is the fit reasonable? If not, why?
# * Is the time offset for min and max temperatures the same within the fit accuracy?

# %%
maxT = np.array([17, 19, 21, 28, 33, 38, 37, 37, 31, 23, 19, 18])
minT = np.array([-62, -59, -56, -46, -32, -18, -9, -13, -25, -46, -52, -58])
months = np.arange(12) + 1
plt.figure(figsize=(6,6))
plt.plot(months, maxT, 'o', color='red', alpha=0.5)
plt.plot(months, minT, 'o', color='blue', alpha=0.5)
plt.xlabel('month')
plt.ylabel('temperature [°C]')
def gaus(xdata, mu, sigma, norm, offset):
    return stats.norm.pdf(xdata, mu, sigma)*norm + offset
param_minT, cov_minT = optimize.curve_fit(gaus, months, minT, p0=[7., 1., 100, 20])
param_maxT, cov_maxT = optimize.curve_fit(gaus, months, maxT, p0=[7., 1., 100, -60])
xpoints = np.linspace(1,12,100)
plt.plot(xpoints, gaus(xpoints, *param_maxT), color='orange', ls='--', label='max')
plt.plot(xpoints, gaus(xpoints, *param_minT), color='lightblue', ls='--', label='min')
plt.legend(loc='best')
comp = np.abs(param_maxT[1] - param_minT[1]) / np.sqrt(cov_maxT[1,1] + cov_minT[1,1])
print('mean compatibility: %.2f sigma' % comp)
# Out:
# mean compatibility: 1.75 sigma

# %% [markdown]
# 3\. **2D minimization of a six-hump camelback function**
#
# $$
# f(x,y) = \left(4-2.1x^2+\frac{x^4}{3} \right) x^2 +xy + (4y^2 -4)y^2
# $$
#
# has multiple global and local minima. Find the global minima of this function.
#
# Hints:
#
# * Variables can be restricted to $-2 < x < 2$ and $-1 < y < 1$.
# * Use numpy.meshgrid() and pylab.imshow() to find visually the regions.
# * Use scipy.optimize.minimize(), optionally trying out several of its methods.
#
# How many global minima are there, and what is the function value at those points? What happens for an initial guess of $(x, y) = (0, 0)$ ?

# %%
# %precision 4
def f(X):
    return (4 - 2.1*X[0]**2 + (X[0]**4)/3)*X[0]**2 + X[0]*X[1] + (4*X[1]**2 - 4)*X[1]**2
from matplotlib import pylab 
x = np.linspace(-2, 2, 100)
y = np.linspace(-1, 1, 100)
xg, yg = np.meshgrid(x, y)
bounds = np.array([-2, 2, -1, 1], dtype='float')
fig = plt.figure(figsize=(7,5))
pylab.imshow(f([xg, yg]), extent=bounds, origin='lower')
#plt.colorbar()
search = [[i,j] for i in np.arange(bounds[0], bounds[1], 0.5) for j in np.arange(bounds[2], bounds[3], 0.5)]
raw_minima = np.array([optimize.minimize(f, x0=point).x for point in search])
minima = np.array([raw_minima[0]])
for i in raw_minima:
    if not np.any(np.isclose(minima, i).flatten()):
        minima = np.append(minima, [i], axis=0)
print('Minima found:\n', minima)
f_min = np.array([f(m) for m in minima])
print('\nFunction at minima:\n', f_min)
print('\nAbsolute minima:\n', minima[np.where(np.isclose(f_min, np.min(f_min)))])
plt.plot(minima.T[0], minima.T[1], 'o', color='red')
# Out:
# Minima found:
#  [[ 0.0898 -0.7127]
#  [-0.0898  0.7127]
#  [-1.7036  0.7961]
#  [-1.6071 -0.5687]
#  [ 0.      0.    ]
#  [ 1.7036 -0.7961]
#  [ 1.6071  0.5687]]
#
# Function at minima:
#  [-1.0316 -1.0316 -0.2155  2.1043  0.     -0.2155  2.1043]
#
# Absolute minima:
#  [[ 0.0898 -0.7127]
#  [-0.0898  0.7127]]

# %% [markdown]
# 4\. **FFT of a simple dataset**
#
# Performe a periodicity analysis on the lynxs-hares population

# %%
# %precision 4
data = pd.read_csv('Data/populations.txt', sep='\t')
data = data.rename(columns={'# year' : 'year'})

def f(x, A, omega, fi, c):
    return A*np.sin(omega*x + fi) + c

hare_par, hare_cov = optimize.curve_fit(f, data['year'].values, data['hare'].values, p0=[20000, 0.6, 0, 25000])
lynx_par, lynx_cov = optimize.curve_fit(f, data['year'].values, data['lynx'].values, p0=[20000, 0.6, 0, 25000])

x_plot = np.linspace(1900, 1920, 100)
fig = plt.figure(figsize=(10,5))
plt.scatter('year', 'hare', data=data, label='hare')
plt.scatter('year', 'lynx', data=data, label='lynx')
plt.plot(x_plot, f(x_plot, *hare_par), '--b', label='fitted hare')
plt.plot(x_plot, f(x_plot, *lynx_par), '--r', label='fitted lynx')
plt.legend(loc='best')
plt.xlabel('$Year$')
plt.ylabel('$Population$')

print('Main frequencies estimated via fit functions:\n')
print('hare: (%.2f +- %.2f) 1/year' % (hare_par[1]/(2*np.pi), np.sqrt(hare_cov[1,1])))
print('lynx: (%.2f +- %.2f) 1/year' % (lynx_par[1]/(2*np.pi), np.sqrt(lynx_cov[1,1])))

#data.head()
# Out:
# Main frequencies estimated via fit functions:
#
# hare: (0.10 +- 0.02) 1/year
# lynx: (0.10 +- 0.03) 1/year

# %% [markdown]
# 5\. **FFT of an image**
#
# * Examine the provided image `moonlanding.png`, which is heavily contaminated with periodic noise. In this exercise, we aim to clean up the noise using the Fast Fourier Transform.
# * Load the image using pylab.imread().
# * Find and use the 2-D FFT function in scipy.fftpack, and plot the spectrum (Fourier transform of) the image. Do you have any trouble visualising the spectrum? If so, why?
# * The spectrum consists of high and low frequency components. The noise is contained in the high-frequency part of the spectrum, so set some of those components to zero (use array slicing).
# * Apply the inverse Fourier transform to see the resulting image.

# %%
img = plt.imread('Data/moonlanding.png')
img_fft = fftpack.fft2(img)
power_spectrum = np.abs(img_fft)

# Image and Spectrum visualization
fig = plt.figure(figsize=(15,15))
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img, plt.cm.gray)
ax1.set_title('Original image')

from matplotlib.colors import LogNorm
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(power_spectrum, norm=LogNorm(vmin=5))
ax2.set_title('Power spectrum')

# Filtering. High frequencies are the edges of the image
r, c = img_fft.shape[0], img_fft.shape[1]
cutoff = 0.05
img_fft2 = img_fft.copy()
mask = np.ones((r, c))
mask[int(r*cutoff) : int(r*(1-cutoff)), int(c*cutoff) : int(c*(1-cutoff))] = 0
img_fft2 = img_fft2 * mask
power_spectrum_filtered = np.abs(img_fft2)
img_filtered = fftpack.ifft2(img_fft2).real

# Visualization
ax3 = fig.add_subplot(2,2,3)
ax3.imshow(img_filtered, plt.cm.gray)
ax3.set_title('Filtered image')

ax4 = fig.add_subplot(2,2,4)
ax4.imshow(power_spectrum_filtered, norm=LogNorm(vmin=5))
ax4.set_title('Power spectrum filtered')
# Out:
# Text(0.5, 1.0, 'Power spectrum filtered')
