# %% [markdown]
# ## Pandas analysis
#
# This exercise consists in analyzing a dataset containg timing information from a series of Time-to-Digital-Converters (TDC) implemented in a couple of FPGAs. Each measurement (i.e. each row of the input file) consists of a flag that specifies the type of message ('HEAD', which in this case is always 1), two addresses of the TDC providing the signal ('FPGA' and 'TDC_CHANNEL'), and the timing information ('ORBIT_CNT', 'BX_COUNTER', and 'TDC_MEAS'). Each TDC count corresponds to 25/30 ns, whereas a unit of BX_COUNTER corresponds to 25 ns, and the ORBIT_CNT is increased every 'x' BX_COUNTER. This allows to store the time in a similar way to hours, minutes and seconds.

# %%
# If you didn't download it yet, please get the relevant file now!
#!wget https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt -P ~/data/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1\. Create a Pandas DataFrame reading N rows of the 'data_000637.txt' dataset. Choose N to be smaller than or equal to the maximum number of rows and larger that 10k.

# %%
file_name="/home/francesco/data/data_000637.txt.1"
N_rows=np.random.randint(10000,1310720)
df=pd.read_csv(file_name, nrows=N_rows)
df
# Out:
#         HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 0          1     0          123  3869200167        2374        26
# 1          1     0          124  3869200167        2374        27
# 2          1     0           63  3869200167        2553        28
# 3          1     0           64  3869200167        2558        19
# 4          1     0           64  3869200167        2760        25
# ...      ...   ...          ...         ...         ...       ...
# 638491     1     0           61  3869206570        1026        26
# 638492     1     0           47  3869206570        1026        14
# 638493     1     0           53  3869206570        1021         7
# 638494     1     0           54  3869206570        1020        20
# 638495     1     0           49  3869206570        1022        26
#
# [638496 rows x 6 columns]

# %% [markdown]
# 2. Find out the number of BX in a ORBIT (the value 'x').

# %%
df.groupby('ORBIT_CNT').max().hist('BX_COUNTER',bins=200)
# Out:
# Max value of BX_COUNTER:  3563
# array([[<AxesSubplot:title={'center':'BX_COUNTER'}>]], dtype=object)

# %%
df.groupby('ORBIT_CNT').max()
# Out:
#             HEAD  FPGA  TDC_CHANNEL  BX_COUNTER  TDC_MEAS
# ORBIT_CNT
# 3869200167     1     1          139        3187        28
# 3869200168     1     1          139        3538        29
# 3869200169     1     1          139        2766        29
# 3869200170     1     1          139        3377        29
# 3869200171     1     1          139        3542        29
# ...          ...   ...          ...         ...       ...
# 3869206566     1     1          139        3334        29
# 3869206567     1     1          139        3459        29
# 3869206568     1     1          139        3559        29
# 3869206569     1     1          139        3546        29
# 3869206570     1     1          139        1026        29
#
# [6400 rows x 5 columns]

# %%
orb_size=df.groupby('ORBIT_CNT').max().loc[:,"BX_COUNTER"].max()
print('Orbit size: ', orb_size)

num_orb=df[df['BX_COUNTER']==orb_size].shape[0]
print('Number of BX_COUNTER==Orbit size: ', num_orb)
# Out:
# Orbit size:  3563
# Number of BX_COUNTER==Orbit size:  177

# %% [markdown]
# 3\. Find out how much the data taking lasted. You can either make an estimate based on the fraction of the measurements (rows) you read, or perform this check precisely by reading out the whole dataset.

# %%
max_orb=df["ORBIT_CNT"].max()
min_orb=df["ORBIT_CNT"].min()
n_orb=max_orb-min_orb+1
#every orbit lasts 3563 BX_COUNTERs, except for the first and the last ones
#calculate time in ns

#first we calculate the time of the complete orbits

time_compl=(n_orb-2)*orb_size*25

#first orbit
bx_forb=df[df['ORBIT_CNT']==min_orb]['BX_COUNTER'].min()
#print(bx_forb)
ftdcm=df[df['ORBIT_CNT']==min_orb][df['BX_COUNTER']==bx_forb]['TDC_MEAS'].min()
#print(ftdcm)
t_forb=(orb_size)-bx_forb*25+(30-ftdcm+1)*(25/30)

bx_lorb=df[df['ORBIT_CNT']==max_orb]['BX_COUNTER'].max()
#print(bx_lorb)
ltdcm=df[df['ORBIT_CNT']==max_orb][df['BX_COUNTER']==bx_lorb]['TDC_MEAS'].max()
#print(ftdcm)
t_lorb=bx_lorb*25+ltdcm*(25/30)


tot_time=time_compl+t_forb+t_lorb
print("Total time: ", tot_time)
# Out:
# Total time:  570228038.8333333
# <ipython-input-42-2a8130f8a0f7>:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ftdcm=df[df['ORBIT_CNT']==min_orb][df['BX_COUNTER']==bx_forb]['TDC_MEAS'].min()
# <ipython-input-42-2a8130f8a0f7>:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ltdcm=df[df['ORBIT_CNT']==max_orb][df['BX_COUNTER']==bx_lorb]['TDC_MEAS'].max()

# %% [markdown]
# 4\. Create a new column with the absolute time in ns (as a combination of the other three columns with timing information).

# %%
df['ABS_TIME']=pd.Series((df['ORBIT_CNT']-min_orb)*orb_size*25+(df['BX_COUNTER']-bx_forb)*25+(df['TDC_MEAS']-ftdcm)*(25/30))
df
# Out:
#         HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0          1     0          123  3869200167        2374        26
# 1          1     0          124  3869200167        2374        27
# 2          1     0           63  3869200167        2553        28
# 3          0     0           64  3869200167        2558        19
# 4          1     0           64  3869200167        2760        25
# ...      ...   ...          ...         ...         ...       ...
# 638491     1     0           61  3869206570        1026        26
# 638492     0     0           47  3869206570        1026        14
# 638493     1     0           53  3869206570        1021         7
# 638494     1     0           54  3869206570        1020        20
# 638495     0     0           49  3869206570        1022        26
#
#             ABS_TIME
# 0       0.000000e+00
# 1       8.333333e-01
# 2       4.476667e+03
# 3       4.594167e+03
# 4       9.649167e+03
# ...              ...
# ...

# %% [markdown]
# 5\. Replace the values (all 1) of the HEAD column randomly with 0 or 1.

# %%
df['HEAD']=pd.Series(np.random.randint(0,2,df.shape[0]))
df
# Out:
#         HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0          1     0          123  3869200167        2374        26
# 1          1     0          124  3869200167        2374        27
# 2          1     0           63  3869200167        2553        28
# 3          0     0           64  3869200167        2558        19
# 4          1     0           64  3869200167        2760        25
# ...      ...   ...          ...         ...         ...       ...
# 638491     1     0           61  3869206570        1026        26
# 638492     0     0           47  3869206570        1026        14
# 638493     1     0           53  3869206570        1021         7
# 638494     1     0           54  3869206570        1020        20
# 638495     0     0           49  3869206570        1022        26
#
#             ABS_TIME
# 0       5.937167e+04
# 1       5.937250e+04
# 2       6.384833e+04
# 3       6.396583e+04
# 4       6.902083e+04
# ...              ...
# ...

# %% [markdown]
# 6\. Create a new DataFrame that contains only the rows with HEAD=1.

# %%
df_new=df[df['HEAD']==1]
df_new
# Out:
#         HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0          1     0          123  3869200167        2374        26
# 1          1     0          124  3869200167        2374        27
# 2          1     0           63  3869200167        2553        28
# 4          1     0           64  3869200167        2760        25
# 5          1     0           63  3869200167        2762         4
# ...      ...   ...          ...         ...         ...       ...
# 638486     1     0          139  3869206570        1023         0
# 638487     1     0           63  3869206570        1016        12
# 638491     1     0           61  3869206570        1026        26
# 638493     1     0           53  3869206570        1021         7
# 638494     1     0           54  3869206570        1020        20
#
#             ABS_TIME
# 0       5.937167e+04
# 1       5.937250e+04
# 2       6.384833e+04
# 4       6.902083e+04
# 5       6.905333e+04
# ...              ...
# ...

# %% [markdown]
# 7\. Make two occupancy plots (one for each FPGA), i.e. plot the number of counts per TDC channel

# %%
plt.hist(df[df['FPGA']==0]['TDC_CHANNEL'])
# Out:
# (array([ 10721.,  23359.,  34697.,  95309., 184773.,  11844.,  12468.,
#           4729.,  34274.,  37248.]),
#  array([  1. ,  14.8,  28.6,  42.4,  56.2,  70. ,  83.8,  97.6, 111.4,
#         125.2, 139. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 8\. Use the groupby method to find out the noisy channels, i.e. the TDC channels with most counts (say the top 3)

# %%
df.groupby('TDC_CHANNEL').size().sort_values(ascending=False).head(3)
# Out:
# TDC_CHANNEL
# 139    53066
# 64     31977
# 63     31373
# dtype: int64

# %% [markdown]
# 9\. Count the number of unique orbits. Count the number of unique orbits with at least one measurement from TDC_CHANNEL=139

# %%
df.groupby('ORBIT_CNT').size().sort_values(ascending=True)
# Out:
# ORBIT_CNT
# 3869206180      1
# 3869204142      1
# 3869205800      2
# 3869203571      2
# 3869206229      3
#              ...
# 3869206521    247
# 3869206565    258
# 3869206536    275
# 3869206454    301
# 3869206506    305
# Length: 6400, dtype: int64
