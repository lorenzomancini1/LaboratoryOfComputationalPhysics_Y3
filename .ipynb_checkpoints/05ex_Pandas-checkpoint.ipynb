# %% [markdown]
# ## Pandas analysis
#
# This exercise consists in analyzing a dataset containg timing information from a series of Time-to-Digital-Converters (TDC) implemented in a couple of FPGAs. Each measurement (i.e. each row of the input file) consists of a flag that specifies the type of message ('HEAD', which in this case is always 1), two addresses of the TDC providing the signal ('FPGA' and 'TDC_CHANNEL'), and the timing information ('ORBIT_CNT', 'BX_COUNTER', and 'TDC_MEAS'). Each TDC count corresponds to 25/30 ns, whereas a unit of BX_COUNTER corresponds to 25 ns, and the ORBIT_CNT is increased every 'x' BX_COUNTER. This allows to store the time in a similar way to hours, minutes and seconds.

# %%
# If you didn't download it yet, please get the relevant file now!
# !wget https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt -P ~/data/

# %% [markdown]
# 1\. Create a Pandas DataFrame reading N rows of the 'data_000637.txt' dataset. Choose N to be smaller than or equal to the maximum number of rows and larger that 10k.
#
# 2\. Find out the number of BX in a ORBIT (the value 'x').
#
# 3\. Find out how much the data taking lasted. You can either make an estimate based on the fraction of the measurements (rows) you read, or perform this check precisely by reading out the whole dataset.
#
# 4\. Create a new column with the absolute time in ns (as a combination of the other three columns with timing information).
#
# 5\. Replace the values (all 1) of the HEAD column randomly with 0 or 1.
#
# 6\. Create a new DataFrame that contains only the rows with HEAD=1.
#
# 7\. Make two occupancy plots (one for each FPGA), i.e. plot the number of counts per TDC channel
#
# 8\. Use the groupby method to find out the noisy channels, i.e. the TDC channels with most counts (say the top 3)
#
# 9\. Count the number of unique orbits. Count the number of unique orbits with at least one measurement from TDC_CHANNEL=139

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#1: create the Pandas DataFrame
file_name='~/data/data_000637.txt'
df=pd.read_csv(file_name)
df
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 0           1     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1310715     1     0           62  3869211171         762        14
# 1310716     1     1            4  3869211171         763        11
# 1310717     1     0           64  3869211171         764         0
# 1310718     1     0          139  3869211171         769         0
# 1310719     1     0           61  3869211171         762        18
#
# [1310720 rows x 6 columns]

# %%
#2: find out the number of BX in an ORBIT
x=np.max(df['BX_COUNTER'])+1
print(x)
# Out:
# 3564

# %%
#3: find out how much the data taking lasted
t_orbits = (np.max(df['ORBIT_CNT'])-np.min(df['ORBIT_CNT']))*25*10**(-9)*x
df_max = df[df['ORBIT_CNT'] == np.max(df['ORBIT_CNT'])]
df_min = df[df['ORBIT_CNT'] == np.min(df['ORBIT_CNT'])]
t_bx = (np.max(df_max['BX_COUNTER'])-np.min(df_min['BX_COUNTER']))*25*10**(-9)
df_max1 = df_max[df_max['BX_COUNTER'] == np.max(df_max['BX_COUNTER'])]
df_min1 = df_min[df_min['BX_COUNTER'] == np.min(df_min['BX_COUNTER'])]
t_meas = (np.max(df_max1['TDC_MEAS'])-np.min(df_min1['TDC_MEAS']))*25*10**(-9)/30
time = t_orbits+t_bx+t_meas
print('The data taking lasted {} s'.format(time))
# Out:
# The data taking lasted 0.9804162533333335 s

# %%
#4: create a new column with the absolut time in ns
df['ABS_TIME(ns)'] = 25/30*df['TDC_MEAS']+25*df['BX_COUNTER']+25*x*df['ORBIT_CNT']
df
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0           1     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1310715     1     0           62  3869211171         762        14
# 1310716     1     1            4  3869211171         763        11
# 1310717     1     0           64  3869211171         764         0
# 1310718     1     0          139  3869211171         769         0
# 1310719     1     0           61  3869211171         762        18
#
#          ABS_TIME(ns)
# 0        3.447457e+14
# 1        3.447457e+14
# 2        3.447457e+14
# 3        3.447457e+14
# 4        3.447457e+14
# ...

# %%
#5: Replace the values (all 1) of the HEAD column randomly with 0 or 1
df.loc[:,'HEAD'] = np.random.randint(0,2,len(df))
df
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0           1     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1310715     1     0           62  3869211171         762        14
# 1310716     0     1            4  3869211171         763        11
# 1310717     0     0           64  3869211171         764         0
# 1310718     1     0          139  3869211171         769         0
# 1310719     1     0           61  3869211171         762        18
#
#          ABS_TIME(ns)
# 0        3.447457e+14
# 1        3.447457e+14
# 2        3.447457e+14
# 3        3.447457e+14
# 4        3.447457e+14
# ...

# %%
#6: Create a new DataFrame that contains only the rows with HEAD=1
new_df = df[df['HEAD']==1]
new_df
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0           1     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1310711     1     1           39  3869211171         430         0
# 1310712     1     1           35  3869211171         429         4
# 1310715     1     0           62  3869211171         762        14
# 1310718     1     0          139  3869211171         769         0
# 1310719     1     0           61  3869211171         762        18
#
#          ABS_TIME(ns)
# 0        3.447457e+14
# 1        3.447457e+14
# 2        3.447457e+14
# 3        3.447457e+14
# 4        3.447457e+14
# ...

# %%
#7: Make two occupancy plots (one for each FPGA)
df_0 = df[df['FPGA'] == 0]
df_1 = df[df['FPGA'] == 1]
plt.clf()
fig, axes= plt.subplots(nrows=1, ncols=2, tight_layout=False, figsize=(18, 6))
fig.subplots_adjust(wspace=0.05)
ax0, ax1 = axes.flatten()
count_0,bins,_ = ax0.hist(df_0['TDC_CHANNEL'], bins=int(df_0['TDC_CHANNEL'].max()-df_0['TDC_CHANNEL'].min()), range=(df_0['TDC_CHANNEL'].min(), df_0['TDC_CHANNEL'].max()), histtype='bar',color='green',alpha=0.8)
ax0.set_xlabel('TDC CHANNELS FPGA 0', size=14)
ax0.set_ylabel('Counts', size=14)
count_1 = ax1.hist(df_1['TDC_CHANNEL'], bins=int(df_1['TDC_CHANNEL'].max()-df_1['TDC_CHANNEL'].min()), range=(df_1['TDC_CHANNEL'].min(), df_1['TDC_CHANNEL'].max()), histtype='bar',color='blue',alpha=0.8)
ax1.set_xlabel('TDC CHANNELS FPGA 1', size=14)
ax1.set_ylabel('Counts', size=14)
ax1.yaxis.set_label_position("right")
ax1.yaxis.tick_right()
plt.show()

# %%
#8: find out the noisy channels
grouped_df = df.groupby("TDC_CHANNEL")
indexis = np.array([len(grouped_df.get_group(key)) for key, item in grouped_df])
keys = np.array([key for key, item in grouped_df])
ix = indexis.argsort()[-3:][::-1]

print("The TDC channels with most counts are {}".format(keys[ix]))
# Out:
# The TDC channels with most counts are [139  64  63]

# %%
#9: find out the number of unique orbits    
unique_orbit = len(df.drop_duplicates(subset = "ORBIT_CNT", keep = "first"))
unique_orbit1 = len(df.drop_duplicates(subset = 'ORBIT_CNT', keep = 'first').loc[df['TDC_CHANNEL'] == 139])
print('number of unique orbits: {}\nnumber of unique orbits with at least one measurement from TDC_CHANNEL=139: {}' .format(unique_orbit, unique_orbit1))
# Out:
# number of unique orbits: 11001
# number of unique orbits with at least one measurement from TDC_CHANNEL=139: 203
