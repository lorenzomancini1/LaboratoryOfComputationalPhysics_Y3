# %% [markdown]
# ## Pandas analysis
#
# This exercise consists in analyzing a dataset containg timing information from a series of Time-to-Digital-Converters (TDC) implemented in a couple of FPGAs. Each measurement (i.e. each row of the input file) consists of a flag that specifies the type of message ('HEAD', which in this case is always 1), two addresses of the TDC providing the signal ('FPGA' and 'TDC_CHANNEL'), and the timing information ('ORBIT_CNT', 'BX_COUNTER', and 'TDC_MEAS'). Each TDC count corresponds to 25/30 ns, whereas a unit of BX_COUNTER corresponds to 25 ns, and the ORBIT_CNT is increased every 'x' BX_COUNTER. This allows to store the time in a similar way to hours, minutes and seconds.

# %%
# If you didn't download it yet, please get the relevant file now!
#!wget https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt -P data/

# %% [markdown]
# 1\. Create a Pandas DataFrame reading N rows of the 'data_000637.txt' dataset. Choose N to be smaller than or equal to the maximum number of rows and larger that 10k.
#
# 2\. Find out the number of BX in a ORBIT (the value 'x').
#
# 3\. Find out how much the data taking lasted. You can either make an estimate based on the fraction of the measurements (rows) you read, or perform this check precisely by reading out the whole dataset.
#
# 4\. Create a new column with the absolute time in ns (as a combination of the other three columns with timing information).
#
# 5\. Replace the values (all 1) of the HEAD column randomly with 0 or 1.
#
# 6\. Create a new DataFrame that contains only the rows with HEAD=1.
#
# 7\. Make two occupancy plots (one for each FPGA), i.e. plot the number of counts per TDC channel
#
# 8\. Use the groupby method to find out the noisy channels, i.e. the TDC channels with most counts (say the top 3)
#
# 9\. Count the number of unique orbits. Count the number of unique orbits with at least one measurement from TDC_CHANNEL=139

# %%
import pandas as pd
import numpy as np

file_name="data\data_000637.txt"
with open(file_name) as data:
    n_rows = len(data.readlines())
data=pd.read_csv(file_name, nrows=np.random.randint(1e5,n_rows))
data
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 0           1     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1008934     1     1          114  3869209075         599        26
# 1008935     1     1          113  3869209075         604         7
# 1008936     1     1          114  3869209075         603        23
# 1008937     1     0           49  3869209075         677        14
# 1008938     1     0           50  3869209075         678        25
#
# [1008939 rows x 6 columns]

# %%
#the ORBIT_CNT is increased every 'x' BX_COUNTER. x=?

x=max(data.loc[:,'BX_COUNTER'])+1 #+1 because also the 0 must be counted, like hours go 0-59 but the minutes are 60
print('x=', x)
# Out:
# x= 3564

# %%
#Find out how much the data taking lasted. 
#You can either make an estimate based on the fraction of the measurements (rows) you read, 
#or perform this check precisely by reading out the whole dataset.

#1 ORBIT_CNT = 3564 BX_COUNTER, 1 BX_COUNTER=30 TDC_MEAS, 1 TDC_MEAS = 25/30 ns
i_max_OCNT=data.loc[:,'ORBIT_CNT'][::-1].idxmax(axis=0)      #finds index of max value in ORBIT_CNT
i_min_OCNT=data.loc[:,'ORBIT_CNT'].idxmin(axis=0)            #finds index of min value in ORBIT_CNT

abs_time_max=(( data.loc[:,'ORBIT_CNT'][i_max_OCNT]*x        #1 ORBIT_CNT= x BX_COUNTER
          + data.loc[:,'BX_COUNTER'][i_max_OCNT])*30         #1 BX_COUNTER=30 TDC_MEAS
          + data.loc[:,'TDC_MEAS'][i_max_OCNT])*25/30        #1 TDC_MEAS = 25/30 ns
abs_time_min=(( data.loc[:,'ORBIT_CNT'][i_min_OCNT]*x        #1 ORBIT_CNT= x BX_COUNTER
          + data.loc[:,'BX_COUNTER'][i_min_OCNT])*30         #1 BX_COUNTER=30 TDC_MEAS
          + data.loc[:,'TDC_MEAS'][i_min_OCNT])*25/30        #1 TDC_MEAS = 25/30 ns

duration=abs_time_max-abs_time_min
print('Data taking lasted ' + str(duration*1e-9) +'s, or ' + str(duration) +'ns')
# Out:
# Data taking lasted 0.7936603991250001s, or 793660399.125ns

# %%
#Create a new column with the absolute time in ns
#(as a combination of the other three columns with timing information).

data['timing_ns']=(( data.loc[:,'ORBIT_CNT']*x            #1 ORBIT_CNT= x BX_COUNTER
                    + data.loc[:,'BX_COUNTER'])*30         #1 BX_COUNTER=30 TDC_MEAS
                    + data.loc[:,'TDC_MEAS'])*25/30       #1 TDC_MEAS = 25/30 ns
data
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0           1     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1008934     1     1          114  3869209075         599        26
# 1008935     1     1          113  3869209075         604         7
# 1008936     1     1          114  3869209075         603        23
# 1008937     1     0           49  3869209075         677        14
# 1008938     1     0           50  3869209075         678        25
#
#             timing_ns
# 0        3.447457e+14
# 1        3.447457e+14
# 2        3.447457e+14
# 3        3.447457e+14
# 4        3.447457e+14
# ...

# %%
#Replace the values (all 1) of the HEAD column randomly with 0 or 1.
data['HEAD']=np.random.randint(0,2, len(data['HEAD']))
data
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0           0     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           0     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1008934     1     1          114  3869209075         599        26
# 1008935     1     1          113  3869209075         604         7
# 1008936     0     1          114  3869209075         603        23
# 1008937     0     0           49  3869209075         677        14
# 1008938     0     0           50  3869209075         678        25
#
#             timing_ns
# 0        3.447457e+14
# 1        3.447457e+14
# 2        3.447457e+14
# 3        3.447457e+14
# 4        3.447457e+14
# ...

# %%
#Create a new DataFrame that contains only the rows with HEAD=1.

data_H1 = data[data['HEAD']==1]
data_H1
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 5           1     0           63  3869200167        2762         4
# 7           1     0          139  3869200167        2776         0
# ...       ...   ...          ...         ...         ...       ...
# 1008925     1     1          111  3869209075         595        19
# 1008927     1     1          139  3869209075         598         0
# 1008931     1     1          115  3869209075         602         4
# 1008934     1     1          114  3869209075         599        26
# 1008935     1     1          113  3869209075         604         7
#
#             timing_ns
# 1        3.447457e+14
# 2        3.447457e+14
# 3        3.447457e+14
# 5        3.447457e+14
# 7        3.447457e+14
# ...

# %%
#Make two occupancy plots (one for each FPGA), i.e. plot the number of counts per TDC channel
import matplotlib.pyplot as plt

TDCC_FPGA=data[['TDC_CHANNEL','FPGA']] #drops every column in data except TDC_CHANNEL and FPGA

TDCC_FPGA_0=TDCC_FPGA[TDCC_FPGA['FPGA']==0] #drops when FPGA==1
Count_0=TDCC_FPGA_0.groupby('TDC_CHANNEL').size() #groups by TDC and gets size=number of counts
plt.figure(0)
Count_0.plot();
plt.ylabel('number of counts');
plt.title('FPGA = 0'); plt.legend('');

plt.figure(1)
TDCC_FPGA_1=TDCC_FPGA[TDCC_FPGA['FPGA']==1] #drops when FPGA==0
Count_1=TDCC_FPGA_1.groupby('TDC_CHANNEL').size() #groups by TDC and gets size=number of counts
Count_1.plot(); 
plt.ylabel('number of counts');
plt.title('FPGA = 1'); plt.legend('');

# %%
#Use the groupby method to find out the noisy channels, i.e. the TDC channels with most counts (say the top 3)

TDCC_FPGA=data[['TDC_CHANNEL','FPGA']] #drops every column in data except TDC_CHANNEL and FPGA

TDCC_FPGA_0=TDCC_FPGA[TDCC_FPGA['FPGA']==0] #drops when FPGA==1
Count_0=TDCC_FPGA_0.groupby('TDC_CHANNEL').size() #groups by TDC and gets size=number of counts
Max_Channels_0=Count_0.sort_values(ascending=False).index[[0,1,2]] #sorts not ascending and takes first 3 indexes 
Max_Channels_0=np.asarray(Max_Channels_0) #cleans from other unuseful notation

TDCC_FPGA_1=TDCC_FPGA[TDCC_FPGA['FPGA']==1] #drops when FPGA==0
Count_1=TDCC_FPGA_1.groupby('TDC_CHANNEL').size() #groups by TDC and gets size=number of counts
Max_Channels_1=Count_1.sort_values(ascending=False).index[[0,1,2]] #sorts not ascending and takes first 3 indexes 
Max_Channels_1=np.asarray(Max_Channels_1) #cleans from other unuseful notation

print('The noisy channels for FPGA=0 are ' + str(Max_Channels_0))
print('The noisy channels for FPGA=1 are ' + str(Max_Channels_1))
# Out:
# The noisy channels for FPGA=0 are [139  64  63]
# The noisy channels for FPGA=1 are [  2 139   1]

# %%
#Count the number of unique orbits. Count the number of unique orbits with at least one measurement from TDC_CHANNEL=139

uniq=len(data[data['TDC_CHANNEL'] == 139]['ORBIT_CNT'].unique())
print('Unique ORBIT_CNTs with TDC_CHANNEL=139: ' + str(uniq))
# Out:
# Unique ORBIT_CNTs with TDC_CHANNEL=139: 8880
