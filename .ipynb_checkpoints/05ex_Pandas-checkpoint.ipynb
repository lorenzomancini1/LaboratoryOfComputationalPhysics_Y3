# %% [markdown]
# ## Pandas analysis
#
# This exercise consists in analyzing a dataset containg timing information from a series of Time-to-Digital-Converters (TDC) implemented in a couple of FPGAs. Each measurement (i.e. each row of the input file) consists of a flag that specifies the type of message ('HEAD', which in this case is always 1), two addresses of the TDC providing the signal ('FPGA' and 'TDC_CHANNEL'), and the timing information ('ORBIT_CNT', 'BX_COUNTER', and 'TDC_MEAS'). Each TDC count corresponds to 25/30 ns, whereas a unit of BX_COUNTER corresponds to 25 ns, and the ORBIT_CNT is increased every 'x' BX_COUNTER. This allows to store the time in a similar way to hours, minutes and seconds.

# %%
# If you didn't download it yet, please get the relevant file now!
#!wget https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt -P ~/data/

# %% [markdown]
# 2\. Find out the number of BX in a ORBIT (the value 'x').

# %%
import pandas as pd
import numpy as np

# %%
file_name="./data/data_000637.txt"

def readNrowsfromfile(file,N):
    data = pd.read_csv(file)
    if N < 10000:
        print('insufficient number of rows, try more that 9999')
    elif N > data.shape[0]:
        print('too large number of rows, maximum number of rows: ',data.shape[0])
    else:
        mydata = pd.read_csv(file_name,nrows=N)
        return mydata
    
# not too happy that this function as it reads the file twice, but I didn't know how to check better if N is larger
# than the number of rows. Let us see if this function works

data = readNrowsfromfile(file_name, 314)
print(data == None)

data = readNrowsfromfile(file_name, 3141526)
print(data == None)

data = readNrowsfromfile(file_name, 31415)
print(data == None)
# Out:
# insufficient number of rows, try more that 9999
# True
# too large number of rows, maximum number of rows:  1310720
# True
#         HEAD   FPGA  TDC_CHANNEL  ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 0      False  False        False      False       False     False
# 1      False  False        False      False       False     False
# 2      False  False        False      False       False     False
# 3      False  False        False      False       False     False
# 4      False  False        False      False       False     False
# ...      ...    ...          ...        ...         ...       ...
# 31410  False  False        False      False       False     False
# 31411  False  False        False      False       False     False
# 31412  False  False        False      False       False     False
# 31413  False  False        False      False       False     False
# 31414  False  False        False      False       False     False
#
# [31415 rows x 6 columns]

# %% [markdown]
# 2. Find out the number of BX in a ORBIT (the value 'x').

# %%
data
# Out:
#        HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 0         1     0          123  3869200167        2374        26
# 1         1     0          124  3869200167        2374        27
# 2         1     0           63  3869200167        2553        28
# 3         1     0           64  3869200167        2558        19
# 4         1     0           64  3869200167        2760        25
# ...     ...   ...          ...         ...         ...       ...
# 31410     1     0          139  3869200480        1684         0
# 31411     1     0           40  3869200480        1681         1
# 31412     1     0          123  3869200480        1682         1
# 31413     1     0           59  3869200480        1992         2
# 31414     1     0           61  3869200480        1997        27
#
# [31415 rows x 6 columns]

# %%
# BX in a ORBIT
data['BX_COUNTER'].nlargest(1)

# a orbit should be 3464 bx_counter
# Out:
# 2893    3563
# Name: BX_COUNTER, dtype: int64

# %% [markdown]
# 3. Find out how much the data taking lasted. You can either make an estimate based on the fraction of the measurements (rows) you read, or perform this check precisely by reading out the whole dataset.

# %%
print((data.loc[31414]['ORBIT_CNT']-data.loc[0]['ORBIT_CNT'])*3564*25 + (data.loc[31414]['BX_COUNTER']-data.loc[0]['BX_COUNTER'])*25 + (data.loc[31414]['TDC_MEAS']-data.loc[0]['TDC_MEAS'])*25/30,'ns')
# Out:
# 27878875.833333332 ns

# %% [markdown]
# 4. Create a new column with the absolute time in ns (as a combination of the other three columns with timing information).

# %%
# a unit od TDC_MEAS corresponds to 25/30 ns
# a unit of BX_COUNTER corresponds to 25 ns -> 30*TDC_MEAS
# a unit of ORBIT_CNT corresponds to 3564 BX_COUNTER -> 3564*25 ns

timedata = np.array([(25/30)*data['TDC_MEAS'] + 25*data['BX_COUNTER'] + 3564*25*data['ORBIT_CNT']])
timedata.shape[1]

data.loc[:,'ABS_TIME'] = (timedata.T)
data
# Out:
#        HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS      ABS_TIME
# 0         1     0          123  3869200167        2374        26  3.447457e+14
# 1         1     0          124  3869200167        2374        27  3.447457e+14
# 2         1     0           63  3869200167        2553        28  3.447457e+14
# 3         1     0           64  3869200167        2558        19  3.447457e+14
# 4         1     0           64  3869200167        2760        25  3.447457e+14
# ...     ...   ...          ...         ...         ...       ...           ...
# 31410     1     0          139  3869200480        1684         0  3.447458e+14
# 31411     1     0           40  3869200480        1681         1  3.447458e+14
# 31412     1     0          123  3869200480        1682         1  3.447458e+14
# 31413     1     0           59  3869200480        1992         2  3.447458e+14
# 31414     1     0           61  3869200480        1997        27  3.447458e+14
#
# ...

# %% [markdown]
# 5. Replace the values (all 1) of the HEAD column randomly with 0 or 1.

# %%
data.loc[:,'HEAD'] = np.random.randint(2, size = data.shape[0])
data
# Out:
#        HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  ABS_TIME
# 0         1     0          123  3869200167        2374        26     59350
# 1         1     0          124  3869200167        2374        27     59350
# 2         1     0           63  3869200167        2553        28     63825
# 3         1     0           64  3869200167        2558        19     63950
# 4         0     0           64  3869200167        2760        25     69000
# ...     ...   ...          ...         ...         ...       ...       ...
# 31410     0     0          139  3869200480        1684         0     42100
# 31411     1     0           40  3869200480        1681         1     42025
# 31412     0     0          123  3869200480        1682         1     42050
# 31413     1     0           59  3869200480        1992         2     49800
# 31414     1     0           61  3869200480        1997        27     49925
#
# [31415 rows x 7 columns]

# %% [markdown]
# 6. Create a new DataFrame that contains only the rows with HEAD=1.

# %%
newdata = data[data['HEAD'] == 1]
newdata
# Out:
#        HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  ABS_TIME
# 0         1     0          123  3869200167        2374        26     59350
# 1         1     0          124  3869200167        2374        27     59350
# 2         1     0           63  3869200167        2553        28     63825
# 3         1     0           64  3869200167        2558        19     63950
# 6         1     0           61  3869200167        2772        14     69300
# ...     ...   ...          ...         ...         ...       ...       ...
# 31406     1     0           54  3869200480        1396        20     34900
# 31407     1     0           56  3869200480        1403         9     35075
# 31411     1     0           40  3869200480        1681         1     42025
# 31413     1     0           59  3869200480        1992         2     49800
# 31414     1     0           61  3869200480        1997        27     49925
#
# [15813 rows x 7 columns]

# %% [markdown]
# 7. Make two occupancy plots (one for each FPGA), i.e. plot the number of counts per TDC channel

# %%
import matplotlib.pyplot as plt

fpga0 = data[data['FPGA'] == 0]
fpga1 = data[data['FPGA'] == 1]

occupancy1 = fpga1['TDC_CHANNEL'].value_counts().sort_values()

occupancy1.index

d1 = pd.DataFrame({ "channel": occupancy1.index, "counts": occupancy1})
p1 = d1.sort_values(by="channel")
p1.plot(x="channel",y="counts")

occupancy0 = fpga0['TDC_CHANNEL'].value_counts().sort_values()

occupancy0.index

d0 = pd.DataFrame({ "channel": occupancy0.index, "counts": occupancy0})
p0 = d0.sort_values(by="channel")
p0.plot(x="channel",y="counts")

# %% [markdown]
# 8. Use the groupby method to find out the noisy channels, i.e. the TDC channels with most counts (say the top 3)

# %%
data
# Out:
#        HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  ABS_TIME
# 0         1     0          123  3869200167        2374        26     59350
# 1         1     0          124  3869200167        2374        27     59350
# 2         1     0           63  3869200167        2553        28     63825
# 3         1     0           64  3869200167        2558        19     63950
# 4         0     0           64  3869200167        2760        25     69000
# ...     ...   ...          ...         ...         ...       ...       ...
# 31410     0     0          139  3869200480        1684         0     42100
# 31411     1     0           40  3869200480        1681         1     42025
# 31412     0     0          123  3869200480        1682         1     42050
# 31413     1     0           59  3869200480        1992         2     49800
# 31414     1     0           61  3869200480        1997        27     49925
#
# [31415 rows x 7 columns]

# %%
data.sort_values(by=['TDC_CHANNEL'])
ex8 = data.groupby('TDC_CHANNEL')['BX_COUNTER'].sum().reset_index()
ex8
# Out:
#      TDC_CHANNEL  BX_COUNTER
# 0              1     1297590
# 1              2     1444789
# 2              3     1006132
# 3              4     1181686
# 4              5      722521
# ..           ...         ...
# 124          125       23161
# 125          126       16749
# 126          127       51149
# 127          128       54406
# 128          139     4625163
#
# [129 rows x 2 columns]

# %%
ex8['BX_COUNTER'].nlargest(3)
# Out:
# 128    4625163
# 63     2873266
# 62     2757815
# Name: BX_COUNTER, dtype: int64

# %% [markdown]
# 9. Count the number of unique orbits.

# %%
data
data['BX_COUNTER'].nunique()
# Out:
# 3556

# %% [markdown]
# 10. Count the number of unique orbits with at least one measurement from TDC_CHANNEL=139

# %%
ex10 = data[data['TDC_CHANNEL']==139]
ex10['BX_COUNTER'].nunique()
# Out:
# 1861
