# %%
import random
import csv
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
randomlistofnumber = np.random.rand(20)
print(randomlistofnumber)
# Out:
# [0.21206031 0.29837352 0.84986912 0.11610865 0.83334415 0.08184579
#  0.57408909 0.31486086 0.92888112 0.86784616 0.88890335 0.31467243
#  0.44972952 0.9202201  0.29435085 0.6097589  0.0163869  0.45810631
#  0.29758332 0.8772302 ]

# %%
a = open('simple_data.txt', 'w')
a.write(str(randomlistofnumber))
a.close()

# %%
randommatrix = np.random.rand(25).reshape(5,5)
a= open('data.txt', 'w')
for tab in randommatrix:
    for nb in tab :
        a.write(str(nb))
        a.write(' ')
    a.write('\n')
a.close()

# %%
with open('data.txt', 'w') as d:
    for i in range(5):
        for item in randommatrix[i]:
            d.write("%s" %str(item))
        d.write("\n")

# %%
df = pd.read_csv("data.txt")
df.to_csv('data.csv', index = None)
print(df)
# Out:
#   0.29952303252375280.336854921968688160.192871670495579180.98125844149739480.06290218732843622
# 0  0.356295155988517460.9862831163438640.57155869...
# 1  0.97295346239839560.07067378983524520.33684789...
# 2  0.439244984080309540.94378774745589860.4632688...
# 3  0.271255985412275250.81239668456428840.4626510...

# %%
card_numbers=[]
with open('credit_card.dat',mode='rb') as file:
    for line in file:
        characters=[]
        no_padding=line[: -5]
        numbers=[chr(int(no_padding[6*i:6*i+6], 2)) for i in range(0, len(no_padding)//6)]
        card_numbers.append(''.join(numbers))
x=card_numbers.pop()
print(card_numbers)
# Out:
# ['7648 5673 3775 2271', '3257 8247 3354 2266', '2722 0001 4011 6652', '0661 3063 3742 3150', '0432 1608 1462 4742', '5827 2027 8785 7303', '5774 8528 2087 1117', '8140 1210 6352 2845', '5764 1133 7301 7100', '6456 1737 4126 6726', '1228 8631 7382 0000', '7051 0160 5374 3166', '0618 3587 1630 6376', '1545 5454 7444 5636', '6735 3116 3202 6834', '7287 5011 1547 8413', '7033 2607 3328 4200', '2568 5244 1874 5024', '1684 2253 7570 7118', '0672 2576 0575 6631', '6332 8353 8787 1340', '1813 3361 1175 4211', '2477 6450 8840 2368', '5512 3505 2563 1326', '3083 7882 0621 0025', '4521 5148 8045 0334', '7563 3654 8713 5787', '8324 2664 0476 5561', '0565 2504 7168 3510', '5107 5507 1767 0738', '2462 1821 2448 1443', '2788 0638 6861 6554', '5851 5873 5474 0547', '0670 1004 4013 2655', '5874 5506 3048 0806', '2805 5401 8462 1260', '5083 8406 6310 1862', '1076 1445 3013 2266', '8440 4804 4844 5277', '4758 6141 0686 1387', '7586 0675 0315 2568', '2544 1258 7432 5165', '3474 5023 4434 5626', '1410 02
# ...

# %%
df = pd.read_json('user_data.json')
output_data = df.loc[df['CreditCardType'] == 'American Express']
output_data.to_csv(r'user_data.csv', index = False, header=True)

# %%
url="https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1"
data = pd.read_csv(url)
data.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
data.hist('class')
print('class is either 0 or 1 and they are with almost equal numbers')
# Out:
# class is either 1 or 0 and they are with almost equal numbers

# %%
url="https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1"
data = pd.read_csv(url)

# %%
# %matplotlib inline
data.plot.scatter("features_1","features_2",color='blue')
data.plot.scatter("features_2","features_3",color='violet')
data.plot.scatter("features_1","features_3",color='green')

# %%
url='https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1'
data = pd.read_csv(url)
data.to_json('mushrooms_categorized.json', orient='records', lines=True)
