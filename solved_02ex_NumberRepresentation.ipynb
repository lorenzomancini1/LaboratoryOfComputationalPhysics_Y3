# %% [markdown]
# 1\. Write a function that converts number representation (bin<->dec<->hex)

# %%
def bin_dec_hex(x):
  if("0b" in str(x)): var=int(var,2)
  elif("0x" in str(x)): var=int(var,16)
  else: var = x
  return bin(var), var, hex(var)

print(bin_dec_hex(0b1010))
# Out:
# ('0b1010', 10, '0xa')

# %% [markdown]
# 2\. Write a function that converts a 32 bit word into a single precision floating point (i.e. interprets the various bits as sign, mantissa and exponent)

# %%
import math as m
def convert_float(x):
  sign=-1 if(int(x[0])==1) else 1
  exp= int(x[1:9],2) -127
  mant=1
  for i in range(23):
    mant+= int(x[i+9])*2**(-i-1)
  return sign*mant*2**exp

print(convert_float('11111111111111111111111111111111'))
# Out:
# -6.805646932770577e+38

# %% [markdown]
# 3\. Write a program to determine the underflow and overflow limits (within a factor of 2) for python on your computer.
#
# **Tips**: define two variables inizialized to 1 and halve/double them enough time to exceed the under/over-flow limits

# %%
x=1
not_error=True
while(not_error):
  temp=x
  x*=100
  if(x<temp):
    not_error=False
    print('Overflow after ',temp)

# %% [markdown]
# 4\. Write a program to determine the machine precision
#
# **Tips**: define a new variable by adding a smaller and smaller value (proceeding similarly to prob. 2) to an original variable and check the point where the two are the same

# %%
x=1
iter=1
not_error=True
while(not_error):
  temp=x+x/iter
  if(x==temp):
    not_error=False
    print('smallest precision',x/iter)
  iter+=10

# %% [markdown]
# 5\. Write a function that takes in input three parameters $a$, $b$ and $c$ and prints out the two solutions to the quadratic equation $ax^2+bx+c=0$ using the standard formula:
# $$
# x=\frac{-b\pm\sqrt{b^2-4ac}}{2a}
# $$
#
# (a) use the program to compute the solution for $a=0.001$, $b=1000$ and $c=0.001$
#
# (b) re-express the standard solution formula by multiplying top and bottom by $-b\mp\sqrt{b^2-4ac}$ and again find the solution for $a=0.001$, $b=1000$ and $c=0.001$. How does it compare with what previously obtained? Why?
#
# (c) write a function that compute the roots of a quadratic equation accurately in all cases

# %%
import math as m
def quad_solver(a,b,c):
  x1=(-b + m.sqrt(b**2-4*a*c))/(2*a)
  x2=(-b - m.sqrt(b**2-4*a*c))/(2*a)
  x3=(4*a*c)*(-b - m.sqrt(b**2-4*a*c))/(2*a)
  x4=(4*a*c)*(-b + m.sqrt(b**2-4*a*c))/(2*a)
  return (x1,x2),(x3,x4)

print(quad_solver(0.001,1000,0.001))

def prec_quad_solver(a,b,c):
  x1=(-b + m.sqrt(b**2-4*a*c))*(-b - m.sqrt(b**2-4*a*c)) / (-b - m.sqrt(b**2-4*a*c))/(2*a)
  x2=(-b - m.sqrt(b**2-4*a*c))*(-b + m.sqrt(b**2-4*a*c)) / (-b + m.sqrt(b**2-4*a*c))/(2*a)
  return (x1,x2)

print(prec_quad_solver(0.001,1000,0.001))

#there are numerical issues for the very big and very small numbers involved in the equations,
#the b point with different expression leads to a wrong result, giving a lot of importance to the term 4*a*c
# Out:
# ((-9.999894245993346e-07, -999999.999999), (-3.9999999999959996, -3.999957698397338e-12))
# (-9.999894245993346e-07, -999999.999999)

# %% [markdown]
# 6\. Write a program that implements the function $f(x)=x(x−1)$
#
# (a) Calculate the derivative of the function at the point $x = 1$ using the derivative definition:
#
# $$
# \frac{{\rm d}f}{{\rm d}x} = \lim_{\delta\to0} \frac{f(x+\delta)-f(x)}{\delta}
# $$
#
# with $\delta = 10^{−2}$. Calculate the true value of the same derivative analytically and compare with the answer your program gives. The two will not agree perfectly. Why not?
#
# (b) Repeat the calculation for $\delta = 10^{−4}, 10^{−6}, 10^{−8}, 10^{−10}, 10^{−12}$ and $10^{−14}$. How does the accuracy scales with $\delta$?

# %%
func=lambda x:x*(x-1)
def deriv(f,p,d):
  return (f(p+d)-f(p))/d

print(deriv(func,1,1e-2))
print(deriv(func,1,1e-4))
print(deriv(func,1,1e-6))
print(deriv(func,1,1e-8))
print(deriv(func,1,1e-10))
print(deriv(func,1,1e-12))
print(deriv(func,1,1e-14))

#if delta increase the result is nearer to the true reult 1 (2*x-1), this is due to better approximation
# Out:
# 1.010000000000001
# 1.0000999999998899
# 1.0000009999177333
# 1.0000000039225287
# 1.000000082840371
# 1.0000889005833413
# 0.9992007221626509

# %% [markdown]
# 7\. Consider the integral of the semicircle of radius 1:
# $$
# I=\int_{-1}^{1} \sqrt(1-x^2) {\rm d}x
# $$
# which it's known to be $I=\frac{\pi}{2}=1.57079632679...$.
# Alternatively we can use the Riemann definition of the integral:
# $$
# I=\lim_{N\to\infty} \sum_{k=1}^{N} h y_k
# $$
#
# with $h=2/N$ the width of each of the $N$ slices the domain is divided into and where
# $y_k$ is the value of the function at the $k-$th slice.
#
# (a) Write a programe to compute the integral with $N=100$. How does the result compares to the true value?
#
# (b) How much can $N$ be increased if the computation needs to be run in less than a second? What is the gain in running it for 1 minute?

# %%
import time
f=lambda x: m.sqrt(1-x**2)
N=2500000
I=0
start=time.time()
for i in range(1,N+1):
  I+=2/N*f(1/N*i)
pass_time=time.time() - start
print('passed seconds:',pass_time)

print(I)
#Higher N makes the result more precise
#B) it depends on how fast is the computer, N shold be selected as (total time)/(time for 1 iteration of the cicle), 
#but this is not so easy because with increasing N increase also the operation complexity 
#running for a lot of time leads to a very small error, but the improvement is less than the sixth decimal digit so it could be useless
# Out:
# passed seconds: 0.9881770610809326
# 1.5707959266461886
